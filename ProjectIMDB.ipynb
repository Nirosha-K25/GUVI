# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in d:\nirosha\guvi\.venv\lib\site-packages (4.34.0)
# Requirement already satisfied: urllib3~=2.4.0 in d:\nirosha\guvi\.venv\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in d:\nirosha\guvi\.venv\lib\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in d:\nirosha\guvi\.venv\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in d:\nirosha\guvi\.venv\lib\site-packages (from selenium) (2025.6.15)
# Requirement already satisfied: typing_extensions~=4.14.0 in d:\nirosha\guvi\.venv\lib\site-packages (from selenium) (4.14.0)
# Requirement already satisfied: websocket-client~=1.8.0 in d:\nirosha\guvi\.venv\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in d:\nirosha\guvi\.venv\lib\site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in d:\nirosha\guvi\.venv\lib\site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in d:\nirosha\guvi\.venv\lib\site-packages (from trio~=0.30.0->selenium) (3.10)
# Requirement already satisfied: outcome in d:\nirosha\guvi\.venv\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in d:\nirosha\guvi\.venv\lib\site-packages (from trio~=0.30.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in d:\nirosha\guvi\.venv\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in d:\nirosha\guvi\.venv\lib\site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in d:\nirosha\guvi\.venv\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in d:\nirosha\guvi\.venv\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in d:\nirosha\guvi\.venv\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Action movies 

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

# Initialize WebDriver
driver = webdriver.Chrome()
driver.get(r"https://www.imdb.com/search/title/?title_type=feature&genres=action&release_date=2024-01-01,2024-12-31")

time.sleep(5)  # Waiting for the page to load

genre = "Action"

# Scroll Until No More New Data Loads
scroll = True
movies_per_page = 50  # Assuming each load gives 50 movies
total_movies = 500
current_movies = 0

while scroll and current_movies < total_movies:
    old_page_source = driver.page_source  # Save old page source
    
    # Scroll down to load more data
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Allow time for new data to load
    
    new_page_source = driver.page_source  # Save new page source

    if new_page_source == old_page_source:
        try:
            # Locate and click the "See More" button if present
            see_more_button = driver.find_element(By.XPATH, "//span[contains(@class, 'ipc-see-more')]")
            ActionChains(driver).move_to_element(see_more_button).click().perform()
            time.sleep(2)  # Wait for new content to load
        except Exception:
            scroll = False  # Stop scroll if button isn't found
    else:
        current_movies += movies_per_page  # Increment count

# Extract movie containers
movie_block = driver.find_elements(By.CSS_SELECTOR, "li.ipc-metadata-list-summary-item")

movie_list = []

for movie in movie_block:
    try:
        title = movie.find_element(By.CSS_SELECTOR, "h3.ipc-title__text").text.strip()
        duration_element = movie.find_element(By.XPATH, ".//span[contains(@class, 'dli-title-metadata-item') and (contains(text(),'h') or contains(text(),'m'))]")
        duration = duration_element.text.strip() if duration_element.text.strip() else "N/A"
        rating = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--rating").text.strip()
        voting = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--voteCount").text.strip()
    except:
        title = "N/A"
        duration = "N/A"
        rating = "N/A"
        voting = "N/A"

    movie_data = {
        "Title": title,
        "Genre": genre,
        "Duration": duration,
        "Rating": rating,
        "Voting": voting,
    }

    movie_list.append(movie_data)

# Print results
for movie in movie_list:
    print(movie)

# Close the driver
driver.quit()
# Out:
# {'Title': '1. The Unholy Trinity', 'Genre': 'Action', 'Duration': '1h 35m', 'Rating': '5.5', 'Voting': '(1.8K)'}
# {'Title': '2. Twisters', 'Genre': 'Action', 'Duration': '2h 2m', 'Rating': '6.5', 'Voting': '(178K)'}
# {'Title': '3. Gladiator II', 'Genre': 'Action', 'Duration': '2h 28m', 'Rating': '6.5', 'Voting': '(260K)'}
# {'Title': '4. Kraven the Hunter', 'Genre': 'Action', 'Duration': '2h 7m', 'Rating': '5.5', 'Voting': '(66K)'}
# {'Title': '5. Dune: Part Two', 'Genre': 'Action', 'Duration': '2h 46m', 'Rating': '8.5', 'Voting': '(649K)'}
# {'Title': '6. Deadpool & Wolverine', 'Genre': 'Action', 'Duration': '2h 8m', 'Rating': '7.5', 'Voting': '(513K)'}
# {'Title': '7. The Ministry of Ungentlemanly Warfare', 'Genre': 'Action', 'Duration': '2h 2m', 'Rating': '6.8', 'Voting': '(141K)'}
# {'Title': '8. Furiosa: A Mad Max Saga', 'Genre': 'Action', 'Duration': '2h 28m', 'Rating': '7.5', 'Voting': '(294K)'}
# {'Title': '9. William Tell', 'Genre': 'Action', 'Duration': '2h 14m', 'Rating': '5.7', 'Voting': '(3.6K)'}
# {'Title': '10. Carry-On', 'Genre': 'Action', 'Duration': '1h 59m', 'Rating': '6.5', 'Voting': '(174K)'}
# {'Title': '11. Sonic the Hedgehog 3', 'Genre': 'Action', 'Duration': '1h 50m', 'Rating': '6.9', 'Voting': '(67K)'}
# {'Title': '12. The Fall Guy', 'Genre': 'Action', 'Duration': '2h 6m', 'Rating': '6.8', 'Voting': '(229K)'}
# {'Title': '13. Civil War', 'Genre': 'Action', 'Duration': '1h 49m', 'Rating': '7.0', 'Voting': '(246K)'}
# {'Title': '14. Venom: The Last Dance', 'Genre': 'Action', 'Duration': '1h 50m', 'Rating': '6.0', 'Voting': '(133K)'}
# {'Title': '15. The Count of Monte-Cristo', 'Genre': 'Action', 'Duration': '2h 58m', 'Rating': '7.6', 'Voting': '(38K)'}
# {'Title': '16. The Beekeeper', 'Genre': 'Action', 'Duration': '1h 45m', 'Rating': '6.3', 'Voting': '(164K)'}
# {'Title': '17. Road House', 'Genre': 'Action', 'Duration': '2h 1m', 'Rating': '6.2', 'Voting': '(172K)'}
# {'Title': '18. Freaky Tales', 'Genre': 'Action', 'Duration': '1h 47m', 'Rating': '6.2', 'Voting': '(7.9K)'}
# {'Title': '19. 40 Acres', 'Genre': 'Action', 'Duration': '1h 53m', 'Rating': '7.1', 'Voting': '(818)'}
# {'Title': '20. Fight or Flight', 'Genre': 'Action', 'Duration': '1h 42m', 'Rating': '6.4', 'Voting': '(16K)'}
# {'Title': '21. Elevation', 'Genre': 'Action', 'Duration': '1h 31m', 'Rating': '5.6', 'Voting': '(25K)'}
# {'Title': '22. Rebel Ridge', 'Genre': 'Action', 'Duration': '2h 11m', 'Rating': '6.8', 'Voting': '(92K)'}
# {'Title': '23. Godzilla x Kong: The New Empire', 'Genre': 'Action', 'Duration': '1h 55m', 'Rating': '6.0', 'Voting': '(125K)'}
# {'Title': '24. Argylle', 'Genre': 'Action', 'Duration': '2h 19m', 'Rating': '5.6', 'Voting': '(95K)'}
# {'Title': '25. Abigail', 'Genre': 'Action', 'Duration': '1h 49m', 'Rating': '6.5', 'Voting': '(101K)'}
# {'Title': '26. Transformers One', 'Genre': 'Action', 'Duration': '1h 44m', 'Rating': '7.6', 'Voting': '(55K)'}
# {'Title': '27. Madame Web', 'Genre': 'Action', 'Duration': '1h 56m', 'Rating': '4.1', 'Voting': '(104K)'}
# {'Title': '28. Borderlands', 'Genre': 'Action', 'Duration': '1h 41m', 'Rating': '4.7', 'Voting': '(51K)'}
# {'Title': '29. Land of Bad', 'Genre': 'Action', 'Duration': '1h 53m', 'Rating': '6.6', 'Voting': '(54K)'}
# {'Title': '30. The Instigators', 'Genre': 'Action', 'Duration': '1h 41m', 'Rating': '6.2', 'Voting': '(39K)'}
# {'Title': '31. The Crow', 'Genre': 'Action', 'Duration': '1h 51m', 'Rating': '4.7', 'Voting': '(37K)'}
# {'Title': '32. Bad Boys: Ride or Die', 'Genre': 'Action', 'Duration': '1h 55m', 'Rating': '6.5', 'Voting': '(104K)'}
# {'Title': '33. Kingdom of the Planet of the Apes', 'Genre': 'Action', 'Duration': '2h 25m', 'Rating': '6.8', 'Voting': '(156K)'}
# {'Title': '34. Relay', 'Genre': 'Action', 'Duration': '1h 52m', 'Rating': '7.3', 'Voting': '(149)'}
# {'Title': '35. Maharaja', 'Genre': 'Action', 'Duration': '2h 21m', 'Rating': '8.4', 'Voting': '(72K)'}
# {'Title': '36. The Union', 'Genre': 'Action', 'Duration': '1h 47m', 'Rating': '5.4', 'Voting': '(55K)'}
# {'Title': '37. Damsel', 'Genre': 'Action', 'Duration': '1h 50m', 'Rating': '6.1', 'Voting': '(112K)'}
# {'Title': '38. Red One', 'Genre': 'Action', 'Duration': '2h 3m', 'Rating': '6.3', 'Voting': '(143K)'}
# {'Title': '39. Kung Fu Panda 4', 'Genre': 'Action', 'Duration': '1h 34m', 'Rating': '6.3', 'Voting': '(71K)'}
# {'Title': '40. The Killer', 'Genre': 'Action', 'Duration': '2h 6m', 'Rating': '5.7', 'Voting': '(14K)'}
# {'Title': '41. Survive', 'Genre': 'Action', 'Duration': '1h 30m', 'Rating': '4.6', 'Voting': '(3.4K)'}
# {'Title': '42. Monkey Man', 'Genre': 'Action', 'Duration': '2h 1m', 'Rating': '6.8', 'Voting': '(94K)'}
# {'Title': '43. Canary Black', 'Genre': 'Action', 'Duration': '1h 41m', 'Rating': '5.4', 'Voting': '(12K)'}
# {'Title': '44. Drive-Away Dolls', 'Genre': 'Action', 'Duration': '1h 24m', 'Rating': '5.4', 'Voting': '(25K)'}
# {'Title': '45. The Lord of the Rings: The War of the Rohirrim', 'Genre': 'Action', 'Duration': '2h 14m', 'Rating': '6.3', 'Voting': '(34K)'}
# {'Title': '46. Absolution', 'Genre': 'Action', 'Duration': '1h 52m', 'Rating': '5.2', 'Voting': '(9.2K)'}
# {'Title': '47. Homestead', 'Genre': 'Action', 'Duration': '1h 52m', 'Rating': '5.2', 'Voting': '(4.3K)'}
# {'Title': '48. Dirty Angels', 'Genre': 'Action', 'Duration': '1h 44m', 'Rating': '4.4', 'Voting': '(4.3K)'}
# {'Title': '49. Jackpot!', 'Genre': 'Action', 'Duration': '1h 46m', 'Rating': '5.8', 'Voting': '(32K)'}
# {'Title': '50. The Silent Hour', 'Genre': 'Action', 'Duration': '1h 39m', 'Rating': '6.1', 'Voting': '(8.6K)'}
# {'Title': '51. Beverly Hills Cop: Axel F', 'Genre': 'Action', 'Duration': '1h 58m', 'Rating': '6.4', 'Voting': '(83K)'}
# {'Title': '52. Kalki 2898 AD', 'Genre': 'Action', 'Duration': '3h', 'Rating': '7.0', 'Voting': '(69K)'}
# {'Title': '53. Pushpa: The Rule - Part 2', 'Genre': 'Action', 'Duration': '3h 21m', 'Rating': '6.1', 'Voting': '(59K)'}
# {'Title': "54. The Killer's Game", 'Genre': 'Action', 'Duration': '1h 44m', 'Rating': '5.8', 'Voting': '(19K)'}
# {'Title': '55. Attack on Titan the Movie: The Last Attack', 'Genre': 'Action', 'Duration': '2h 25m', 'Rating': '9.1', 'Voting': '(18K)'}
# {'Title': '56. Thelma', 'Genre': 'Action', 'Duration': '1h 38m', 'Rating': '7.0', 'Voting': '(25K)'}
# {'Title': '57. Solo Leveling: ReAwakening', 'Genre': 'Action', 'Duration': '2h 1m', 'Rating': '8.8', 'Voting': '(14K)'}
# {'Title': '58. Descendants: The Rise of Red', 'Genre': 'Action', 'Duration': '1h 31m', 'Rating': '4.7', 'Voting': '(7.4K)'}
# {'Title': '59. Blitz', 'Genre': 'Action', 'Duration': '2h', 'Rating': '6.2', 'Voting': '(17K)'}
# {'Title': '60. Hellboy: The Crooked Man', 'Genre': 'Action', 'Duration': '1h 39m', 'Rating': '4.5', 'Voting': '(15K)'}
# {'Title': '61. Arcadian', 'Genre': 'Action', 'Duration': '1h 32m', 'Rating': '5.5', 'Voting': '(25K)'}
# {'Title': '62. Brothers', 'Genre': 'Action', 'Duration': '1h 29m', 'Rating': '5.4', 'Voting': '(14K)'}
# {'Title': '63. Role Play', 'Genre': 'Action', 'Duration': '1h 40m', 'Rating': '5.5', 'Voting': '(19K)'}
# {'Title': '64. Apocalypse Z: The Beginning of the End', 'Genre': 'Action', 'Duration': '1h 57m', 'Rating': '6.1', 'Voting': '(21K)'}
# {'Title': '65. Old Guy', 'Genre': 'Action', 'Duration': '1h 34m', 'Rating': '5.2', 'Voting': '(3.4K)'}
# {'Title': '66. Uglies', 'Genre': 'Action', 'Duration': '1h 40m', 'Rating': '4.7', 'Voting': '(34K)'}
# {'Title': '67. Atlas', 'Genre': 'Action', 'Duration': '1h 58m', 'Rating': '5.6', 'Voting': '(57K)'}
# {'Title': '68. Weekend in Taipei', 'Genre': 'Action', 'Duration': '1h 40m', 'Rating': '5.7', 'Voting': '(5.5K)'}
# {'Title': '69. Rebel Moon - Part Two: The Scargiver', 'Genre': 'Action', 'Duration': '2h 2m', 'Rating': '5.3', 'Voting': '(60K)'}
# {'Title': '70. Azrael', 'Genre': 'Action', 'Duration': '1h 26m', 'Rating': '5.4', 'Voting': '(12K)'}
# {'Title': '71. Damaged', 'Genre': 'Action', 'Duration': '1h 37m', 'Rating': '4.7', 'Voting': '(7.7K)'}
# {'Title': '72. Lift', 'Genre': 'Action', 'Duration': '1h 47m', 'Rating': '5.5', 'Voting': '(50K)'}
# {'Title': '73. Under Paris', 'Genre': 'Action', 'Duration': '1h 44m', 'Rating': '5.2', 'Voting': '(37K)'}
# {'Title': '74. Mura', 'Genre': 'Action', 'Duration': '2h 9m', 'Rating': '7.2', 'Voting': '(6.5K)'}
# {'Title': '75. Watchmen: Chapter I', 'Genre': 'Action', 'Duration': '1h 23m', 'Rating': '7.1', 'Voting': '(7.1K)'}
# {'Title': '76. Dan Da Dan: First Encounter', 'Genre': 'Action', 'Duration': '1h 23m', 'Rating': '8.2', 'Voting': '(3.1K)'}
# {'Title': '77. Werewolves', 'Genre': 'Action', 'Duration': '1h 33m', 'Rating': '4.4', 'Voting': '(7.7K)'}
# {'Title': '78. The Prosecutor', 'Genre': 'Action', 'Duration': '1h 57m', 'Rating': '6.6', 'Voting': '(2.8K)'}
# {'Title': '79. Utopia', 'Genre': 'Action', 'Duration': '1h 31m', 'Rating': '3.7', 'Voting': '(467)'}
# {'Title': '80. Alien: Rubicon', 'Genre': 'Action', 'Duration': '1h 26m', 'Rating': '2.4', 'Voting': '(529)'}
# {'Title': '81. Speed 220', 'Genre': 'Action', 'Duration': '1h 54m', 'Rating': '6.4', 'Voting': '(1.3K)'}
# {'Title': '82. Amaran', 'Genre': 'Action', 'Duration': '2h 47m', 'Rating': '8.1', 'Voting': '(20K)'}
# {'Title': '83. Night Call', 'Genre': 'Action', 'Duration': '1h 37m', 'Rating': '6.7', 'Voting': '(2.6K)'}
# {'Title': '84. Life After Fighting', 'Genre': 'Action', 'Duration': '2h 6m', 'Rating': '6.4', 'Voting': '(2.2K)'}
# {'Title': '85. Justice League: Crisis on Infinite Earths - Part One', 'Genre': 'Action', 'Duration': '1h 33m', 'Rating': '6.2', 'Voting': '(8.9K)'}
# {'Title': '86. Justice League: Crisis on Infinite Earths - Part Three', 'Genre': 'Action', 'Duration': '1h 34m', 'Rating': '6.0', 'Voting': '(4.9K)'}
# {'Title': '87. Marco', 'Genre': 'Action', 'Duration': '2h 25m', 'Rating': '6.7', 'Voting': '(23K)'}
# {'Title': '88. No Way Up', 'Genre': 'Action', 'Duration': '1h 30m', 'Rating': '4.6', 'Voting': '(11K)'}
# {'Title': '89. My Spy: The Eternal City', 'Genre': 'Action', 'Duration': '1h 52m', 'Rating': '5.7', 'Voting': '(11K)'}
# {'Title': '90. Cloud', 'Genre': 'Action', 'Duration': '2h 4m', 'Rating': '6.3', 'Voting': '(1.7K)'}
# {'Title': '91. Boneyard', 'Genre': 'Action', 'Duration': '1h 36m', 'Rating': '4.1', 'Voting': '(5.3K)'}
# {'Title': '92. Devara Part 1', 'Genre': 'Action', 'Duration': '2h 56m', 'Rating': '6.0', 'Voting': '(21K)'}
# {'Title': '93. Aftermath', 'Genre': 'Action', 'Duration': '1h 37m', 'Rating': '5.2', 'Voting': '(4.5K)'}
# {'Title': '94. Cells at Work!', 'Genre': 'Action', 'Duration': '1h 49m', 'Rating': '6.7', 'Voting': '(1K)'}
# {'Title': '95. Captain Miller', 'Genre': 'Action', 'Duration': '2h 37m', 'Rating': '7.2', 'Voting': '(14K)'}
# {'Title': '96. Pani', 'Genre': 'Action', 'Duration': '2h 23m', 'Rating': '6.9', 'Voting': '(3.4K)'}
# {'Title': '97. Baby John', 'Genre': 'Action', 'Duration': '2h 39m', 'Rating': '5.0', 'Voting': '(18K)'}
# {'Title': '98. Take Cover', 'Genre': 'Action', 'Duration': '1h 30m', 'Rating': '5.1', 'Voting': '(2.9K)'}
# {'Title': '99. Ultraman: Rising', 'Genre': 'Action', 'Duration': '1h 57m', 'Rating': '6.9', 'Voting': '(6.8K)'}
# {'Title': '100. Yodha', 'Genre': 'Action', 'Duration': '2h 10m', 'Rating': '5.7', 'Voting': '(9K)'}
# {'Title': '101. Chandu Champion', 'Genre': 'Action', 'Duration': '2h 22m', 'Rating': '7.8', 'Voting': '(35K)'}
# {'Title': '102. Fighter', 'Genre': 'Action', 'Duration': '2h 46m', 'Rating': '6.2', 'Voting': '(53K)'}
# {'Title': '103. Hitpig', 'Genre': 'Action', 'Duration': '1h 26m', 'Rating': '5.2', 'Voting': '(1.1K)'}
# {'Title': '104. The Hangman', 'Genre': 'Action', 'Duration': '1h 32m', 'Rating': '3.3', 'Voting': '(1.1K)'}
# {'Title': '105. Trigger Warning', 'Genre': 'Action', 'Duration': '1h 46m', 'Rating': '4.6', 'Voting': '(20K)'}
# {'Title': '106. 11 Rebels', 'Genre': 'Action', 'Duration': '2h 35m', 'Rating': '6.3', 'Voting': '(786)'}
# {'Title': '107. River of Blood', 'Genre': 'Action', 'Duration': '1h 26m', 'Rating': '5.0', 'Voting': '(2K)'}
# {'Title': '108. Aavesham', 'Genre': 'Action', 'Duration': '2h 35m', 'Rating': '7.8', 'Voting': '(30K)'}
# {'Title': '109. Karma', 'Genre': 'Action', 'Duration': '2h 47m', 'Rating': '7.8', 'Voting': '(1.5K)'}
# {'Title': '110. Wynonna Earp: Vengeance', 'Genre': 'Action', 'Duration': '1h 36m', 'Rating': '5.5', 'Voting': '(1.7K)'}
# {'Title': '111. In the Fire of War', 'Genre': 'Action', 'Duration': '1h 55m', 'Rating': '6.8', 'Voting': '(248)'}
# {'Title': '112. Twilight of the Warriors: Walled In', 'Genre': 'Action', 'Duration': '2h 6m', 'Rating': '6.9', 'Voting': '(11K)'}
# {'Title': '113. Drive Back', 'Genre': 'Action', 'Duration': '1h 34m', 'Rating': '4.5', 'Voting': '(678)'}
# {'Title': '114. Demon Slayer: Kimetsu No Yaiba - To the Hashira Training', 'Genre': 'Action', 'Duration': '1h 44m', 'Rating': '7.2', 'Voting': '(8.9K)'}
# {'Title': '115. The Greatest of All Time', 'Genre': 'Action', 'Duration': '3h 3m', 'Rating': '5.7', 'Voting': '(24K)'}
# {'Title': '116. Officer Black Belt', 'Genre': 'Action', 'Duration': '1h 48m', 'Rating': '6.9', 'Voting': '(8.9K)'}
# {'Title': '117. Red Right Hand', 'Genre': 'Action', 'Duration': '1h 51m', 'Rating': '5.5', 'Voting': '(6.1K)'}
# {'Title': '118. Watchmen: Chapter II', 'Genre': 'Action', 'Duration': '1h 30m', 'Rating': '7.1', 'Voting': '(3.6K)'}
# {'Title': '119. I, the Executioner', 'Genre': 'Action', 'Duration': '1h 58m', 'Rating': '6.3', 'Voting': '(2.1K)'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Action', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}

# %%
#common csv converting code

import pandas as pd

df=pd.DataFrame(movie_list)
# Cleaning Steps:
# 1. Remove leading numbers from "Title"
df["Title"] = df["Title"].str.replace(r"^\d+\.\s*", "", regex=True)

# 2. Remove parentheses from "Voting"
df["Voting"] = df["Voting"].str.replace(r"[()]", "", regex=True)

# 3. Reset index to start from 1
df.index = df.index + 1

df.to_csv(r"D:\Nirosha\GUVI\Project\action.csv", index=False, encoding="utf-8")
print(r"CSV file - Action Movies saved successfully")
# Out:
# CSV file - Action Movies saved successfully

# %%
# Horror movies 

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

# Initialize WebDriver
driver = webdriver.Chrome()
driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=horror")

time.sleep(5)  # Waiting for the page to load

genre = "Horror"

# Scroll Until No More New Data Loads
scroll = True
movies_per_page = 50  # Assuming each load gives 50 movies
total_movies = 500
current_movies = 0

while scroll and current_movies < total_movies:
    old_page_source = driver.page_source  # Save old page source
    
    # Scroll down to load more data
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Allow time for new data to load
    
    new_page_source = driver.page_source  # Save new page source

    if new_page_source == old_page_source:
        try:
            # Locate and click the "See More" button if present
            see_more_button = driver.find_element(By.XPATH, "//span[contains(@class, 'ipc-see-more')]")
            ActionChains(driver).move_to_element(see_more_button).click().perform()
            time.sleep(3)  # Wait for new content to load
        except Exception:
            scroll = False  # Stop scrolling if button isn't found
    else:
        current_movies += movies_per_page  # Increment count

# Extract movie containers
movie_block = driver.find_elements(By.CSS_SELECTOR, "li.ipc-metadata-list-summary-item")

movie_list = []

for movie in movie_block:
    try:
        title = movie.find_element(By.CSS_SELECTOR, "h3.ipc-title__text").text.strip()
        duration_element = movie.find_element(By.XPATH, ".//span[contains(@class, 'dli-title-metadata-item') and (contains(text(),'h') or contains(text(),'m'))]")
        duration = duration_element.text.strip() if duration_element.text.strip() else "N/A"
        rating = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--rating").text.strip()
        voting = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--voteCount").text.strip()
    except:
        title = "N/A"
        duration = "N/A"
        rating = "N/A"
        voting = "N/A"

    movie_data = {
        "Title": title,
        "Genre": genre,
        "Duration": duration,
        "Rating": rating,
        "Voting": voting,
    }
    movie_list.append(movie_data)

# Print results
for movie in movie_list:
    print(movie)

# Close the driver
driver.quit()
# Out:
# {'Title': '1. Nosferatu', 'Genre': 'Horror', 'Duration': '2h 12m', 'Rating': '7.2', 'Voting': '(217K)'}
# {'Title': '2. Heretic', 'Genre': 'Horror', 'Duration': '1h 51m', 'Rating': '7.0', 'Voting': '(170K)'}
# {'Title': '3. The Substance', 'Genre': 'Horror', 'Duration': '2h 21m', 'Rating': '7.2', 'Voting': '(324K)'}
# {'Title': '4. Push', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '4.7', 'Voting': '(364)'}
# {'Title': '5. Longlegs', 'Genre': 'Horror', 'Duration': '1h 41m', 'Rating': '6.6', 'Voting': '(196K)'}
# {'Title': '6. Speak No Evil', 'Genre': 'Horror', 'Duration': '1h 50m', 'Rating': '6.8', 'Voting': '(113K)'}
# {'Title': '7. Alien: Romulus', 'Genre': 'Horror', 'Duration': '1h 59m', 'Rating': '7.1', 'Voting': '(256K)'}
# {'Title': '8. Presence', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '6.1', 'Voting': '(31K)'}
# {'Title': '9. Beetlejuice Beetlejuice', 'Genre': 'Horror', 'Duration': '1h 45m', 'Rating': '6.6', 'Voting': '(156K)'}
# {'Title': '10. Smile 2', 'Genre': 'Horror', 'Duration': '2h 7m', 'Rating': '6.7', 'Voting': '(117K)'}
# {'Title': '11. The Shrouds', 'Genre': 'Horror', 'Duration': '2h', 'Rating': '5.8', 'Voting': '(4.8K)'}
# {'Title': '12. Trap', 'Genre': 'Horror', 'Duration': '1h 45m', 'Rating': '5.8', 'Voting': '(146K)'}
# {'Title': '13. MaXXXine', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '6.2', 'Voting': '(75K)'}
# {'Title': "14. Salem's Lot", 'Genre': 'Horror', 'Duration': '1h 54m', 'Rating': '5.6', 'Voting': '(36K)'}
# {'Title': '15. The Rule of Jenny Pen', 'Genre': 'Horror', 'Duration': '1h 44m', 'Rating': '6.2', 'Voting': '(6.7K)'}
# {'Title': '16. 1978', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '5.0', 'Voting': '(789)'}
# {'Title': '17. Abigail', 'Genre': 'Horror', 'Duration': '1h 49m', 'Rating': '6.5', 'Voting': '(101K)'}
# {'Title': '18. Oddity', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '6.7', 'Voting': '(47K)'}
# {'Title': '19. A Quiet Place: Day One', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '6.3', 'Voting': '(157K)'}
# {'Title': '20. Kinds of Kindness', 'Genre': 'Horror', 'Duration': '2h 44m', 'Rating': '6.5', 'Voting': '(62K)'}
# {'Title': '21. Terrifier 3', 'Genre': 'Horror', 'Duration': '2h 5m', 'Rating': '6.3', 'Voting': '(52K)'}
# {'Title': '22. Else', 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '5.6', 'Voting': '(425)'}
# {'Title': '23. The Crow', 'Genre': 'Horror', 'Duration': '1h 51m', 'Rating': '4.7', 'Voting': '(37K)'}
# {'Title': '24. Saint Clare', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '5.1', 'Voting': '(145)'}
# {'Title': "25. Don't Move", 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '5.8', 'Voting': '(41K)'}
# {'Title': '26. Tarot', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '4.8', 'Voting': '(33K)'}
# {'Title': '27. The Watchers', 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '5.7', 'Voting': '(59K)'}
# {'Title': '28. Survive', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '4.6', 'Voting': '(3.4K)'}
# {'Title': '29. Immaculate', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '5.8', 'Voting': '(55K)'}
# {'Title': '30. Witchboard', 'Genre': 'Horror', 'Duration': '1h 52m', 'Rating': '7.3', 'Voting': '(124)'}
# {'Title': "31. Please Don't Feed the Children", 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '4.8', 'Voting': '(563)'}
# {'Title': '32. Cuckoo', 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '5.7', 'Voting': '(30K)'}
# {'Title': '33. Nightbitch', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '5.5', 'Voting': '(21K)'}
# {'Title': '34. Bagman', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '4.7', 'Voting': '(6.6K)'}
# {'Title': '35. MadS', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '6.4', 'Voting': '(9.2K)'}
# {'Title': "36. I Don't Understand You", 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '5.4', 'Voting': '(939)'}
# {'Title': '37. The Damned', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '5.7', 'Voting': '(5.9K)'}
# {'Title': '38. Never Let Go', 'Genre': 'Horror', 'Duration': '1h 41m', 'Rating': '5.4', 'Voting': '(17K)'}
# {'Title': '39. The Deliverance', 'Genre': 'Horror', 'Duration': '1h 52m', 'Rating': '5.1', 'Voting': '(23K)'}
# {'Title': '40. Time Cut', 'Genre': 'Horror', 'Duration': '1h 31m', 'Rating': '5.0', 'Voting': '(20K)'}
# {'Title': '41. The First Omen', 'Genre': 'Horror', 'Duration': '1h 59m', 'Rating': '6.5', 'Voting': '(66K)'}
# {'Title': '42. Y2K', 'Genre': 'Horror', 'Duration': '1h 31m', 'Rating': '4.8', 'Voting': '(17K)'}
# {'Title': '43. Exhuma', 'Genre': 'Horror', 'Duration': '2h 14m', 'Rating': '6.9', 'Voting': '(25K)'}
# {'Title': '44. Monster Island', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '6.1', 'Voting': '(109)'}
# {'Title': '45. Hellboy: The Crooked Man', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '4.5', 'Voting': '(15K)'}
# {'Title': '46. Apartment 7A', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '5.9', 'Voting': '(17K)'}
# {'Title': '47. In a Violent Nature', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '5.6', 'Voting': '(28K)'}
# {'Title': '48. Arcadian', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '5.5', 'Voting': '(25K)'}
# {'Title': '49. The Strangers: Chapter 1', 'Genre': 'Horror', 'Duration': '1h 31m', 'Rating': '4.6', 'Voting': '(23K)'}
# {'Title': '50. Apocalypse Z: The Beginning of the End', 'Genre': 'Horror', 'Duration': '1h 57m', 'Rating': '6.1', 'Voting': '(21K)'}
# {'Title': '51. Get Away', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '5.3', 'Voting': '(7.8K)'}
# {'Title': '52. Dead Mail', 'Genre': 'Horror', 'Duration': '1h 46m', 'Rating': '6.0', 'Voting': '(2.3K)'}
# {'Title': '53. Frewaka', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '6.1', 'Voting': '(1.7K)'}
# {'Title': '54. The Platform 2', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '4.9', 'Voting': '(42K)'}
# {'Title': '55. Chime', 'Genre': 'Horror', 'Duration': '45m', 'Rating': '6.4', 'Voting': '(2.8K)'}
# {'Title': '56. Azrael', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '5.4', 'Voting': '(12K)'}
# {'Title': '57. Ick', 'Genre': 'Horror', 'Duration': '1h 27m', 'Rating': '5.5', 'Voting': '(228)'}
# {'Title': '58. Lisa Frankenstein', 'Genre': 'Horror', 'Duration': '1h 41m', 'Rating': '6.1', 'Voting': '(29K)'}
# {'Title': '59. Under Paris', 'Genre': 'Horror', 'Duration': '1h 44m', 'Rating': '5.2', 'Voting': '(37K)'}
# {'Title': '60. Night Swim', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '4.7', 'Voting': '(28K)'}
# {'Title': '61. Your Monster', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '6.4', 'Voting': '(6.5K)'}
# {'Title': '62. Went Up the Hill', 'Genre': 'Horror', 'Duration': '1h 40m', 'Rating': '6.6', 'Voting': '(94)'}
# {'Title': '63. Missing Child Videotape', 'Genre': 'Horror', 'Duration': '1h 44m', 'Rating': '5.5', 'Voting': '(192)'}
# {'Title': '64. Strange Harvest', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '6.7', 'Voting': '(82)'}
# {'Title': '65. The Twin', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '7.9', 'Voting': '(88)'}
# {'Title': '66. The Balconettes', 'Genre': 'Horror', 'Duration': '1h 44m', 'Rating': '5.9', 'Voting': '(1.5K)'}
# {'Title': '67. Dan Da Dan: First Encounter', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '8.2', 'Voting': '(3.1K)'}
# {'Title': '68. Werewolves', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '4.4', 'Voting': '(7.7K)'}
# {'Title': "69. The Devil's Bath", 'Genre': 'Horror', 'Duration': '2h 1m', 'Rating': '6.6', 'Voting': '(6.9K)'}
# {'Title': '70. Sting', 'Genre': 'Horror', 'Duration': '1h 31m', 'Rating': '5.7', 'Voting': '(17K)'}
# {'Title': '71. Outbreak', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '4.4', 'Voting': '(1.3K)'}
# {'Title': '72. A Sacrifice', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '5.0', 'Voting': '(5.8K)'}
# {'Title': '73. A Desert', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '5.6', 'Voting': '(520)'}
# {'Title': '74. Winnie-the-Pooh: Blood and Honey 2', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '4.6', 'Voting': '(12K)'}
# {'Title': '75. V/H/S/Beyond', 'Genre': 'Horror', 'Duration': '1h 54m', 'Rating': '5.8', 'Voting': '(10K)'}
# {'Title': '76. The Inheritance', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '4.7', 'Voting': '(3.1K)'}
# {'Title': '77. Afraid', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '5.2', 'Voting': '(15K)'}
# {'Title': '78. Rumours', 'Genre': 'Horror', 'Duration': '1h 44m', 'Rating': '4.9', 'Voting': '(5.3K)'}
# {'Title': '79. The Master and Margarita', 'Genre': 'Horror', 'Duration': '2h 36m', 'Rating': '7.2', 'Voting': '(5.1K)'}
# {'Title': '80. Lembayung', 'Genre': 'Horror', 'Duration': '2h 3m', 'Rating': '5.9', 'Voting': '(791)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '82. The Corpse Washer', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '6.1', 'Voting': '(1.3K)'}
# {'Title': '83. Stream', 'Genre': 'Horror', 'Duration': '2h 3m', 'Rating': '5.9', 'Voting': '(9.5K)'}
# {'Title': '84. Die Alone', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '5.8', 'Voting': '(4.1K)'}
# {'Title': '85. Cloud', 'Genre': 'Horror', 'Duration': '2h 4m', 'Rating': '6.3', 'Voting': '(1.7K)'}
# {'Title': '86. The Exorcism', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '4.2', 'Voting': '(12K)'}
# {'Title': "87. Daddy's Head", 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '5.6', 'Voting': '(5.6K)'}
# {'Title': '88. Succubus', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '4.6', 'Voting': '(1.4K)'}
# {'Title': '89. Something in the Water', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '4.1', 'Voting': '(5.2K)'}
# {'Title': '90. Lowlifes', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '6.2', 'Voting': '(6.8K)'}
# {'Title': '91. Grafted', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '5.6', 'Voting': '(2.7K)'}
# {'Title': '92. The Radleys', 'Genre': 'Horror', 'Duration': '1h 55m', 'Rating': '5.0', 'Voting': '(3K)'}
# {'Title': '93. Jimmy and Stiggs', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '6.3', 'Voting': '(94)'}
# {'Title': '94. Dead Talents Society', 'Genre': 'Horror', 'Duration': '1h 51m', 'Rating': '7.0', 'Voting': '(2.7K)'}
# {'Title': '95. Night of the Zoopocalypse', 'Genre': 'Horror', 'Duration': '1h 31m', 'Rating': '6.0', 'Voting': '(1K)'}
# {'Title': '96. The Beast Within', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '4.3', 'Voting': '(5.4K)'}
# {'Title': '97. Blackwater Lane', 'Genre': 'Horror', 'Duration': '1h 48m', 'Rating': '4.6', 'Voting': '(2.4K)'}
# {'Title': '98. Ghost Train', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '4.5', 'Voting': '(21)'}
# {'Title': '99. Dirty Boy', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '7.5', 'Voting': '(40)'}
# {'Title': '100. The Painted', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '4.8', 'Voting': '(1.2K)'}
# {'Title': '101. Imaginary', 'Genre': 'Horror', 'Duration': '1h 44m', 'Rating': '4.7', 'Voting': '(18K)'}
# {'Title': '102. Bloody Axe Wound', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '5.0', 'Voting': '(1.1K)'}
# {'Title': '103. Hold Your Breath', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '5.3', 'Voting': '(9K)'}
# {'Title': '104. Sumala', 'Genre': 'Horror', 'Duration': '1h 52m', 'Rating': '5.8', 'Voting': '(1.2K)'}
# {'Title': '105. The Severed Sun', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '4.9', 'Voting': '(401)'}
# {'Title': '106. The Hangman', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '3.3', 'Voting': '(1.1K)'}
# {'Title': '107. Here After', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '4.2', 'Voting': '(1.8K)'}
# {'Title': '108. Outside', 'Genre': 'Horror', 'Duration': '2h 22m', 'Rating': '5.1', 'Voting': '(4.9K)'}
# {'Title': '109. River of Blood', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '5.0', 'Voting': '(2K)'}
# {'Title': '110. Stree 2: Sarkate Ka Aatank', 'Genre': 'Horror', 'Duration': '2h 27m', 'Rating': '6.9', 'Voting': '(43K)'}
# {'Title': '111. Wynonna Earp: Vengeance', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '5.5', 'Voting': '(1.7K)'}
# {'Title': '112. Drive Back', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '4.5', 'Voting': '(678)'}
# {'Title': '113. Humane', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '5.5', 'Voting': '(7.7K)'}
# {'Title': '114. Noise', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '6.2', 'Voting': '(119)'}
# {'Title': '115. Bramayugam', 'Genre': 'Horror', 'Duration': '2h 19m', 'Rating': '7.8', 'Voting': '(15K)'}
# {'Title': '116. The Wailing', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '6.1', 'Voting': '(1.8K)'}
# {'Title': '117. Pins & Needles', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '6.5', 'Voting': '(32)'}
# {'Title': '118. Hotspring Sharkattack', 'Genre': 'Horror', 'Duration': '1h 10m', 'Rating': '6.1', 'Voting': '(66)'}
# {'Title': '119. Shelby Oaks', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '5.8', 'Voting': '(263)'}
# {'Title': '120. The Last Breath', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '4.7', 'Voting': '(2.6K)'}
# {'Title': '121. Parvulos', 'Genre': 'Horror', 'Duration': '1h 59m', 'Rating': '6.6', 'Voting': '(406)'}
# {'Title': '122. The Front Room', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '4.6', 'Voting': '(5.8K)'}
# {'Title': '123. Beezel', 'Genre': 'Horror', 'Duration': '1h 21m', 'Rating': '4.9', 'Voting': '(1.6K)'}
# {'Title': "124. The Devil's Disciples", 'Genre': 'Horror', 'Duration': '1h 22m', 'Rating': '8.4', 'Voting': '(47)'}
# {'Title': '125. Ghost Killer', 'Genre': 'Horror', 'Duration': '1h 45m', 'Rating': '6.7', 'Voting': '(115)'}
# {'Title': '126. Shaitaan', 'Genre': 'Horror', 'Duration': '2h 12m', 'Rating': '6.5', 'Voting': '(55K)'}
# {'Title': '127. The Mouse Trap', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '2.4', 'Voting': '(3.6K)'}
# {'Title': '128. The Banished', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '5.4', 'Voting': '(34)'}
# {'Title': '129. Grave Torture', 'Genre': 'Horror', 'Duration': '1h 57m', 'Rating': '6.2', 'Voting': '(3.1K)'}
# {'Title': '130. Pechi', 'Genre': 'Horror', 'Duration': '1h 50m', 'Rating': '5.5', 'Voting': '(1.5K)'}
# {'Title': '131. Bleeding', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '4.3', 'Voting': '(370)'}
# {'Title': '132. Pedro Páramo', 'Genre': 'Horror', 'Duration': '2h 10m', 'Rating': '6.3', 'Voting': '(3.2K)'}
# {'Title': "133. Death's Sonata", 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '8.4', 'Voting': '(510)'}
# {'Title': '134. Spiders on a Plane', 'Genre': 'Horror', 'Duration': '1h 18m', 'Rating': '3.9', 'Voting': '(472)'}
# {'Title': '135. Kryptic', 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '4.0', 'Voting': '(648)'}
# {'Title': '136. #MissingCouple', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '5.3', 'Voting': '(764)'}
# {'Title': '137. The Soul Eater', 'Genre': 'Horror', 'Duration': '1h 48m', 'Rating': '5.8', 'Voting': '(3.1K)'}
# {'Title': '138. Things Will Be Different', 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '5.2', 'Voting': '(2.9K)'}
# {'Title': '139. We Bury the Dead', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '6.9', 'Voting': '(124)'}
# {'Title': '140. Handling the Undead', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '5.3', 'Voting': '(4.6K)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '142. Dark Match', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '5.4', 'Voting': '(1.2K)'}
# {'Title': '143. Black', 'Genre': 'Horror', 'Duration': '1h 55m', 'Rating': '7.1', 'Voting': '(2.9K)'}
# {'Title': '144. Queen of Bones', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '4.7', 'Voting': '(289)'}
# {'Title': '145. Mr. Crocket', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '5.4', 'Voting': '(4.9K)'}
# {'Title': '146. Handsome Guys', 'Genre': 'Horror', 'Duration': '1h 41m', 'Rating': '6.5', 'Voting': '(990)'}
# {'Title': '147. Year 10', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '5.4', 'Voting': '(2K)'}
# {'Title': '148. Bloodline Killer', 'Genre': 'Horror', 'Duration': '1h 45m', 'Rating': '4.2', 'Voting': '(5.2K)'}
# {'Title': '149. Munkar', 'Genre': 'Horror', 'Duration': '1h 27m', 'Rating': '5.2', 'Voting': '(566)'}
# {'Title': '150. Room Service', 'Genre': 'Horror', 'Duration': '47m', 'Rating': '3.9', 'Voting': '(327)'}
# {'Title': '151. Mononoke the Movie: The Phantom in the Rain', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '6.7', 'Voting': '(1.4K)'}
# {'Title': '152. Bogieville', 'Genre': 'Horror', 'Duration': '1h 48m', 'Rating': '4.0', 'Voting': '(656)'}
# {'Title': '153. Consumed', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '3.7', 'Voting': '(659)'}
# {'Title': '154. Turno Nocturno', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '5.3', 'Voting': '(719)'}
# {'Title': '155. Bring on the Damned!', 'Genre': 'Horror', 'Duration': '1h 54m', 'Rating': '5.0', 'Voting': '(49)'}
# {'Title': '156. Crescent City', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '3.9', 'Voting': '(1.5K)'}
# {'Title': '157. Koston enkeli', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '3.9', 'Voting': '(59)'}
# {'Title': '158. Little Bites', 'Genre': 'Horror', 'Duration': '1h 45m', 'Rating': '4.7', 'Voting': '(1.4K)'}
# {'Title': '159. Life of Belle', 'Genre': 'Horror', 'Duration': '1h 13m', 'Rating': '5.0', 'Voting': '(704)'}
# {'Title': '160. Munjya', 'Genre': 'Horror', 'Duration': '2h 3m', 'Rating': '6.3', 'Voting': '(26K)'}
# {'Title': '161. The Lost Daughter', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '5.7', 'Voting': '(329)'}
# {'Title': '162. Iconic', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '5.2', 'Voting': '(451)'}
# {'Title': '163. The Dead Thing', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '4.7', 'Voting': '(1K)'}
# {'Title': '164. Murder Mubarak', 'Genre': 'Horror', 'Duration': '2h 20m', 'Rating': '5.8', 'Voting': '(51K)'}
# {'Title': '165. Behave', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '2.8', 'Voting': '(217)'}
# {'Title': '166. Desert Road', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '6.8', 'Voting': '(168)'}
# {'Title': '167. Test Screening', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '6.9', 'Voting': '(68)'}
# {'Title': '168. Terminator: Skynet Rising', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '6.6', 'Voting': '(286)'}
# {'Title': '169. Bhool Bhulaiyaa 3', 'Genre': 'Horror', 'Duration': '2h 38m', 'Rating': '4.6', 'Voting': '(78K)'}
# {'Title': '170. Invasive', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '5.6', 'Voting': '(809)'}
# {'Title': '171. The Beldham', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '7.0', 'Voting': '(49)'}
# {'Title': '172. Devon', 'Genre': 'Horror', 'Duration': '1h 12m', 'Rating': '2.6', 'Voting': '(325)'}
# {'Title': '173. Exorcism Chronicles: The Beginning', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '6.4', 'Voting': '(136)'}
# {'Title': '174. Drained', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '4.5', 'Voting': '(333)'}
# {'Title': '175. Death Whisperer 2', 'Genre': 'Horror', 'Duration': '1h 50m', 'Rating': '6.3', 'Voting': '(1.6K)'}
# {'Title': '176. Hunting Matthew Nichols', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '8.8', 'Voting': '(52)'}
# {'Title': '177. Black Cab', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '4.1', 'Voting': '(1.9K)'}
# {'Title': '178. Swap', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '2.9', 'Voting': '(383)'}
# {'Title': '179. Up the Catalogue', 'Genre': 'Horror', 'Duration': '1h 12m', 'Rating': '8.1', 'Voting': '(10)'}
# {'Title': '180. Shell', 'Genre': 'Horror', 'Duration': '1h 40m', 'Rating': '6.8', 'Voting': '(79)'}
# {'Title': '181. What Happened to Suzy', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '6.4', 'Voting': '(89)'}
# {'Title': '182. The Curse of the Necklace', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '4.4', 'Voting': '(1.4K)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '184. Out Come the Wolves', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '4.7', 'Voting': '(1.8K)'}
# {'Title': '185. Spin the Bottle', 'Genre': 'Horror', 'Duration': '2h 4m', 'Rating': '3.5', 'Voting': '(1.1K)'}
# {'Title': '186. Carved', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '4.4', 'Voting': '(2.9K)'}
# {'Title': '187. The Killgrin', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '6.1', 'Voting': '(85)'}
# {'Title': '188. Lopaliki Ra Chepta', 'Genre': 'Horror', 'Duration': '1h 52m', 'Rating': '8.1', 'Voting': '(1.5K)'}
# {'Title': '189. Seeds', 'Genre': 'Horror', 'Duration': '1h 22m', 'Rating': '4.9', 'Voting': '(240)'}
# {'Title': '190. The Haunted Apartment: Miss K', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '5.6', 'Voting': '(508)'}
# {'Title': '191. Kalinga', 'Genre': 'Horror', 'Duration': '1h 56m', 'Rating': '6.6', 'Voting': '(9.5K)'}
# {'Title': '192. Heresy', 'Genre': 'Horror', 'Duration': '1h 1m', 'Rating': '6.9', 'Voting': '(319)'}
# {'Title': '193. Destroy All Neighbors', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '5.3', 'Voting': '(2.1K)'}
# {'Title': '194. Goldilocks and the Three Bears: Death and Porridge', 'Genre': 'Horror', 'Duration': '1h 22m', 'Rating': '2.2', 'Voting': '(2K)'}
# {'Title': '195. The Ceremony Is About to Begin', 'Genre': 'Horror', 'Duration': '1h 10m', 'Rating': '4.4', 'Voting': '(837)'}
# {'Title': '196. Demonte Colony 2', 'Genre': 'Horror', 'Duration': '2h 24m', 'Rating': '6.6', 'Voting': '(4.6K)'}
# {'Title': '197. The Containment', 'Genre': 'Horror', 'Duration': '1h 22m', 'Rating': '4.7', 'Voting': '(73)'}
# {'Title': '198. Chain Reactions', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '7.1', 'Voting': '(116)'}
# {'Title': '199. The Ghost', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '6.3', 'Voting': '(130)'}
# {'Title': '200. Campton Manor', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '3.4', 'Voting': '(245)'}
# {'Title': "201. Cinderella's Curse", 'Genre': 'Horror', 'Duration': '1h 22m', 'Rating': '3.4', 'Voting': '(1.4K)'}
# {'Title': '202. Broken Bird', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '5.8', 'Voting': '(129)'}
# {'Title': '203. Frankie Freako', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '5.5', 'Voting': '(1.4K)'}
# {'Title': '204. House of Spoils', 'Genre': 'Horror', 'Duration': '1h 41m', 'Rating': '5.0', 'Voting': '(4K)'}
# {'Title': '205. Milk & Serial', 'Genre': 'Horror', 'Duration': '1h 2m', 'Rating': '6.6', 'Voting': '(2.7K)'}
# {'Title': "206. You Can't Run Forever", 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '4.5', 'Voting': '(4.5K)'}
# {'Title': '207. Love Me Dead', 'Genre': 'Horror', 'Duration': '1h 27m', 'Rating': '6.8', 'Voting': '(44)'}
# {'Title': '208. Street Trash', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '4.5', 'Voting': '(965)'}
# {'Title': '209. Barda', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '4.6', 'Voting': '(692)'}
# {'Title': '210. Crackcoon', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '3.6', 'Voting': '(458)'}
# {'Title': '211. Sunrise', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '3.9', 'Voting': '(1.2K)'}
# {'Title': '212. #AMFAD: All My Friends Are Dead', 'Genre': 'Horror', 'Duration': '1h 31m', 'Rating': '4.5', 'Voting': '(1.3K)'}
# {'Title': '213. Slay', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '6.5', 'Voting': '(1.2K)'}
# {'Title': '214. Krazy House', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '4.8', 'Voting': '(1.5K)'}
# {'Title': '215. The Witch: Revenge', 'Genre': 'Horror', 'Duration': '1h 40m', 'Rating': '5.3', 'Voting': '(889)'}
# {'Title': '216. Operation Laila', 'Genre': 'Horror', 'Duration': '2h 3m', 'Rating': '5.5', 'Voting': '(56)'}
# {'Title': '217. Do Not Enter', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '5.3', 'Voting': '(673)'}
# {'Title': '218. Devils Stay', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '4.8', 'Voting': '(355)'}
# {'Title': "219. Dr. Sander's Sleep Cure", 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '6.4', 'Voting': '(1.2K)'}
# {'Title': '220. Operation Undead', 'Genre': 'Horror', 'Duration': '1h 50m', 'Rating': '4.7', 'Voting': '(450)'}
# {'Title': '221. Monster on a Plane', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '4.6', 'Voting': '(2.4K)'}
# {'Title': '222. The Matriarch', 'Genre': 'Horror', 'Duration': '1h 22m', 'Rating': '6.5', 'Voting': '(29)'}
# {'Title': '223. Peripheral', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '9.4', 'Voting': '(44)'}
# {'Title': '224. Una ballena', 'Genre': 'Horror', 'Duration': '1h 48m', 'Rating': '5.6', 'Voting': '(188)'}
# {'Title': '225. Hauntology', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '3.7', 'Voting': '(374)'}
# {'Title': '226. Jurassic Triangle', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '2.4', 'Voting': '(291)'}
# {'Title': '227. 404 Run Run', 'Genre': 'Horror', 'Duration': '1h 44m', 'Rating': '5.7', 'Voting': '(507)'}
# {'Title': '228. Horror in the High Desert 3: Firewatch', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '5.4', 'Voting': '(777)'}
# {'Title': '229. The Gesuidouz', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '6.7', 'Voting': '(100)'}
# {'Title': '230. Haunt Season', 'Genre': 'Horror', 'Duration': '1h 21m', 'Rating': '4.9', 'Voting': '(907)'}
# {'Title': '231. Rita', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '5.7', 'Voting': '(301)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '233. Continente', 'Genre': 'Horror', 'Duration': '1h 55m', 'Rating': '5.1', 'Voting': '(98)'}
# {'Title': '234. A Stranger in the Woods', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '4.8', 'Voting': '(710)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': "236. Hemet, or the Landlady Don't Drink Tea", 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '4.3', 'Voting': '(96)'}
# {'Title': '237. Air Fryer Slaughter', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '6.3', 'Voting': '(569)'}
# {'Title': '238. Oculus', 'Genre': 'Horror', 'Duration': '1h 53m', 'Rating': '6.0', 'Voting': '(15)'}
# {'Title': '239. Dead Whisper', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '3.8', 'Voting': '(566)'}
# {'Title': '240. Séance', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '8.0', 'Voting': '(27)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '242. The Vampire Next Door', 'Genre': 'Horror', 'Duration': '1h 50m', 'Rating': '4.6', 'Voting': '(807)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '244. Anaconda', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '4.9', 'Voting': '(682)'}
# {'Title': "245. I'll Play Mother", 'Genre': 'Horror', 'Duration': '1h 48m', 'Rating': '5.1', 'Voting': '(111)'}
# {'Title': '246. Conjuring the Cult', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '4.3', 'Voting': '(942)'}
# {'Title': '247. Succubus', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '3.5', 'Voting': '(902)'}
# {'Title': '248. Saint Catherine', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '3.5', 'Voting': '(264)'}
# {'Title': '249. Ghost Game', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '3.4', 'Voting': '(382)'}
# {'Title': '250. Latency', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '4.2', 'Voting': '(3K)'}
# {'Title': '251. Rippy', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '4.2', 'Voting': '(1K)'}
# {'Title': '252. The Bunker', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '4.3', 'Voting': '(367)'}
# {'Title': '253. Hell Hole', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '4.4', 'Voting': '(1.4K)'}
# {'Title': '254. Blood Star', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '6.3', 'Voting': '(6.2K)'}
# {'Title': '255. Gacy: Serial Killer Next Door', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '3.3', 'Voting': '(487)'}
# {'Title': '256. Heretics', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '3.8', 'Voting': '(109)'}
# {'Title': '257. X Files', 'Genre': 'Horror', 'Duration': '1h 14m', 'Rating': '2.3', 'Voting': '(73)'}
# {'Title': '258. Fear Cabin: The Last Weekend of Summer', 'Genre': 'Horror', 'Duration': '1h 17m', 'Rating': '3.5', 'Voting': '(19)'}
# {'Title': '259. The Moogai', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '5.4', 'Voting': '(421)'}
# {'Title': '260. Scurry', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '7.6', 'Voting': '(26)'}
# {'Title': '261. Mummy Shark', 'Genre': 'Horror', 'Duration': '1h 6m', 'Rating': '1.9', 'Voting': '(211)'}
# {'Title': '262. Monster Mash', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '3.5', 'Voting': '(457)'}
# {'Title': '263. The Little Mermaid', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '3.5', 'Voting': '(218)'}
# {'Title': '264. Dancing Village: The Curse Begins', 'Genre': 'Horror', 'Duration': '2h 2m', 'Rating': '5.7', 'Voting': '(4.3K)'}
# {'Title': '265. Bureau 749', 'Genre': 'Horror', 'Duration': '2h 3m', 'Rating': '3.9', 'Voting': '(588)'}
# {'Title': '266. Mother Father Sister Brother Frank', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '5.8', 'Voting': '(308)'}
# {'Title': '267. Tantra', 'Genre': 'Horror', 'Duration': '2h 16m', 'Rating': '4.9', 'Voting': '(2.4K)'}
# {'Title': '268. DarkGame', 'Genre': 'Horror', 'Duration': '1h 40m', 'Rating': '4.6', 'Voting': '(2.9K)'}
# {'Title': '269. Bystanders', 'Genre': 'Horror', 'Duration': '1h 22m', 'Rating': '4.0', 'Voting': '(397)'}
# {'Title': '270. Angels Fallen: Warriors of Peace', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '4.9', 'Voting': '(6.5K)'}
# {'Title': '271. Desert Fiends', 'Genre': 'Horror', 'Duration': '1h 46m', 'Rating': '4.9', 'Voting': '(882)'}
# {'Title': '272. Amityville: Where the Echo Lives', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '1.5', 'Voting': '(451)'}
# {'Title': '273. Its Name Was Mormo', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '3.8', 'Voting': '(172)'}
# {'Title': "274. Cinderella's Revenge", 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '3.7', 'Voting': '(1.2K)'}
# {'Title': '275. Animale', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '5.8', 'Voting': '(341)'}
# {'Title': '276. We Are Wolves', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '3.4', 'Voting': '(274)'}
# {'Title': '277. Unspeakable: Beyond the Wall of Sleep', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '4.0', 'Voting': '(138)'}
# {'Title': '278. From Darkness', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '4.9', 'Voting': '(607)'}
# {'Title': '279. Granny', 'Genre': 'Horror', 'Duration': '40m', 'Rating': '8.0', 'Voting': '(7)'}
# {'Title': '280. The Woods', 'Genre': 'Horror', 'Duration': '1h 16m', 'Rating': '3.9', 'Voting': '(79)'}
# {'Title': '281. The Forbidden Camp: Mass Possession', 'Genre': 'Horror', 'Duration': '1h 52m', 'Rating': '6.1', 'Voting': '(383)'}
# {'Title': '282. The Train of Death', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '4.7', 'Voting': '(729)'}
# {'Title': '283. Believer', 'Genre': 'Horror', 'Duration': '1h 48m', 'Rating': '4.6', 'Voting': '(444)'}
# {'Title': '284. Mutants of Nature Cove', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '3.6', 'Voting': '(167)'}
# {'Title': '285. Seven Cemeteries', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '4.6', 'Voting': '(672)'}
# {'Title': '286. Baby Invasion', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '4.6', 'Voting': '(605)'}
# {'Title': '287. Pacific Fear', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '3.5', 'Voting': '(313)'}
# {'Title': '288. Invader', 'Genre': 'Horror', 'Duration': '1h 10m', 'Rating': '4.6', 'Voting': '(166)'}
# {'Title': '289. Siccin 7', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '4.0', 'Voting': '(1.1K)'}
# {'Title': '290. Love Me If You Dare', 'Genre': 'Horror', 'Duration': '2h 8m', 'Rating': '4.3', 'Voting': '(484)'}
# {'Title': '291. Kakuda', 'Genre': 'Horror', 'Duration': '1h 56m', 'Rating': '5.4', 'Voting': '(6.4K)'}
# {'Title': '292. Espantaho', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '4.8', 'Voting': '(243)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '294. Paranoia', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '4.1', 'Voting': '(409)'}
# {'Title': '295. Aranmanai 4', 'Genre': 'Horror', 'Duration': '2h 28m', 'Rating': '5.0', 'Voting': '(2.4K)'}
# {'Title': '296. Curse of the Seven Oceans', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '5.5', 'Voting': '(530)'}
# {'Title': '297. Operation Blood Hunt', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '3.4', 'Voting': '(531)'}
# {'Title': "298. Poison Sangga: The Homewrecker's Curse", 'Genre': 'Horror', 'Duration': '1h 58m', 'Rating': '6.8', 'Voting': '(384)'}
# {'Title': '299. Sattam En Kaiyil', 'Genre': 'Horror', 'Duration': '2h 4m', 'Rating': '7.9', 'Voting': '(2.3K)'}
# {'Title': '300. Cara', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '6.1', 'Voting': '(62)'}
# {'Title': '301. Possessions', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '3.7', 'Voting': '(887)'}
# {'Title': '302. Mom', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '5.2', 'Voting': '(237)'}
# {'Title': '303. The Demon Disorder', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '4.8', 'Voting': '(1.4K)'}
# {'Title': '304. Alien Country', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '4.5', 'Voting': '(418)'}
# {'Title': '305. Witch Hunter', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '4.4', 'Voting': '(32)'}
# {'Title': '306. Vina: Before 7 Days', 'Genre': 'Horror', 'Duration': '1h 40m', 'Rating': '5.4', 'Voting': '(612)'}
# {'Title': '307. Butchers Book Two: Raghorn', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '4.1', 'Voting': '(670)'}
# {'Title': '308. Sorop', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '5.4', 'Voting': '(254)'}
# {'Title': '309. Nearing Death', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '5.7', 'Voting': '(380)'}
# {'Title': '310. Strange Frequencies: Taiwan Killer Hospital', 'Genre': 'Horror', 'Duration': '1h 31m', 'Rating': '7.2', 'Voting': '(75)'}
# {'Title': '311. A Herança', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '5.3', 'Voting': '(248)'}
# {'Title': '312. Killer Body Count', 'Genre': 'Horror', 'Duration': '1h 49m', 'Rating': '4.7', 'Voting': '(687)'}
# {'Title': '313. Sayuri', 'Genre': 'Horror', 'Duration': '1h 48m', 'Rating': '6.3', 'Voting': '(359)'}
# {'Title': '314. Kang Mak', 'Genre': 'Horror', 'Duration': '2h 2m', 'Rating': '6.4', 'Voting': '(910)'}
# {'Title': '315. Riders', 'Genre': 'Horror', 'Duration': '1h 45m', 'Rating': '6.4', 'Voting': '(517)'}
# {'Title': '316. Wanita Ahli Neraka', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '5.0', 'Voting': '(317)'}
# {'Title': '317. Hide N Seek', 'Genre': 'Horror', 'Duration': '2h 14m', 'Rating': '8.8', 'Voting': '(2.2K)'}
# {'Title': '318. Model House', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '4.0', 'Voting': '(1.1K)'}
# {'Title': '319. Witch', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '4.9', 'Voting': '(1.4K)'}
# {'Title': '320. Ba', 'Genre': 'Horror', 'Duration': '1h 19m', 'Rating': '7.4', 'Voting': '(70)'}
# {'Title': '321. Thaghut', 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '5.8', 'Voting': '(337)'}
# {'Title': '322. I Heart Willie', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '6.1', 'Voting': '(119)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '324. Jhamkudi', 'Genre': 'Horror', 'Duration': '2h 31m', 'Rating': '6.6', 'Voting': '(1K)'}
# {'Title': "325. A Mother's Embrace", 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '5.8', 'Voting': '(647)'}
# {'Title': '326. Sam and Colby: The Legends of the Paranormal', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '4.9', 'Voting': '(316)'}
# {'Title': '327. Hu Die Da Shia', 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '4.3', 'Voting': '(62)'}
# {'Title': '328. Festival of the Living Dead', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '4.3', 'Voting': '(673)'}
# {'Title': '329. Another Cabin in the Woods Movie', 'Genre': 'Horror', 'Duration': '1h 17m', 'Rating': '4.7', 'Voting': '(240)'}
# {'Title': '330. Night Shoot', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '5.6', 'Voting': '(93)'}
# {'Title': '331. The Ritual', 'Genre': 'Horror', 'Duration': '1h 40m', 'Rating': '3.5', 'Voting': '(31)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '333. Freelance', 'Genre': 'Horror', 'Duration': '1h 50m', 'Rating': '4.8', 'Voting': '(388)'}
# {'Title': '334. Bloody Ishq', 'Genre': 'Horror', 'Duration': '2h 18m', 'Rating': '2.9', 'Voting': '(2.2K)'}
# {'Title': '335. Last Stop: Rocafort St.', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '4.1', 'Voting': '(511)'}
# {'Title': "336. Don't Open the Door", 'Genre': 'Horror', 'Duration': '1h 27m', 'Rating': '6.6', 'Voting': '(8.4K)'}
# {'Title': '337. Sakaratul Maut', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '5.4', 'Voting': '(192)'}
# {'Title': '338. 12 to Midnight', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '3.6', 'Voting': '(303)'}
# {'Title': '339. The Jack in the Box Rises', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '4.1', 'Voting': '(839)'}
# {'Title': '340. Camp Pleasant Lake', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '3.3', 'Voting': '(2.4K)'}
# {'Title': '341. You Shall Not Sleep Tonight', 'Genre': 'Horror', 'Duration': '1h 17m', 'Rating': '4.1', 'Voting': '(397)'}
# {'Title': '342. My Boo', 'Genre': 'Horror', 'Duration': '2h 5m', 'Rating': '6.1', 'Voting': '(738)'}
# {'Title': '343. They Call Her Death', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '5.4', 'Voting': '(213)'}
# {'Title': '344. Are You There?', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '6.3', 'Voting': '(71)'}
# {'Title': '345. Horny Teenagers Must Die!', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '3.2', 'Voting': '(249)'}
# {'Title': '346. Cora', 'Genre': 'Horror', 'Duration': '1h 44m', 'Rating': '4.5', 'Voting': '(951)'}
# {'Title': '347. Spring Garden', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '4.4', 'Voting': '(213)'}
# {'Title': '348. Guess Who', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '4.8', 'Voting': '(378)'}
# {'Title': '349. Blood Debt', 'Genre': 'Horror', 'Duration': '1h 40m', 'Rating': '5.4', 'Voting': '(214)'}
# {'Title': '350. The Legend of Lake Hollow', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '3.7', 'Voting': '(554)'}
# {'Title': '351. Wake', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '3.4', 'Voting': '(288)'}
# {'Title': '352. Till Death Do Us Part', 'Genre': 'Horror', 'Duration': '1h 48m', 'Rating': '6.3', 'Voting': '(283)'}
# {'Title': '353. Replicator', 'Genre': 'Horror', 'Duration': '1h 15m', 'Rating': '3.8', 'Voting': '(183)'}
# {'Title': '354. Five Friends', 'Genre': 'Horror', 'Duration': '1h 52m', 'Rating': '6.7', 'Voting': '(992)'}
# {'Title': '355. The North Witch', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '4.7', 'Voting': '(65)'}
# {'Title': '356. What Lurks Beneath', 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '4.2', 'Voting': '(809)'}
# {'Title': '357. Chainsaws Were Singing', 'Genre': 'Horror', 'Duration': '1h 57m', 'Rating': '7.2', 'Voting': '(391)'}
# {'Title': '358. Dominion of Darkness', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '5.6', 'Voting': '(862)'}
# {'Title': '359. Do You See What I See', 'Genre': 'Horror', 'Duration': '1h 49m', 'Rating': '5.4', 'Voting': '(705)'}
# {'Title': '360. The Notorious Finster', 'Genre': 'Horror', 'Duration': '1h 53m', 'Rating': '3.9', 'Voting': '(184)'}
# {'Title': '361. History of Evil', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '3.4', 'Voting': '(834)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '363. Down Below', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '2.6', 'Voting': '(208)'}
# {'Title': '364. Haunted Universities 3', 'Genre': 'Horror', 'Duration': '1h 59m', 'Rating': '5.4', 'Voting': '(325)'}
# {'Title': '365. Nyctophobia', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '6.8', 'Voting': '(1.8K)'}
# {'Title': '366. Buzz House: The Movie', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '3.2', 'Voting': '(1.3K)'}
# {'Title': '367. American Werewolf', 'Genre': 'Horror', 'Duration': '1h 7m', 'Rating': '1.6', 'Voting': '(125)'}
# {'Title': '368. Lumina', 'Genre': 'Horror', 'Duration': '1h 53m', 'Rating': '2.1', 'Voting': '(716)'}
# {'Title': '369. Salem Witch Doll', 'Genre': 'Horror', 'Duration': '1h 16m', 'Rating': '2.3', 'Voting': '(144)'}
# {'Title': '370. Kuyang', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '5.2', 'Voting': '(501)'}
# {'Title': '371. Clickbait: Unfollowed', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '4.9', 'Voting': '(611)'}
# {'Title': '372. Wineville', 'Genre': 'Horror', 'Duration': '1h 40m', 'Rating': '4.3', 'Voting': '(286)'}
# {'Title': '373. Interlopers', 'Genre': 'Horror', 'Duration': '1h 46m', 'Rating': '4.9', 'Voting': '(77)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '375. Cellphone', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '3.0', 'Voting': '(754)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '377. Possession: Kerasukan', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '3.6', 'Voting': '(309)'}
# {'Title': '378. The Hunted', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '5.2', 'Voting': '(402)'}
# {'Title': '379. The Monster Beneath Us', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '5.4', 'Voting': '(471)'}
# {'Title': '380. Burning Butterflies', 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '7.8', 'Voting': '(95)'}
# {'Title': "381. There's a Zombie Outside", 'Genre': 'Horror', 'Duration': '1h 15m', 'Rating': '5.7', 'Voting': '(69)'}
# {'Title': '382. Shark Girl', 'Genre': 'Horror', 'Duration': '1h 22m', 'Rating': '2.6', 'Voting': '(183)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '384. The Windigo', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '4.6', 'Voting': '(726)'}
# {'Title': '385. Curse of the Sin Eater', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '4.9', 'Voting': '(815)'}
# {'Title': '386. Soul Reaper', 'Genre': 'Horror', 'Duration': '1h 52m', 'Rating': '5.7', 'Voting': '(329)'}
# {'Title': '387. Perewangan', 'Genre': 'Horror', 'Duration': '1h 49m', 'Rating': '5.4', 'Voting': '(182)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '389. Guna guna istri muda', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '5.2', 'Voting': '(207)'}
# {'Title': '390. Bad Fish', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '3.3', 'Voting': '(348)'}
# {'Title': '391. Phallacies', 'Genre': 'Horror', 'Duration': '1h 41m', 'Rating': '8.5', 'Voting': '(7)'}
# {'Title': '392. Vincent', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '5.1', 'Voting': '(136)'}
# {'Title': '393. Nokturno', 'Genre': 'Horror', 'Duration': '1h 39m', 'Rating': '3.7', 'Voting': '(232)'}
# {'Title': '394. Haze', 'Genre': 'Horror', 'Duration': '1h 16m', 'Rating': '6.4', 'Voting': '(54)'}
# {'Title': '395. Guardian', 'Genre': 'Horror', 'Duration': '2h', 'Rating': '4.0', 'Voting': '(676)'}
# {'Title': '396. The Omicron Killer', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '2.9', 'Voting': '(600)'}
# {'Title': '397. Bull Shark 3', 'Genre': 'Horror', 'Duration': '1h 16m', 'Rating': '3.3', 'Voting': '(116)'}
# {'Title': '398. Pale Horse', 'Genre': 'Horror', 'Duration': '1h 27m', 'Rating': '3.8', 'Voting': '(79)'}
# {'Title': '399. Butchers Book Three: Bonesaw', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '4.9', 'Voting': '(129)'}
# {'Title': '400. The Waves of Madness', 'Genre': 'Horror', 'Duration': '1h 8m', 'Rating': '5.8', 'Voting': '(116)'}
# {'Title': '401. Pasar Setan', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '6.7', 'Voting': '(62)'}
# {'Title': '402. 30 to 45', 'Genre': 'Horror', 'Duration': '1h 58m', 'Rating': '3.8', 'Voting': '(18)'}
# {'Title': '403. The Bad Nun 3', 'Genre': 'Horror', 'Duration': '1h 12m', 'Rating': '3.2', 'Voting': '(281)'}
# {'Title': '404. The Family Business', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '8.7', 'Voting': '(30)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '406. Naalkane Aayama', 'Genre': 'Horror', 'Duration': '1h 48m', 'Rating': '7.2', 'Voting': '(2.2K)'}
# {'Title': "407. H. P. Lovecraft's the Old Ones", 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '3.6', 'Voting': '(416)'}
# {'Title': '408. Z Zone', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '3.7', 'Voting': '(59)'}
# {'Title': '409. Salve Maria', 'Genre': 'Horror', 'Duration': '1h 51m', 'Rating': '6.4', 'Voting': '(526)'}
# {'Title': '410. Solitude', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '6.2', 'Voting': '(47)'}
# {'Title': '411. Last Night at Terrace Lanes', 'Genre': 'Horror', 'Duration': '1h 15m', 'Rating': '4.4', 'Voting': '(657)'}
# {'Title': '412. Alyad Palyad', 'Genre': 'Horror', 'Duration': '2h 9m', 'Rating': '6.9', 'Voting': '(1.2K)'}
# {'Title': '413. Darling', 'Genre': 'Horror', 'Duration': '2h 39m', 'Rating': '5.2', 'Voting': '(759)'}
# {'Title': '414. The Ruse', 'Genre': 'Horror', 'Duration': '1h 45m', 'Rating': '6.9', 'Voting': '(423)'}
# {'Title': "415. A Fisherman's Tale", 'Genre': 'Horror', 'Duration': '1h 43m', 'Rating': '6.0', 'Voting': '(146)'}
# {'Title': '416. The Redemption of Sin', 'Genre': 'Horror', 'Duration': '1h 56m', 'Rating': '5.7', 'Voting': '(240)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '418. (Pri)sons', 'Genre': 'Horror', 'Duration': '1h 40m', 'Rating': '5.0', 'Voting': '(300)'}
# {'Title': '419. Manipula', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '8.4', 'Voting': '(33)'}
# {'Title': '420. Biaz: Kara Iyenin Laneti', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '5.1', 'Voting': '(405)'}
# {'Title': '421. Art of a Hit', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '4.2', 'Voting': '(221)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '423. Pusaka', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '5.2', 'Voting': '(201)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '425. Suckers', 'Genre': 'Horror', 'Duration': '1h 7m', 'Rating': '2.4', 'Voting': '(133)'}
# {'Title': '426. Invited', 'Genre': 'Horror', 'Duration': '1h 11m', 'Rating': '5.2', 'Voting': '(252)'}
# {'Title': '427. Night Talkers', 'Genre': 'Horror', 'Duration': '1h 29m', 'Rating': '4.1', 'Voting': '(103)'}
# {'Title': '428. Do Not Open', 'Genre': 'Horror', 'Duration': '1h 31m', 'Rating': '2.6', 'Voting': '(285)'}
# {'Title': '429. Stupid Games', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '4.2', 'Voting': '(438)'}
# {'Title': '430. Scared to Death', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '6.6', 'Voting': '(34)'}
# {'Title': '431. Jurnal Risa by Risa Saraswati', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '4.4', 'Voting': '(315)'}
# {'Title': '432. Gone with the Dead', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '4.1', 'Voting': '(56)'}
# {'Title': '433. Pater Noster and the Mission of Light', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '7.2', 'Voting': '(145)'}
# {'Title': '434. Virgo', 'Genre': 'Horror', 'Duration': '1h 27m', 'Rating': '5.4', 'Voting': '(104)'}
# {'Title': '435. A Hell of a Difference', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '4.8', 'Voting': '(51)'}
# {'Title': '436. Marni: The Story of Wewe Gombel', 'Genre': 'Horror', 'Duration': '1h 59m', 'Rating': '5.8', 'Voting': '(239)'}
# {'Title': '437. The Book of the Witch', 'Genre': 'Horror', 'Duration': '1h 13m', 'Rating': '4.4', 'Voting': '(148)'}
# {'Title': '438. Within the Pines', 'Genre': 'Horror', 'Duration': '1h 13m', 'Rating': '6.3', 'Voting': '(20)'}
# {'Title': '439. The Stalking', 'Genre': 'Horror', 'Duration': '1h 12m', 'Rating': '3.6', 'Voting': '(53)'}
# {'Title': '440. Yagna', 'Genre': 'Horror', 'Duration': '2h 11m', 'Rating': '6.3', 'Voting': '(1.6K)'}
# {'Title': '441. Skeletons in the Closet', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '3.0', 'Voting': '(580)'}
# {'Title': '442. Spirit Riser', 'Genre': 'Horror', 'Duration': '1h 38m', 'Rating': '6.4', 'Voting': '(40)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '444. People in the Walls', 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '3.3', 'Voting': '(53)'}
# {'Title': '445. Good Neighbours', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '3.0', 'Voting': '(192)'}
# {'Title': '446. Spithood', 'Genre': 'Horror', 'Duration': '58m', 'Rating': '5.4', 'Voting': '(1.1K)'}
# {'Title': '447. Mountain Shark', 'Genre': 'Horror', 'Duration': '1h 21m', 'Rating': '3.5', 'Voting': '(158)'}
# {'Title': '448. Trinil', 'Genre': 'Horror', 'Duration': '1h 45m', 'Rating': '4.5', 'Voting': '(379)'}
# {'Title': '449. Effigy', 'Genre': 'Horror', 'Duration': '1h 18m', 'Rating': '2.8', 'Voting': '(265)'}
# {'Title': '450. Mona: Jinn-2', 'Genre': 'Horror', 'Duration': '2h 4m', 'Rating': '4.3', 'Voting': '(128)'}
# {'Title': '451. Cadi', 'Genre': 'Horror', 'Duration': '2h 14m', 'Rating': '6.3', 'Voting': '(4.4K)'}
# {'Title': '452. Scared Shitless', 'Genre': 'Horror', 'Duration': '1h 16m', 'Rating': '6.1', 'Voting': '(228)'}
# {'Title': '453. Killer Influence', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '2.6', 'Voting': '(332)'}
# {'Title': '454. Shark Island', 'Genre': 'Horror', 'Duration': '1h 21m', 'Rating': '3.0', 'Voting': '(138)'}
# {'Title': '455. Jugaremos en el bosque', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '4.9', 'Voting': '(103)'}
# {'Title': '456. The Backrooms', 'Genre': 'Horror', 'Duration': '1h 3m', 'Rating': '8.2', 'Voting': '(16)'}
# {'Title': '457. Vertical', 'Genre': 'Horror', 'Duration': '1h 51m', 'Rating': '5.2', 'Voting': '(148)'}
# {'Title': '458. Family', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '6.8', 'Voting': '(33)'}
# {'Title': '459. 9 Windows', 'Genre': 'Horror', 'Duration': '1h 22m', 'Rating': '3.6', 'Voting': '(329)'}
# {'Title': '460. Thine Ears Shall Bleed', 'Genre': 'Horror', 'Duration': '1h 42m', 'Rating': '6.2', 'Voting': '(1.1K)'}
# {'Title': '461. Kromoleo', 'Genre': 'Horror', 'Duration': '1h 20m', 'Rating': '3.9', 'Voting': '(271)'}
# {'Title': '462. La Patasola', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '2.7', 'Voting': '(99)'}
# {'Title': '463. Solvent', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '7.2', 'Voting': '(459)'}
# {'Title': '464. Geethanjali Malli Vachindi', 'Genre': 'Horror', 'Duration': '2h 24m', 'Rating': '4.8', 'Voting': '(2.2K)'}
# {'Title': '465. Remnant', 'Genre': 'Horror', 'Duration': '1h 52m', 'Rating': '2.6', 'Voting': '(334)'}
# {'Title': '466. Tenants', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '4.3', 'Voting': '(127)'}
# {'Title': '467. Bag of Lies', 'Genre': 'Horror', 'Duration': '1h 36m', 'Rating': '3.8', 'Voting': '(601)'}
# {'Title': '468. The American Backyard', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '6.1', 'Voting': '(210)'}
# {'Title': '469. Hide and Seek', 'Genre': 'Horror', 'Duration': '1h 24m', 'Rating': '4.9', 'Voting': '(162)'}
# {'Title': '470. Camp Blood: Clown Shark', 'Genre': 'Horror', 'Duration': '1h 10m', 'Rating': '3.3', 'Voting': '(96)'}
# {'Title': '471. Deadly Retreat', 'Genre': 'Horror', 'Duration': '46m', 'Rating': '4.8', 'Voting': '(113)'}
# {'Title': '472. Kuang Bao Ju Xi', 'Genre': 'Horror', 'Duration': '1h 15m', 'Rating': '5.5', 'Voting': '(94)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '474. Ghost Island', 'Genre': 'Horror', 'Duration': '1h 35m', 'Rating': '7.1', 'Voting': '(57)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '476. The Cellar', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '5.8', 'Voting': '(174)'}
# {'Title': '477. Malice', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '2.7', 'Voting': '(45)'}
# {'Title': '478. SinÉl', 'Genre': 'Horror', 'Duration': '1h 12m', 'Rating': '5.5', 'Voting': '(17)'}
# {'Title': "479. In Search of Darkness 1990-1994: A Journey Into Iconic '90s Horror", 'Genre': 'Horror', 'Duration': '6h 3m', 'Rating': '8.0', 'Voting': '(165)'}
# {'Title': "480. Father's Haunted House", 'Genre': 'Horror', 'Duration': '1h 33m', 'Rating': '5.9', 'Voting': '(360)'}
# {'Title': '481. Z-Mom', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '4.9', 'Voting': '(47)'}
# {'Title': '482. Water Horse', 'Genre': 'Horror', 'Duration': '1h 25m', 'Rating': '5.0', 'Voting': '(262)'}
# {'Title': '483. A Wedding Story', 'Genre': 'Horror', 'Duration': '1h 50m', 'Rating': '6.0', 'Voting': '(2.8K)'}
# {'Title': '484. Nanay, tatay', 'Genre': 'Horror', 'Duration': '2h', 'Rating': '6.9', 'Voting': '(72)'}
# {'Title': '485. Staycation', 'Genre': 'Horror', 'Duration': '1h 34m', 'Rating': '7.2', 'Voting': '(120)'}
# {'Title': '486. The Blackwell Ghost 8', 'Genre': 'Horror', 'Duration': '1h 9m', 'Rating': '6.1', 'Voting': '(419)'}
# {'Title': '487. The Prodigy', 'Genre': 'Horror', 'Duration': '1h 23m', 'Rating': '4.6', 'Voting': '(38)'}
# {'Title': '488. Temurun', 'Genre': 'Horror', 'Duration': '1h 26m', 'Rating': '4.6', 'Voting': '(360)'}
# {'Title': 'N/A', 'Genre': 'Horror', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '490. Liu mang qu mo shi', 'Genre': 'Horror', 'Duration': '1h 44m', 'Rating': '5.6', 'Voting': '(56)'}
# {'Title': '491. All That Remains', 'Genre': 'Horror', 'Duration': '1h 10m', 'Rating': '6.1', 'Voting': '(25)'}
# {'Title': '492. Book of the Dead', 'Genre': 'Horror', 'Duration': '1h 30m', 'Rating': '5.4', 'Voting': '(79)'}
# {'Title': '493. Ladybug', 'Genre': 'Horror', 'Duration': '1h 47m', 'Rating': '5.5', 'Voting': '(34)'}
# {'Title': '494. Ship of the Damned', 'Genre': 'Horror', 'Duration': '1h 28m', 'Rating': '2.8', 'Voting': '(311)'}
# {'Title': '495. El instinto', 'Genre': 'Horror', 'Duration': '1h 32m', 'Rating': '6.6', 'Voting': '(123)'}
# {'Title': '496. Purgatory Station', 'Genre': 'Horror', 'Duration': '1h 49m', 'Rating': '3.2', 'Voting': '(59)'}
# {'Title': '497. Death Streamer', 'Genre': 'Horror', 'Duration': '1h 12m', 'Rating': '3.0', 'Voting': '(236)'}
# {'Title': '498. My Redneck Neighbor: Chapter 2 - Let the Games Begin', 'Genre': 'Horror', 'Duration': '55m', 'Rating': '5.7', 'Voting': '(11)'}
# {'Title': '499. Space Sharks', 'Genre': 'Horror', 'Duration': '1h 10m', 'Rating': '1.5', 'Voting': '(332)'}
# {'Title': '500. Silence of the Prey', 'Genre': 'Horror', 'Duration': '1h 37m', 'Rating': '3.8', 'Voting': '(302)'}

# %%
#common csv converting code

import pandas as pd


df=pd.DataFrame(movie_list)

# 1. Remove leading numbers from "Title"
df["Title"] = df["Title"].str.replace(r"^\d+\.\s*", "", regex=True)

# 2. Remove parentheses from "Voting"
df["Voting"] = df["Voting"].str.replace(r"[()]", "", regex=True)

# 3. Reset index to start from 1
df.index = df.index + 1

df.to_csv(r"D:\Nirosha\GUVI\Project\horror.csv", index=False, encoding="utf-8")
print(r"CSV file - HORROR Movie saved successfully!")
# Out:
# CSV file - HORROR Movie saved successfully!

# %%
# Thriller movies 

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

# Initialize WebDriver
driver = webdriver.Chrome()
driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=thriller")

time.sleep(5)  # Waiting for the page to load

genre = "Thriller"

# Scroll Until No More New Data Loads
scroll = True
movies_per_page = 50  # Assuming each load gives 50 movies
total_movies = 500
current_movies = 0

while scroll and current_movies < total_movies:
    old_page_source = driver.page_source  # Save old page source
    
    # Scroll down to load more data
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Allow time for new data to load
    
    new_page_source = driver.page_source  # Save new page source

    if new_page_source == old_page_source:
        try:
            # Locate and click the "See More" button if present
            see_more_button = driver.find_element(By.XPATH, "//span[contains(@class, 'ipc-see-more')]")
            ActionChains(driver).move_to_element(see_more_button).click().perform()
            time.sleep(2)  # Wait for new content to load
        except Exception:
            scroll = False  # Stop scrolling if button isn't found
    else:
        current_movies += movies_per_page  # Increment count

# Extract movie containers
movie_block = driver.find_elements(By.CSS_SELECTOR, "li.ipc-metadata-list-summary-item")

movie_list = []

for movie in movie_block:
    try:
        title = movie.find_element(By.CSS_SELECTOR, "h3.ipc-title__text").text.strip()
        duration_element = movie.find_element(By.XPATH, ".//span[contains(@class, 'dli-title-metadata-item') and (contains(text(),'h') or contains(text(),'m'))]")
        duration = duration_element.text.strip() if duration_element.text.strip() else "N/A"   
        rating = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--rating").text.strip()
        voting = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--voteCount").text.strip()
    except:
        title = "N/A"
        duration = "N/A"
        rating = "N/A"
        voting = "N/A"

    movie_data = {
        "Title": title,
        "Genre": genre,
        "Duration": duration,
        "Rating": rating,
        "Voting": voting,
    }
    movie_list.append(movie_data)

# Print results
for movie in movie_list:
    print(movie)

# Close the driver
driver.quit()
# Out:
# {'Title': '1. Eden', 'Genre': 'Thriller', 'Duration': '2h', 'Rating': '6.3', 'Voting': '(5.5K)'}
# {'Title': '2. Heretic', 'Genre': 'Thriller', 'Duration': '1h 51m', 'Rating': '7.0', 'Voting': '(170K)'}
# {'Title': '3. Twisters', 'Genre': 'Thriller', 'Duration': '2h 2m', 'Rating': '6.5', 'Voting': '(178K)'}
# {'Title': '4. Kraven the Hunter', 'Genre': 'Thriller', 'Duration': '2h 7m', 'Rating': '5.5', 'Voting': '(66K)'}
# {'Title': '5. The Surfer', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '6.0', 'Voting': '(11K)'}
# {'Title': '6. Push', 'Genre': 'Thriller', 'Duration': '1h 29m', 'Rating': '4.7', 'Voting': '(366)'}
# {'Title': '7. The Order', 'Genre': 'Thriller', 'Duration': '1h 56m', 'Rating': '6.8', 'Voting': '(51K)'}
# {'Title': '8. Conclave', 'Genre': 'Thriller', 'Duration': '2h', 'Rating': '7.4', 'Voting': '(209K)'}
# {'Title': '9. Babygirl', 'Genre': 'Thriller', 'Duration': '1h 54m', 'Rating': '5.8', 'Voting': '(65K)'}
# {'Title': '10. Juror #2', 'Genre': 'Thriller', 'Duration': '1h 54m', 'Rating': '7.0', 'Voting': '(107K)'}
# {'Title': '11. Long Distance', 'Genre': 'Thriller', 'Duration': '1h 27m', 'Rating': '5.7', 'Voting': '(4.3K)'}
# {'Title': '12. Longlegs', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '6.6', 'Voting': '(196K)'}
# {'Title': '13. Speak No Evil', 'Genre': 'Thriller', 'Duration': '1h 50m', 'Rating': '6.8', 'Voting': '(113K)'}
# {'Title': '14. Alien: Romulus', 'Genre': 'Thriller', 'Duration': '1h 59m', 'Rating': '7.1', 'Voting': '(256K)'}
# {'Title': '15. Carry-On', 'Genre': 'Thriller', 'Duration': '1h 59m', 'Rating': '6.5', 'Voting': '(174K)'}
# {'Title': '16. Presence', 'Genre': 'Thriller', 'Duration': '1h 24m', 'Rating': '6.1', 'Voting': '(31K)'}
# {'Title': '17. Blink Twice', 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '6.5', 'Voting': '(113K)'}
# {'Title': '18. Wolfs', 'Genre': 'Thriller', 'Duration': '1h 48m', 'Rating': '6.5', 'Voting': '(90K)'}
# {'Title': '19. Civil War', 'Genre': 'Thriller', 'Duration': '1h 49m', 'Rating': '7.0', 'Voting': '(246K)'}
# {'Title': '20. Venom: The Last Dance', 'Genre': 'Thriller', 'Duration': '1h 50m', 'Rating': '6.0', 'Voting': '(133K)'}
# {'Title': '21. The Count of Monte-Cristo', 'Genre': 'Thriller', 'Duration': '2h 58m', 'Rating': '7.6', 'Voting': '(38K)'}
# {'Title': '22. The Beekeeper', 'Genre': 'Thriller', 'Duration': '1h 45m', 'Rating': '6.3', 'Voting': '(164K)'}
# {'Title': '23. Smile 2', 'Genre': 'Thriller', 'Duration': '2h 7m', 'Rating': '6.7', 'Voting': '(117K)'}
# {'Title': '24. Joker: Folie à Deux', 'Genre': 'Thriller', 'Duration': '2h 18m', 'Rating': '5.2', 'Voting': '(167K)'}
# {'Title': '25. Road House', 'Genre': 'Thriller', 'Duration': '2h 1m', 'Rating': '6.2', 'Voting': '(172K)'}
# {'Title': '26. The Shrouds', 'Genre': 'Thriller', 'Duration': '2h', 'Rating': '5.8', 'Voting': '(4.8K)'}
# {'Title': '27. Trap', 'Genre': 'Thriller', 'Duration': '1h 45m', 'Rating': '5.8', 'Voting': '(146K)'}
# {'Title': '28. 40 Acres', 'Genre': 'Thriller', 'Duration': '1h 53m', 'Rating': '7.1', 'Voting': '(818)'}
# {'Title': "29. Salem's Lot", 'Genre': 'Thriller', 'Duration': '1h 54m', 'Rating': '5.6', 'Voting': '(36K)'}
# {'Title': '30. The Rule of Jenny Pen', 'Genre': 'Thriller', 'Duration': '1h 44m', 'Rating': '6.2', 'Voting': '(6.7K)'}
# {'Title': '31. The Luckiest Man in America', 'Genre': 'Thriller', 'Duration': '1h 31m', 'Rating': '6.2', 'Voting': '(4.3K)'}
# {'Title': '32. Elevation', 'Genre': 'Thriller', 'Duration': '1h 31m', 'Rating': '5.6', 'Voting': '(25K)'}
# {'Title': '33. Caddo Lake', 'Genre': 'Thriller', 'Duration': '1h 43m', 'Rating': '6.8', 'Voting': '(46K)'}
# {'Title': '34. 1978', 'Genre': 'Thriller', 'Duration': '1h 20m', 'Rating': '5.0', 'Voting': '(789)'}
# {'Title': '35. Rebel Ridge', 'Genre': 'Thriller', 'Duration': '2h 11m', 'Rating': '6.8', 'Voting': '(92K)'}
# {'Title': '36. Godzilla x Kong: The New Empire', 'Genre': 'Thriller', 'Duration': '1h 55m', 'Rating': '6.0', 'Voting': '(125K)'}
# {'Title': '37. Argylle', 'Genre': 'Thriller', 'Duration': '2h 19m', 'Rating': '5.6', 'Voting': '(95K)'}
# {'Title': '38. Abigail', 'Genre': 'Thriller', 'Duration': '1h 49m', 'Rating': '6.5', 'Voting': '(101K)'}
# {'Title': '39. Oddity', 'Genre': 'Thriller', 'Duration': '1h 38m', 'Rating': '6.7', 'Voting': '(47K)'}
# {'Title': '40. A Quiet Place: Day One', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '6.3', 'Voting': '(157K)'}
# {'Title': '41. Madame Web', 'Genre': 'Thriller', 'Duration': '1h 56m', 'Rating': '4.1', 'Voting': '(104K)'}
# {'Title': '42. Borderlands', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '4.7', 'Voting': '(51K)'}
# {'Title': '43. Land of Bad', 'Genre': 'Thriller', 'Duration': '1h 53m', 'Rating': '6.6', 'Voting': '(54K)'}
# {'Title': '44. The Instigators', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '6.2', 'Voting': '(39K)'}
# {'Title': '45. The Crow', 'Genre': 'Thriller', 'Duration': '1h 51m', 'Rating': '4.7', 'Voting': '(37K)'}
# {'Title': '46. Subservience', 'Genre': 'Thriller', 'Duration': '1h 46m', 'Rating': '5.4', 'Voting': '(30K)'}
# {'Title': '47. Saint Clare', 'Genre': 'Thriller', 'Duration': '1h 32m', 'Rating': '5.1', 'Voting': '(145)'}
# {'Title': '48. Bad Boys: Ride or Die', 'Genre': 'Thriller', 'Duration': '1h 55m', 'Rating': '6.5', 'Voting': '(104K)'}
# {'Title': '49. Emilia Pérez', 'Genre': 'Thriller', 'Duration': '2h 12m', 'Rating': '5.4', 'Voting': '(92K)'}
# {'Title': '50. A Different Man', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '6.9', 'Voting': '(32K)'}
# {'Title': '51. Pune Highway', 'Genre': 'Thriller', 'Duration': '2h 1m', 'Rating': '5.1', 'Voting': '(318)'}
# {'Title': '52. Kingdom of the Planet of the Apes', 'Genre': 'Thriller', 'Duration': '2h 25m', 'Rating': '6.8', 'Voting': '(156K)'}
# {'Title': '53. Relay', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '7.3', 'Voting': '(149)'}
# {'Title': '54. Lucky Baskhar', 'Genre': 'Thriller', 'Duration': '2h 28m', 'Rating': '8.0', 'Voting': '(35K)'}
# {'Title': '55. September 5', 'Genre': 'Thriller', 'Duration': '1h 35m', 'Rating': '7.1', 'Voting': '(28K)'}
# {'Title': '56. Maharaja', 'Genre': 'Thriller', 'Duration': '2h 21m', 'Rating': '8.4', 'Voting': '(72K)'}
# {'Title': '57. The Union', 'Genre': 'Thriller', 'Duration': '1h 47m', 'Rating': '5.4', 'Voting': '(55K)'}
# {'Title': "58. Don't Move", 'Genre': 'Thriller', 'Duration': '1h 32m', 'Rating': '5.8', 'Voting': '(41K)'}
# {'Title': '59. Love Lies Bleeding', 'Genre': 'Thriller', 'Duration': '1h 44m', 'Rating': '6.6', 'Voting': '(59K)'}
# {'Title': '60. The Watchers', 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '5.7', 'Voting': '(59K)'}
# {'Title': "61. It's What's Inside", 'Genre': 'Thriller', 'Duration': '1h 43m', 'Rating': '6.6', 'Voting': '(45K)'}
# {'Title': '62. Kung Fu Panda 4', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '6.3', 'Voting': '(71K)'}
# {'Title': '63. F*** Marry Kill', 'Genre': 'Thriller', 'Duration': '1h 37m', 'Rating': '5.3', 'Voting': '(3.4K)'}
# {'Title': '64. The Killer', 'Genre': 'Thriller', 'Duration': '2h 6m', 'Rating': '5.7', 'Voting': '(14K)'}
# {'Title': '65. Survive', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '4.6', 'Voting': '(3.4K)'}
# {'Title': '66. Immaculate', 'Genre': 'Thriller', 'Duration': '1h 29m', 'Rating': '5.8', 'Voting': '(55K)'}
# {'Title': '67. Monkey Man', 'Genre': 'Thriller', 'Duration': '2h 1m', 'Rating': '6.8', 'Voting': '(94K)'}
# {'Title': '68. Sew Torn', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '6.0', 'Voting': '(968)'}
# {'Title': '69. Canary Black', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '5.4', 'Voting': '(12K)'}
# {'Title': "70. Please Don't Feed the Children", 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '4.8', 'Voting': '(563)'}
# {'Title': '71. The Seed of the Sacred Fig', 'Genre': 'Thriller', 'Duration': '2h 47m', 'Rating': '7.6', 'Voting': '(16K)'}
# {'Title': '72. Drive-Away Dolls', 'Genre': 'Thriller', 'Duration': '1h 24m', 'Rating': '5.4', 'Voting': '(25K)'}
# {'Title': '73. Absolution', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '5.2', 'Voting': '(9.2K)'}
# {'Title': '74. Homestead', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '5.2', 'Voting': '(4.3K)'}
# {'Title': '75. Cuckoo', 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '5.7', 'Voting': '(30K)'}
# {'Title': '76. Dirty Angels', 'Genre': 'Thriller', 'Duration': '1h 44m', 'Rating': '4.4', 'Voting': '(4.3K)'}
# {'Title': '77. The Silent Hour', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '6.1', 'Voting': '(8.6K)'}
# {'Title': '78. Beverly Hills Cop: Axel F', 'Genre': 'Thriller', 'Duration': '1h 58m', 'Rating': '6.4', 'Voting': '(83K)'}
# {'Title': '79. Sleeping Dogs', 'Genre': 'Thriller', 'Duration': '1h 50m', 'Rating': '6.2', 'Voting': '(23K)'}
# {'Title': '80. Kalki 2898 AD', 'Genre': 'Thriller', 'Duration': '3h', 'Rating': '7.0', 'Voting': '(69K)'}
# {'Title': "81. Miller's Girl", 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '5.2', 'Voting': '(25K)'}
# {'Title': '82. Pushpa: The Rule - Part 2', 'Genre': 'Thriller', 'Duration': '3h 21m', 'Rating': '6.1', 'Voting': '(59K)'}
# {'Title': "83. The Killer's Game", 'Genre': 'Thriller', 'Duration': '1h 44m', 'Rating': '5.8', 'Voting': '(19K)'}
# {'Title': '84. MadS', 'Genre': 'Thriller', 'Duration': '1h 29m', 'Rating': '6.4', 'Voting': '(9.2K)'}
# {'Title': '85. Never Let Go', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '5.4', 'Voting': '(17K)'}
# {'Title': "86. Mothers' Instinct", 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '6.3', 'Voting': '(22K)'}
# {'Title': '87. The Deliverance', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '5.1', 'Voting': '(23K)'}
# {'Title': '88. Sharp Corner', 'Genre': 'Thriller', 'Duration': '1h 50m', 'Rating': '5.9', 'Voting': '(2.1K)'}
# {'Title': '89. Time Cut', 'Genre': 'Thriller', 'Duration': '1h 31m', 'Rating': '5.0', 'Voting': '(20K)'}
# {'Title': '90. Ask Me What You Want', 'Genre': 'Thriller', 'Duration': '1h 54m', 'Rating': '3.9', 'Voting': '(1.3K)'}
# {'Title': '91. To a Land Unknown', 'Genre': 'Thriller', 'Duration': '1h 45m', 'Rating': '7.3', 'Voting': '(676)'}
# {'Title': '92. Hellboy: The Crooked Man', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '4.5', 'Voting': '(15K)'}
# {'Title': '93. Apartment 7A', 'Genre': 'Thriller', 'Duration': '1h 47m', 'Rating': '5.9', 'Voting': '(17K)'}
# {'Title': '94. In a Violent Nature', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '5.6', 'Voting': '(28K)'}
# {'Title': '95. Arcadian', 'Genre': 'Thriller', 'Duration': '1h 32m', 'Rating': '5.5', 'Voting': '(25K)'}
# {'Title': '96. Guns & Moses', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '6.5', 'Voting': '(142)'}
# {'Title': '97. Apocalypse Z: The Beginning of the End', 'Genre': 'Thriller', 'Duration': '1h 57m', 'Rating': '6.1', 'Voting': '(21K)'}
# {'Title': '98. Cellar Door', 'Genre': 'Thriller', 'Duration': '1h 37m', 'Rating': '5.3', 'Voting': '(4.8K)'}
# {'Title': '99. Dead Mail', 'Genre': 'Thriller', 'Duration': '1h 46m', 'Rating': '6.0', 'Voting': '(2.3K)'}
# {'Title': '100. Atlas', 'Genre': 'Thriller', 'Duration': '1h 58m', 'Rating': '5.6', 'Voting': '(57K)'}
# {'Title': '101. Weekend in Taipei', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '5.7', 'Voting': '(5.5K)'}
# {'Title': '102. The Platform 2', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '4.9', 'Voting': '(42K)'}
# {'Title': '103. Chime', 'Genre': 'Thriller', 'Duration': '45m', 'Rating': '6.4', 'Voting': '(2.8K)'}
# {'Title': '104. Bring Them Down', 'Genre': 'Thriller', 'Duration': '1h 46m', 'Rating': '6.5', 'Voting': '(4.4K)'}
# {'Title': '105. Damaged', 'Genre': 'Thriller', 'Duration': '1h 37m', 'Rating': '4.7', 'Voting': '(7.7K)'}
# {'Title': '106. Lift', 'Genre': 'Thriller', 'Duration': '1h 47m', 'Rating': '5.5', 'Voting': '(50K)'}
# {'Title': '107. Legally Veer', 'Genre': 'Thriller', 'Duration': '2h 22m', 'Rating': '7.0', 'Voting': '(4.9K)'}
# {'Title': '108. Under Paris', 'Genre': 'Thriller', 'Duration': '1h 44m', 'Rating': '5.2', 'Voting': '(37K)'}
# {'Title': '109. Night Swim', 'Genre': 'Thriller', 'Duration': '1h 38m', 'Rating': '4.7', 'Voting': '(28K)'}
# {'Title': '110. Slingshot', 'Genre': 'Thriller', 'Duration': '1h 48m', 'Rating': '5.7', 'Voting': '(10K)'}
# {'Title': '111. Went Up the Hill', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '6.6', 'Voting': '(94)'}
# {'Title': '112. Black Dog', 'Genre': 'Thriller', 'Duration': '1h 56m', 'Rating': '7.2', 'Voting': '(4.1K)'}
# {'Title': '113. Restless', 'Genre': 'Thriller', 'Duration': '1h 29m', 'Rating': '6.3', 'Voting': '(698)'}
# {'Title': '114. Skincare', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '5.7', 'Voting': '(5K)'}
# {'Title': '115. Manjummel Boys', 'Genre': 'Thriller', 'Duration': '2h 15m', 'Rating': '8.2', 'Voting': '(29K)'}
# {'Title': '116. Magpie', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '6.2', 'Voting': '(3.9K)'}
# {'Title': '117. Werewolves', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '4.4', 'Voting': '(7.7K)'}
# {'Title': '118. Detained', 'Genre': 'Thriller', 'Duration': '1h 37m', 'Rating': '4.9', 'Voting': '(1.9K)'}
# {'Title': "119. The Devil's Bath", 'Genre': 'Thriller', 'Duration': '2h 1m', 'Rating': '6.6', 'Voting': '(6.9K)'}
# {'Title': '120. The Prosecutor', 'Genre': 'Thriller', 'Duration': '1h 57m', 'Rating': '6.6', 'Voting': '(2.8K)'}
# {'Title': '121. Utopia', 'Genre': 'Thriller', 'Duration': '1h 31m', 'Rating': '3.7', 'Voting': '(467)'}
# {'Title': '122. Alien: Rubicon', 'Genre': 'Thriller', 'Duration': '1h 26m', 'Rating': '2.4', 'Voting': '(529)'}
# {'Title': '123. Sting', 'Genre': 'Thriller', 'Duration': '1h 31m', 'Rating': '5.7', 'Voting': '(17K)'}
# {'Title': '124. King Ivory', 'Genre': 'Thriller', 'Duration': '2h 10m', 'Rating': '7.1', 'Voting': '(79)'}
# {'Title': '125. Outbreak', 'Genre': 'Thriller', 'Duration': '1h 28m', 'Rating': '4.4', 'Voting': '(1.3K)'}
# {'Title': '126. Force of Nature: The Dry 2', 'Genre': 'Thriller', 'Duration': '2h', 'Rating': '5.8', 'Voting': '(7.6K)'}
# {'Title': '127. Amongst the Wolves', 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '5.1', 'Voting': '(335)'}
# {'Title': '128. Santosh', 'Genre': 'Thriller', 'Duration': '2h 8m', 'Rating': '7.1', 'Voting': '(2.6K)'}
# {'Title': '129. A Sacrifice', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '5.0', 'Voting': '(5.8K)'}
# {'Title': '130. A Desert', 'Genre': 'Thriller', 'Duration': '1h 43m', 'Rating': '5.6', 'Voting': '(520)'}
# {'Title': '131. Night Call', 'Genre': 'Thriller', 'Duration': '1h 37m', 'Rating': '6.7', 'Voting': '(2.6K)'}
# {'Title': '132. Maldoror', 'Genre': 'Thriller', 'Duration': '2h 35m', 'Rating': '6.7', 'Voting': '(1.2K)'}
# {'Title': '133. The Smile Man', 'Genre': 'Thriller', 'Duration': '2h 2m', 'Rating': '7.3', 'Voting': '(1.8K)'}
# {'Title': '134. Life After Fighting', 'Genre': 'Thriller', 'Duration': '2h 6m', 'Rating': '6.4', 'Voting': '(2.2K)'}
# {'Title': '135. 2073', 'Genre': 'Thriller', 'Duration': '1h 25m', 'Rating': '5.1', 'Voting': '(3.3K)'}
# {'Title': '136. Sookshma Darshini', 'Genre': 'Thriller', 'Duration': '2h 22m', 'Rating': '7.8', 'Voting': '(11K)'}
# {'Title': '137. Winnie-the-Pooh: Blood and Honey 2', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '4.6', 'Voting': '(12K)'}
# {'Title': '138. V/H/S/Beyond', 'Genre': 'Thriller', 'Duration': '1h 54m', 'Rating': '5.8', 'Voting': '(10K)'}
# {'Title': '139. Inside', 'Genre': 'Thriller', 'Duration': '1h 44m', 'Rating': '6.8', 'Voting': '(361)'}
# {'Title': '140. The Inheritance', 'Genre': 'Thriller', 'Duration': '1h 25m', 'Rating': '4.7', 'Voting': '(3.1K)'}
# {'Title': '141. Afraid', 'Genre': 'Thriller', 'Duration': '1h 24m', 'Rating': '5.2', 'Voting': '(15K)'}
# {'Title': '142. Marco', 'Genre': 'Thriller', 'Duration': '2h 25m', 'Rating': '6.7', 'Voting': '(23K)'}
# {'Title': '143. The Old Bachelor', 'Genre': 'Thriller', 'Duration': '3h 12m', 'Rating': '8.2', 'Voting': '(768)'}
# {'Title': '144. Killer Heat', 'Genre': 'Thriller', 'Duration': '1h 35m', 'Rating': '5.6', 'Voting': '(14K)'}
# {'Title': '145. The Master and Margarita', 'Genre': 'Thriller', 'Duration': '2h 36m', 'Rating': '7.2', 'Voting': '(5.1K)'}
# {'Title': '146. Lembayung', 'Genre': 'Thriller', 'Duration': '2h 3m', 'Rating': '5.9', 'Voting': '(792)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '148. Kishkindha Kaandam', 'Genre': 'Thriller', 'Duration': '2h 13m', 'Rating': '8.0', 'Voting': '(13K)'}
# {'Title': '149. No Way Up', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '4.6', 'Voting': '(11K)'}
# {'Title': '150. The Corpse Washer', 'Genre': 'Thriller', 'Duration': '1h 47m', 'Rating': '6.1', 'Voting': '(1.3K)'}
# {'Title': '151. Depravity', 'Genre': 'Thriller', 'Duration': '1h 57m', 'Rating': '4.3', 'Voting': '(1.2K)'}
# {'Title': '152. Die Alone', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '5.8', 'Voting': '(4.1K)'}
# {'Title': '153. Bonhoeffer: Pastor. Spy. Assassin.', 'Genre': 'Thriller', 'Duration': '2h 13m', 'Rating': '6.2', 'Voting': '(4K)'}
# {'Title': '154. Cloud', 'Genre': 'Thriller', 'Duration': '2h 4m', 'Rating': '6.3', 'Voting': '(1.7K)'}
# {'Title': '155. The Exorcism', 'Genre': 'Thriller', 'Duration': '1h 35m', 'Rating': '4.2', 'Voting': '(12K)'}
# {'Title': '156. The Girl in the Pool', 'Genre': 'Thriller', 'Duration': '1h 29m', 'Rating': '4.3', 'Voting': '(1.6K)'}
# {'Title': '157. Boneyard', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '4.1', 'Voting': '(5.3K)'}
# {'Title': '158. Succubus', 'Genre': 'Thriller', 'Duration': '1h 43m', 'Rating': '4.6', 'Voting': '(1.4K)'}
# {'Title': '159. Something in the Water', 'Genre': 'Thriller', 'Duration': '1h 26m', 'Rating': '4.1', 'Voting': '(5.2K)'}
# {'Title': '160. The Wasp', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '6.1', 'Voting': '(5.2K)'}
# {'Title': '161. Devara Part 1', 'Genre': 'Thriller', 'Duration': '2h 56m', 'Rating': '6.0', 'Voting': '(21K)'}
# {'Title': "162. Barron's Cove", 'Genre': 'Thriller', 'Duration': '1h 56m', 'Rating': '6.3', 'Voting': '(307)'}
# {'Title': '163. Aftermath', 'Genre': 'Thriller', 'Duration': '1h 37m', 'Rating': '5.2', 'Voting': '(4.5K)'}
# {'Title': '164. Grafted', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '5.6', 'Voting': '(2.7K)'}
# {'Title': '165. Captain Miller', 'Genre': 'Thriller', 'Duration': '2h 37m', 'Rating': '7.2', 'Voting': '(14K)'}
# {'Title': '166. Undercover', 'Genre': 'Thriller', 'Duration': '1h 58m', 'Rating': '7.2', 'Voting': '(4.9K)'}
# {'Title': '167. Dead Talents Society', 'Genre': 'Thriller', 'Duration': '1h 51m', 'Rating': '7.0', 'Voting': '(2.7K)'}
# {'Title': '168. The Contract', 'Genre': 'Thriller', 'Duration': '1h 45m', 'Rating': '7.3', 'Voting': '(81)'}
# {'Title': '169. Sector 36', 'Genre': 'Thriller', 'Duration': '2h 3m', 'Rating': '7.1', 'Voting': '(26K)'}
# {'Title': '170. Pani', 'Genre': 'Thriller', 'Duration': '2h 23m', 'Rating': '6.9', 'Voting': '(3.4K)'}
# {'Title': '171. Baby John', 'Genre': 'Thriller', 'Duration': '2h 39m', 'Rating': '5.0', 'Voting': '(18K)'}
# {'Title': '172. Take Cover', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '5.1', 'Voting': '(2.9K)'}
# {'Title': '173. The Playroom', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '6.7', 'Voting': '(194)'}
# {'Title': '174. Yodha', 'Genre': 'Thriller', 'Duration': '2h 10m', 'Rating': '5.7', 'Voting': '(9K)'}
# {'Title': '175. Blackwater Lane', 'Genre': 'Thriller', 'Duration': '1h 48m', 'Rating': '4.6', 'Voting': '(2.4K)'}
# {'Title': '176. Dirty Boy', 'Genre': 'Thriller', 'Duration': '1h 38m', 'Rating': '7.5', 'Voting': '(40)'}
# {'Title': '177. The Painted', 'Genre': 'Thriller', 'Duration': '1h 25m', 'Rating': '4.8', 'Voting': '(1.2K)'}
# {'Title': '178. Bad Genius', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '6.2', 'Voting': '(2.6K)'}
# {'Title': '179. Rich Flu', 'Genre': 'Thriller', 'Duration': '1h 56m', 'Rating': '5.1', 'Voting': '(6.5K)'}
# {'Title': '180. Imaginary', 'Genre': 'Thriller', 'Duration': '1h 44m', 'Rating': '4.7', 'Voting': '(18K)'}
# {'Title': '181. Hold Your Breath', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '5.3', 'Voting': '(9K)'}
# {'Title': '182. Sumala', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '5.8', 'Voting': '(1.2K)'}
# {'Title': '183. The Hangman', 'Genre': 'Thriller', 'Duration': '1h 32m', 'Rating': '3.3', 'Voting': '(1.1K)'}
# {'Title': '184. Here After', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '4.2', 'Voting': '(1.8K)'}
# {'Title': '185. Trigger Warning', 'Genre': 'Thriller', 'Duration': '1h 46m', 'Rating': '4.6', 'Voting': '(20K)'}
# {'Title': '186. Outside', 'Genre': 'Thriller', 'Duration': '2h 22m', 'Rating': '5.1', 'Voting': '(4.9K)'}
# {'Title': '187. 11 Rebels', 'Genre': 'Thriller', 'Duration': '2h 35m', 'Rating': '6.3', 'Voting': '(786)'}
# {'Title': '188. River of Blood', 'Genre': 'Thriller', 'Duration': '1h 26m', 'Rating': '5.0', 'Voting': '(2K)'}
# {'Title': '189. Amber Alert', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '6.0', 'Voting': '(6.1K)'}
# {'Title': '190. Karma', 'Genre': 'Thriller', 'Duration': '2h 47m', 'Rating': '7.8', 'Voting': '(1.5K)'}
# {'Title': '191. Steppenwolf', 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '6.4', 'Voting': '(458)'}
# {'Title': '192. Wynonna Earp: Vengeance', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '5.5', 'Voting': '(1.7K)'}
# {'Title': '193. Twilight of the Warriors: Walled In', 'Genre': 'Thriller', 'Duration': '2h 6m', 'Rating': '6.9', 'Voting': '(11K)'}
# {'Title': '194. Motel Destino', 'Genre': 'Thriller', 'Duration': '1h 55m', 'Rating': '6.5', 'Voting': '(2.1K)'}
# {'Title': '195. Drive Back', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '4.5', 'Voting': '(678)'}
# {'Title': '196. Humane', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '5.5', 'Voting': '(7.7K)'}
# {'Title': '197. In Vitro', 'Genre': 'Thriller', 'Duration': '1h 29m', 'Rating': '6.0', 'Voting': '(226)'}
# {'Title': '198. Demon Slayer: Kimetsu No Yaiba - To the Hashira Training', 'Genre': 'Thriller', 'Duration': '1h 44m', 'Rating': '7.2', 'Voting': '(8.9K)'}
# {'Title': '199. The Greatest of All Time', 'Genre': 'Thriller', 'Duration': '3h 3m', 'Rating': '5.7', 'Voting': '(24K)'}
# {'Title': '200. Noise', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '6.2', 'Voting': '(119)'}
# {'Title': '201. Bramayugam', 'Genre': 'Thriller', 'Duration': '2h 19m', 'Rating': '7.8', 'Voting': '(15K)'}
# {'Title': '202. The Painter', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '4.7', 'Voting': '(2.4K)'}
# {'Title': '203. Red Right Hand', 'Genre': 'Thriller', 'Duration': '1h 51m', 'Rating': '5.5', 'Voting': '(6.1K)'}
# {'Title': '204. Cult Killer', 'Genre': 'Thriller', 'Duration': '1h 45m', 'Rating': '4.8', 'Voting': '(2.9K)'}
# {'Title': '205. Winner', 'Genre': 'Thriller', 'Duration': '1h 43m', 'Rating': '6.5', 'Voting': '(2.8K)'}
# {'Title': '206. I, the Executioner', 'Genre': 'Thriller', 'Duration': '1h 58m', 'Rating': '6.3', 'Voting': '(2.1K)'}
# {'Title': '207. Megamind vs. The Doom Syndicate', 'Genre': 'Thriller', 'Duration': '1h 23m', 'Rating': '2.5', 'Voting': '(5.8K)'}
# {'Title': '208. The Shadow Strays', 'Genre': 'Thriller', 'Duration': '2h 24m', 'Rating': '6.5', 'Voting': '(9.8K)'}
# {'Title': '209. Pins & Needles', 'Genre': 'Thriller', 'Duration': '1h 35m', 'Rating': '6.5', 'Voting': '(32)'}
# {'Title': '210. The Good Teacher', 'Genre': 'Thriller', 'Duration': '1h 31m', 'Rating': '6.6', 'Voting': '(2.1K)'}
# {'Title': '211. Shelby Oaks', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '5.8', 'Voting': '(263)'}
# {'Title': '212. Uprising', 'Genre': 'Thriller', 'Duration': '2h 6m', 'Rating': '6.6', 'Voting': '(6K)'}
# {'Title': '213. Code 8: Part II', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '5.7', 'Voting': '(16K)'}
# {'Title': '214. Bedspacer', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '4.5', 'Voting': '(388)'}
# {'Title': '215. Ghost Trail', 'Genre': 'Thriller', 'Duration': '1h 46m', 'Rating': '6.6', 'Voting': '(1K)'}
# {'Title': '216. Breathe', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '4.3', 'Voting': '(7.6K)'}
# {'Title': '217. Chief of Station', 'Genre': 'Thriller', 'Duration': '1h 37m', 'Rating': '4.7', 'Voting': '(4.9K)'}
# {'Title': '218. The Last Breath', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '4.7', 'Voting': '(2.6K)'}
# {'Title': '219. The Front Room', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '4.6', 'Voting': '(5.8K)'}
# {'Title': '220. Singham Again', 'Genre': 'Thriller', 'Duration': '2h 24m', 'Rating': '4.6', 'Voting': '(75K)'}
# {'Title': '221. Bougainvillea', 'Genre': 'Thriller', 'Duration': '2h 18m', 'Rating': '6.4', 'Voting': '(3.4K)'}
# {'Title': '222. Beezel', 'Genre': 'Thriller', 'Duration': '1h 21m', 'Rating': '4.9', 'Voting': '(1.6K)'}
# {'Title': '223. Long Gone Heroes', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '5.1', 'Voting': '(1.3K)'}
# {'Title': '224. Sons', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '6.4', 'Voting': '(2.3K)'}
# {'Title': '225. Hidden Face', 'Genre': 'Thriller', 'Duration': '1h 55m', 'Rating': '6.1', 'Voting': '(635)'}
# {'Title': '226. Race for Glory: Audi vs. Lancia', 'Genre': 'Thriller', 'Duration': '1h 49m', 'Rating': '5.8', 'Voting': '(5.1K)'}
# {'Title': '227. The Paradise of Thorns', 'Genre': 'Thriller', 'Duration': '2h 11m', 'Rating': '7.6', 'Voting': '(1.4K)'}
# {'Title': '228. 1 Million Followers', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '4.6', 'Voting': '(812)'}
# {'Title': '229. My Fault', 'Genre': 'Thriller', 'Duration': '2h', 'Rating': '4.2', 'Voting': '(7.2K)'}
# {'Title': '230. Butas', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '4.8', 'Voting': '(189)'}
# {'Title': '231. Shaitaan', 'Genre': 'Thriller', 'Duration': '2h 12m', 'Rating': '6.5', 'Voting': '(55K)'}
# {'Title': '232. Do Patti', 'Genre': 'Thriller', 'Duration': '2h 6m', 'Rating': '6.4', 'Voting': '(69K)'}
# {'Title': '233. The Mouse Trap', 'Genre': 'Thriller', 'Duration': '1h 20m', 'Rating': '2.4', 'Voting': '(3.6K)'}
# {'Title': '234. Grave Torture', 'Genre': 'Thriller', 'Duration': '1h 57m', 'Rating': '6.2', 'Voting': '(3.1K)'}
# {'Title': '235. Classified', 'Genre': 'Thriller', 'Duration': '1h 45m', 'Rating': '3.7', 'Voting': '(2.9K)'}
# {'Title': '236. The Price of Money: A Largo Winch Adventure', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '5.1', 'Voting': '(1.4K)'}
# {'Title': '237. The Kingdom', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '6.9', 'Voting': '(1.2K)'}
# {'Title': '238. Parallel', 'Genre': 'Thriller', 'Duration': '1h 28m', 'Rating': '5.3', 'Voting': '(2.1K)'}
# {'Title': '239. Elyas', 'Genre': 'Thriller', 'Duration': '1h 45m', 'Rating': '6.1', 'Voting': '(1.7K)'}
# {'Title': '240. Sikandar Ka Muqaddar', 'Genre': 'Thriller', 'Duration': '2h 22m', 'Rating': '5.9', 'Voting': '(25K)'}
# {'Title': '241. Salawahan', 'Genre': 'Thriller', 'Duration': '1h 56m', 'Rating': '4.4', 'Voting': '(483)'}
# {'Title': '242. Air Force One Down', 'Genre': 'Thriller', 'Duration': '1h 24m', 'Rating': '4.4', 'Voting': '(3K)'}
# {'Title': '243. How to Make a Killing', 'Genre': 'Thriller', 'Duration': '1h 49m', 'Rating': '6.5', 'Voting': '(1.5K)'}
# {'Title': '244. Prey', 'Genre': 'Thriller', 'Duration': '1h 26m', 'Rating': '3.7', 'Voting': '(3.5K)'}
# {'Title': '245. Kryptic', 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '4.0', 'Voting': '(648)'}
# {'Title': '246. Badland Hunters', 'Genre': 'Thriller', 'Duration': '1h 47m', 'Rating': '5.9', 'Voting': '(13K)'}
# {'Title': '247. The Soul Eater', 'Genre': 'Thriller', 'Duration': '1h 48m', 'Rating': '5.8', 'Voting': '(3.1K)'}
# {'Title': "248. Tyler Perry's Divorce in the Black", 'Genre': 'Thriller', 'Duration': '2h 23m', 'Rating': '4.6', 'Voting': '(3.7K)'}
# {'Title': '249. Things Will Be Different', 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '5.2', 'Voting': '(2.9K)'}
# {'Title': '250. We Bury the Dead', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '6.9', 'Voting': '(124)'}
# {'Title': '251. Raayan', 'Genre': 'Thriller', 'Duration': '2h 25m', 'Rating': '6.5', 'Voting': '(12K)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '253. Unit 234', 'Genre': 'Thriller', 'Duration': '1h 26m', 'Rating': '5.4', 'Voting': '(859)'}
# {'Title': '254. Lazareth', 'Genre': 'Thriller', 'Duration': '1h 26m', 'Rating': '4.4', 'Voting': '(1K)'}
# {'Title': '255. Everyone Is Going to Die', 'Genre': 'Thriller', 'Duration': '1h 24m', 'Rating': '3.9', 'Voting': '(373)'}
# {'Title': '256. Levels', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '5.0', 'Voting': '(1.6K)'}
# {'Title': '257. Lake George', 'Genre': 'Thriller', 'Duration': '1h 58m', 'Rating': '6.5', 'Voting': '(1.6K)'}
# {'Title': '258. Black', 'Genre': 'Thriller', 'Duration': '1h 55m', 'Rating': '7.1', 'Voting': '(2.9K)'}
# {'Title': '259. The Wages of Fear', 'Genre': 'Thriller', 'Duration': '1h 44m', 'Rating': '4.6', 'Voting': '(4.2K)'}
# {'Title': '260. Maharaj', 'Genre': 'Thriller', 'Duration': '2h 11m', 'Rating': '6.5', 'Voting': '(15K)'}
# {'Title': '261. Queen of Bones', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '4.7', 'Voting': '(289)'}
# {'Title': '262. Lights Out', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '4.9', 'Voting': '(1.9K)'}
# {'Title': '263. Despatch', 'Genre': 'Thriller', 'Duration': '2h 33m', 'Rating': '4.4', 'Voting': '(4.6K)'}
# {'Title': '264. Blue Lock: Episode Nagi', 'Genre': 'Thriller', 'Duration': '1h 31m', 'Rating': '6.6', 'Voting': '(2.7K)'}
# {'Title': '265. The Correspondent', 'Genre': 'Thriller', 'Duration': '1h 59m', 'Rating': '7.4', 'Voting': '(138)'}
# {'Title': '266. Thalavan', 'Genre': 'Thriller', 'Duration': '2h 11m', 'Rating': '7.2', 'Voting': '(5.4K)'}
# {'Title': '267. The Calendar Killer', 'Genre': 'Thriller', 'Duration': '1h 37m', 'Rating': '5.4', 'Voting': '(4.5K)'}
# {'Title': '268. Dead Money', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '5.8', 'Voting': '(763)'}
# {'Title': '269. Hisaab Barabar', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '5.8', 'Voting': '(1.9K)'}
# {'Title': '270. 5lbs of Pressure', 'Genre': 'Thriller', 'Duration': '1h 51m', 'Rating': '5.2', 'Voting': '(1.8K)'}
# {'Title': '271. Saripodhaa Sanivaaram', 'Genre': 'Thriller', 'Duration': '2h 46m', 'Rating': '7.0', 'Voting': '(10K)'}
# {'Title': '272. Green Bones', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '7.0', 'Voting': '(504)'}
# {'Title': '273. The Roundup: Punishment', 'Genre': 'Thriller', 'Duration': '1h 49m', 'Rating': '6.6', 'Voting': '(5.8K)'}
# {'Title': '274. Armor', 'Genre': 'Thriller', 'Duration': '1h 29m', 'Rating': '3.6', 'Voting': '(4.6K)'}
# {'Title': '275. Bloodline Killer', 'Genre': 'Thriller', 'Duration': '1h 45m', 'Rating': '4.2', 'Voting': '(5.2K)'}
# {'Title': '276. Vanished Into the Night', 'Genre': 'Thriller', 'Duration': '1h 32m', 'Rating': '5.2', 'Voting': '(4.9K)'}
# {'Title': '277. One More Shot', 'Genre': 'Thriller', 'Duration': '1h 43m', 'Rating': '5.4', 'Voting': '(3.9K)'}
# {'Title': '278. The Thundermans Return', 'Genre': 'Thriller', 'Duration': '1h 10m', 'Rating': '5.0', 'Voting': '(1.9K)'}
# {'Title': '279. Dedalus', 'Genre': 'Thriller', 'Duration': '1h 32m', 'Rating': '7.8', 'Voting': '(48)'}
# {'Title': '280. Spark', 'Genre': 'Thriller', 'Duration': '1h 50m', 'Rating': '5.4', 'Voting': '(63)'}
# {'Title': '281. The Shameless', 'Genre': 'Thriller', 'Duration': '1h 54m', 'Rating': '5.9', 'Voting': '(325)'}
# {'Title': '282. Crescent City', 'Genre': 'Thriller', 'Duration': '1h 43m', 'Rating': '3.9', 'Voting': '(1.5K)'}
# {'Title': '283. Bade Miyan Chote Miyan', 'Genre': 'Thriller', 'Duration': '2h 43m', 'Rating': '3.8', 'Voting': '(40K)'}
# {'Title': '284. Iconic', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '5.2', 'Voting': '(451)'}
# {'Title': '285. Freedom', 'Genre': 'Thriller', 'Duration': '1h 50m', 'Rating': '5.9', 'Voting': '(1.5K)'}
# {'Title': '286. Beyond the Rush', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '8.6', 'Voting': '(946)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '288. The Silent Planet', 'Genre': 'Thriller', 'Duration': '1h 35m', 'Rating': '4.7', 'Voting': '(301)'}
# {'Title': '289. Harbin', 'Genre': 'Thriller', 'Duration': '1h 48m', 'Rating': '6.2', 'Voting': '(1K)'}
# {'Title': '290. Hijack 1971', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '6.8', 'Voting': '(3.5K)'}
# {'Title': '291. Dominique', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '5.3', 'Voting': '(2.4K)'}
# {'Title': '292. Colors of Evil: Red', 'Genre': 'Thriller', 'Duration': '1h 51m', 'Rating': '6.4', 'Voting': '(8.8K)'}
# {'Title': '293. Last Night on Earth', 'Genre': 'Thriller', 'Duration': '1h 26m', 'Rating': '4.7', 'Voting': '(421)'}
# {'Title': '294. Marmalade', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '6.3', 'Voting': '(3.8K)'}
# {'Title': '295. Bagheera', 'Genre': 'Thriller', 'Duration': '2h 38m', 'Rating': '6.7', 'Voting': '(7.7K)'}
# {'Title': '296. McVeigh', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '4.5', 'Voting': '(595)'}
# {'Title': '297. Clear Cut', 'Genre': 'Thriller', 'Duration': '1h 28m', 'Rating': '3.7', 'Voting': '(595)'}
# {'Title': '298. Arena Wars', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '5.5', 'Voting': '(3.2K)'}
# {'Title': '299. The Image of You', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '4.6', 'Voting': '(900)'}
# {'Title': '300. Death Whisperer 2', 'Genre': 'Thriller', 'Duration': '1h 50m', 'Rating': '6.3', 'Voting': '(1.6K)'}
# {'Title': '301. Operation: Raqqa', 'Genre': 'Thriller', 'Duration': '1h 47m', 'Rating': '5.6', 'Voting': '(315)'}
# {'Title': '302. Hunt', 'Genre': 'Thriller', 'Duration': '2h', 'Rating': '3.8', 'Voting': '(146)'}
# {'Title': '303. Hunting Matthew Nichols', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '8.8', 'Voting': '(52)'}
# {'Title': '304. Waves', 'Genre': 'Thriller', 'Duration': '2h 11m', 'Rating': '7.9', 'Voting': '(2.1K)'}
# {'Title': '305. Black Cab', 'Genre': 'Thriller', 'Duration': '1h 28m', 'Rating': '4.1', 'Voting': '(1.9K)'}
# {'Title': '306. Mandara', 'Genre': 'Thriller', 'Duration': '2h 12m', 'Rating': '7.8', 'Voting': '(78)'}
# {'Title': '307. Shell', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '6.8', 'Voting': '(79)'}
# {'Title': '308. What Happened to Suzy', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '6.4', 'Voting': '(89)'}
# {'Title': '309. Abraham Ozler', 'Genre': 'Thriller', 'Duration': '2h 23m', 'Rating': '6.6', 'Voting': '(4.5K)'}
# {'Title': '310. Article 370', 'Genre': 'Thriller', 'Duration': '2h 38m', 'Rating': '7.8', 'Voting': '(25K)'}
# {'Title': '311. Out Come the Wolves', 'Genre': 'Thriller', 'Duration': '1h 26m', 'Rating': '4.7', 'Voting': '(1.8K)'}
# {'Title': '312. Fear', 'Genre': 'Thriller', 'Duration': '1h 55m', 'Rating': '8.1', 'Voting': '(2.8K)'}
# {'Title': '313. Blink', 'Genre': 'Thriller', 'Duration': '2h 16m', 'Rating': '6.9', 'Voting': '(1.6K)'}
# {'Title': '314. Sugar Baby', 'Genre': 'Thriller', 'Duration': '1h 28m', 'Rating': '3.9', 'Voting': '(419)'}
# {'Title': '315. Gazer', 'Genre': 'Thriller', 'Duration': '1h 54m', 'Rating': '6.0', 'Voting': '(208)'}
# {'Title': '316. Held Hostage in My House', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '4.7', 'Voting': '(150)'}
# {'Title': '317. Eat the Night', 'Genre': 'Thriller', 'Duration': '1h 46m', 'Rating': '6.0', 'Voting': '(586)'}
# {'Title': '318. Seeds', 'Genre': 'Thriller', 'Duration': '1h 22m', 'Rating': '4.9', 'Voting': '(240)'}
# {'Title': '319. The Haunted Apartment: Miss K', 'Genre': 'Thriller', 'Duration': '1h 43m', 'Rating': '5.6', 'Voting': '(508)'}
# {'Title': '320. Boundless', 'Genre': 'Thriller', 'Duration': '2h 1m', 'Rating': '5.6', 'Voting': '(2.1K)'}
# {'Title': '321. She Came Back', 'Genre': 'Thriller', 'Duration': '1h 23m', 'Rating': '5.3', 'Voting': '(101)'}
# {'Title': '322. Blame the Game', 'Genre': 'Thriller', 'Duration': '1h 32m', 'Rating': '5.4', 'Voting': '(5.4K)'}
# {'Title': '323. Viduthalai Part 2', 'Genre': 'Thriller', 'Duration': '2h 50m', 'Rating': '7.8', 'Voting': '(17K)'}
# {'Title': '324. Mond', 'Genre': 'Thriller', 'Duration': '1h 32m', 'Rating': '7.0', 'Voting': '(349)'}
# {'Title': '325. Bogota: City of the Lost', 'Genre': 'Thriller', 'Duration': '1h 48m', 'Rating': '5.4', 'Voting': '(2.1K)'}
# {'Title': '326. Invasion', 'Genre': 'Thriller', 'Duration': '1h 31m', 'Rating': '4.8', 'Voting': '(759)'}
# {'Title': '327. Goldilocks and the Three Bears: Death and Porridge', 'Genre': 'Thriller', 'Duration': '1h 22m', 'Rating': '2.2', 'Voting': '(2K)'}
# {'Title': '328. Disciples in the Moonlight', 'Genre': 'Thriller', 'Duration': '2h 6m', 'Rating': '3.8', 'Voting': '(698)'}
# {'Title': '329. Bosco', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '5.5', 'Voting': '(4K)'}
# {'Title': '330. Merry Christmas', 'Genre': 'Thriller', 'Duration': '2h 24m', 'Rating': '6.9', 'Voting': '(30K)'}
# {'Title': '331. Demonte Colony 2', 'Genre': 'Thriller', 'Duration': '2h 24m', 'Rating': '6.6', 'Voting': '(4.6K)'}
# {'Title': '332. Escape', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '6.4', 'Voting': '(2.3K)'}
# {'Title': '333. Frankenstein: Legacy', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '3.7', 'Voting': '(212)'}
# {'Title': '334. Campton Manor', 'Genre': 'Thriller', 'Duration': '1h 23m', 'Rating': '3.4', 'Voting': '(245)'}
# {'Title': '335. Anweshippin Kandethum', 'Genre': 'Thriller', 'Duration': '2h 22m', 'Rating': '7.4', 'Voting': '(11K)'}
# {'Title': '336. Boksi Ko Ghar', 'Genre': 'Thriller', 'Duration': '1h 56m', 'Rating': '7.7', 'Voting': '(960)'}
# {'Title': "337. Cinderella's Curse", 'Genre': 'Thriller', 'Duration': '1h 22m', 'Rating': '3.4', 'Voting': '(1.4K)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '339. Where Is Gilgamesh?', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '8.9', 'Voting': '(639)'}
# {'Title': '340. Kurukku', 'Genre': 'Thriller', 'Duration': '1h 49m', 'Rating': '6.3', 'Voting': '(541)'}
# {'Title': '341. Phir Aayi Hasseen Dillruba', 'Genre': 'Thriller', 'Duration': '2h 12m', 'Rating': '5.8', 'Voting': '(7K)'}
# {'Title': '342. House of Spoils', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '5.0', 'Voting': '(4K)'}
# {'Title': '343. Here Now', 'Genre': 'Thriller', 'Duration': '1h 58m', 'Rating': '4.9', 'Voting': '(491)'}
# {'Title': '344. Milk & Serial', 'Genre': 'Thriller', 'Duration': '1h 2m', 'Rating': '6.6', 'Voting': '(2.7K)'}
# {'Title': '345. Strictly Confidential', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '2.8', 'Voting': '(884)'}
# {'Title': '346. Footage', 'Genre': 'Thriller', 'Duration': '2h 4m', 'Rating': '4.9', 'Voting': '(2.4K)'}
# {'Title': "347. You Can't Run Forever", 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '4.5', 'Voting': '(4.5K)'}
# {'Title': '348. Love Me Dead', 'Genre': 'Thriller', 'Duration': '1h 27m', 'Rating': '6.8', 'Voting': '(44)'}
# {'Title': '349. A Mistake', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '5.6', 'Voting': '(1.1K)'}
# {'Title': '350. Till Death Do Us Part', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '6.2', 'Voting': '(185)'}
# {'Title': '351. Barda', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '4.6', 'Voting': '(692)'}
# {'Title': '352. The Sand Castle', 'Genre': 'Thriller', 'Duration': '1h 38m', 'Rating': '4.7', 'Voting': '(1.8K)'}
# {'Title': '353. Three Kilometres to the End of the World', 'Genre': 'Thriller', 'Duration': '1h 45m', 'Rating': '7.1', 'Voting': '(1.2K)'}
# {'Title': '354. The Last Front', 'Genre': 'Thriller', 'Duration': '1h 38m', 'Rating': '5.5', 'Voting': '(650)'}
# {'Title': '355. Sunrise', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '3.9', 'Voting': '(1.2K)'}
# {'Title': '356. #AMFAD: All My Friends Are Dead', 'Genre': 'Thriller', 'Duration': '1h 31m', 'Rating': '4.5', 'Voting': '(1.3K)'}
# {'Title': '357. Operation Laila', 'Genre': 'Thriller', 'Duration': '2h 3m', 'Rating': '5.5', 'Voting': '(56)'}
# {'Title': '358. Way Home', 'Genre': 'Thriller', 'Duration': '1h 38m', 'Rating': '6.4', 'Voting': '(1.5K)'}
# {'Title': '359. Reawakening', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '6.2', 'Voting': '(403)'}
# {'Title': '360. Tezgah', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '5.4', 'Voting': '(204)'}
# {'Title': '361. Cold Wallet', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '5.1', 'Voting': '(651)'}
# {'Title': '362. Transplant', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '8.4', 'Voting': '(26)'}
# {'Title': '363. The Kingdom', 'Genre': 'Thriller', 'Duration': '2h 13m', 'Rating': '7.0', 'Voting': '(156)'}
# {'Title': '364. The Sleeping Woman', 'Genre': 'Thriller', 'Duration': '1h 50m', 'Rating': '5.3', 'Voting': '(604)'}
# {'Title': '365. Dead Sea', 'Genre': 'Thriller', 'Duration': '1h 28m', 'Rating': '5.2', 'Voting': '(5.5K)'}
# {'Title': '366. The Matriarch', 'Genre': 'Thriller', 'Duration': '1h 22m', 'Rating': '6.5', 'Voting': '(29)'}
# {'Title': '367. Mia', 'Genre': 'Thriller', 'Duration': '1h 21m', 'Rating': '8.9', 'Voting': '(293)'}
# {'Title': '368. In Flight', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '3.6', 'Voting': '(252)'}
# {'Title': '369. Una ballena', 'Genre': 'Thriller', 'Duration': '1h 48m', 'Rating': '5.6', 'Voting': '(188)'}
# {'Title': '370. Borderless Fog', 'Genre': 'Thriller', 'Duration': '1h 50m', 'Rating': '5.2', 'Voting': '(1.3K)'}
# {'Title': '371. War Game', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '5.5', 'Voting': '(640)'}
# {'Title': '372. Kanguva', 'Genre': 'Thriller', 'Duration': '2h 32m', 'Rating': '4.5', 'Voting': '(15K)'}
# {'Title': '373. Le Mohican', 'Genre': 'Thriller', 'Duration': '1h 27m', 'Rating': '6.8', 'Voting': '(275)'}
# {'Title': '374. Haunt Season', 'Genre': 'Thriller', 'Duration': '1h 21m', 'Rating': '4.9', 'Voting': '(907)'}
# {'Title': '375. Unexposed', 'Genre': 'Thriller', 'Duration': '1h 3m', 'Rating': '7.8', 'Voting': '(74)'}
# {'Title': '376. Jigra', 'Genre': 'Thriller', 'Duration': '2h 33m', 'Rating': '6.0', 'Voting': '(24K)'}
# {'Title': '377. Customs Frontline', 'Genre': 'Thriller', 'Duration': '1h 55m', 'Rating': '5.5', 'Voting': '(546)'}
# {'Title': '378. Puntos suspensivos', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '6.1', 'Voting': '(489)'}
# {'Title': '379. The Weekend', 'Genre': 'Thriller', 'Duration': '1h 57m', 'Rating': '6.2', 'Voting': '(69)'}
# {'Title': '380. Shark Warning', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '3.5', 'Voting': '(386)'}
# {'Title': "381. Hemet, or the Landlady Don't Drink Tea", 'Genre': 'Thriller', 'Duration': '1h 29m', 'Rating': '4.3', 'Voting': '(96)'}
# {'Title': '382. The Courier', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '6.0', 'Voting': '(4.6K)'}
# {'Title': '383. Dead Whisper', 'Genre': 'Thriller', 'Duration': '1h 28m', 'Rating': '3.8', 'Voting': '(566)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '385. Bitter Gold', 'Genre': 'Thriller', 'Duration': '1h 23m', 'Rating': '8.1', 'Voting': '(62)'}
# {'Title': '386. Above the Knee', 'Genre': 'Thriller', 'Duration': '1h 16m', 'Rating': '6.3', 'Voting': '(72)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '388. Séance', 'Genre': 'Thriller', 'Duration': '1h 25m', 'Rating': '8.0', 'Voting': '(27)'}
# {'Title': '389. CTRL', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '6.2', 'Voting': '(6.4K)'}
# {'Title': '390. Mong Vuot', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '5.0', 'Voting': '(176)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '393. Sway', 'Genre': 'Thriller', 'Duration': '1h 39m', 'Rating': '8.1', 'Voting': '(21)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '395. Thiru.Manickam', 'Genre': 'Thriller', 'Duration': '2h 2m', 'Rating': '8.0', 'Voting': '(2.6K)'}
# {'Title': '396. The Clean Up Crew', 'Genre': 'Thriller', 'Duration': '1h 35m', 'Rating': '4.2', 'Voting': '(1.3K)'}
# {'Title': '397. Mafia Wars', 'Genre': 'Thriller', 'Duration': '1h 38m', 'Rating': '3.6', 'Voting': '(296)'}
# {'Title': '398. The Sabarmati Report', 'Genre': 'Thriller', 'Duration': '2h 7m', 'Rating': '6.4', 'Voting': '(25K)'}
# {'Title': '399. S.T.A.L.K.E.R.: Shadow of the Zone', 'Genre': 'Thriller', 'Duration': '1h 11m', 'Rating': '4.8', 'Voting': '(658)'}
# {'Title': '400. Scorched Earth', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '6.7', 'Voting': '(651)'}
# {'Title': "401. Hijack '93", 'Genre': 'Thriller', 'Duration': '1h 27m', 'Rating': '3.8', 'Voting': '(955)'}
# {'Title': '402. Darkness of Man', 'Genre': 'Thriller', 'Duration': '1h 49m', 'Rating': '4.7', 'Voting': '(3.3K)'}
# {'Title': '403. Unpredictable', 'Genre': 'Thriller', 'Duration': '1h 41m', 'Rating': '5.4', 'Voting': '(424)'}
# {'Title': '404. Logout', 'Genre': 'Thriller', 'Duration': '1h 48m', 'Rating': '7.2', 'Voting': '(1.3K)'}
# {'Title': '405. Taboo: Family Secrets', 'Genre': 'Thriller', 'Duration': '1h 35m', 'Rating': '7.1', 'Voting': '(766)'}
# {'Title': '406. The Diary', 'Genre': 'Thriller', 'Duration': '1h 22m', 'Rating': '5.0', 'Voting': '(1K)'}
# {'Title': '407. Vedaa', 'Genre': 'Thriller', 'Duration': '2h 25m', 'Rating': '6.0', 'Voting': '(4.5K)'}
# {'Title': '408. Operation Valentine', 'Genre': 'Thriller', 'Duration': '2h 13m', 'Rating': '5.3', 'Voting': '(1.6K)'}
# {'Title': '409. Succubus', 'Genre': 'Thriller', 'Duration': '1h 36m', 'Rating': '3.5', 'Voting': '(902)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '411. Somebody', 'Genre': 'Thriller', 'Duration': '1h 52m', 'Rating': '7.6', 'Voting': '(93)'}
# {'Title': '412. American Star', 'Genre': 'Thriller', 'Duration': '1h 47m', 'Rating': '5.5', 'Voting': '(2.6K)'}
# {'Title': '413. Out of Control', 'Genre': 'Thriller', 'Duration': '1h 51m', 'Rating': '5.7', 'Voting': '(177)'}
# {'Title': '414. Uninvited', 'Genre': 'Thriller', 'Duration': '1h 33m', 'Rating': '5.6', 'Voting': '(355)'}
# {'Title': '415. Ulajh', 'Genre': 'Thriller', 'Duration': '2h 30m', 'Rating': '6.0', 'Voting': '(24K)'}
# {'Title': '416. KA', 'Genre': 'Thriller', 'Duration': '2h 31m', 'Rating': '7.0', 'Voting': '(1.7K)'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '418. Ferry 2', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '5.6', 'Voting': '(4K)'}
# {'Title': '419. Ghost Game', 'Genre': 'Thriller', 'Duration': '1h 26m', 'Rating': '3.4', 'Voting': '(382)'}
# {'Title': '420. Latency', 'Genre': 'Thriller', 'Duration': '1h 34m', 'Rating': '4.2', 'Voting': '(3K)'}
# {'Title': '421. Savi', 'Genre': 'Thriller', 'Duration': '2h 6m', 'Rating': '6.1', 'Voting': '(35K)'}
# {'Title': '422. Rippy', 'Genre': 'Thriller', 'Duration': '1h 23m', 'Rating': '4.2', 'Voting': '(1K)'}
# {'Title': '423. Case of Kondana', 'Genre': 'Thriller', 'Duration': '2h 23m', 'Rating': '5.8', 'Voting': '(727)'}
# {'Title': '424. Following', 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '6.5', 'Voting': '(1.5K)'}
# {'Title': '425. Blood Star', 'Genre': 'Thriller', 'Duration': '1h 37m', 'Rating': '6.3', 'Voting': '(6.2K)'}
# {'Title': '426. Why Do You?', 'Genre': 'Thriller', 'Duration': '1h 43m', 'Rating': '5.3', 'Voting': '(482)'}
# {'Title': '427. Martin', 'Genre': 'Thriller', 'Duration': '2h 27m', 'Rating': '2.2', 'Voting': '(36K)'}
# {'Title': '428. Bhaje Vaayu Vegam', 'Genre': 'Thriller', 'Duration': '2h 16m', 'Rating': '6.1', 'Voting': '(772)'}
# {'Title': '429. Hard Home', 'Genre': 'Thriller', 'Duration': '1h 27m', 'Rating': '4.1', 'Voting': '(744)'}
# {'Title': '430. Matka', 'Genre': 'Thriller', 'Duration': '2h 36m', 'Rating': '4.7', 'Voting': '(609)'}
# {'Title': '431. Kidnapping Inc.', 'Genre': 'Thriller', 'Duration': '1h 47m', 'Rating': '6.0', 'Voting': '(311)'}
# {'Title': '432. Scurry', 'Genre': 'Thriller', 'Duration': '1h 30m', 'Rating': '7.6', 'Voting': '(26)'}
# {'Title': '433. The Death That Awaits', 'Genre': 'Thriller', 'Duration': '1h 42m', 'Rating': '5.0', 'Voting': '(792)'}
# {'Title': '434. Peter Five Eight', 'Genre': 'Thriller', 'Duration': '1h 40m', 'Rating': '3.5', 'Voting': '(1.1K)'}
# {'Title': '435. Run Baby Run', 'Genre': 'Thriller', 'Duration': '1h 38m', 'Rating': '4.6', 'Voting': '(43)'}
# ...
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Thriller', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}

# %%
#common csv converting code

import pandas as pd

df=pd.DataFrame(movie_list)

# 1. Remove leading numbers from "Title"
df["Title"] = df["Title"].str.replace(r"^\d+\.\s*", "", regex=True)

# 2. Remove parentheses from "Voting"
df["Voting"] = df["Voting"].str.replace(r"[()]", "", regex=True)

# 3. Reset index to start from 1
df.index = df.index + 1

df.to_csv(r"D:\Nirosha\GUVI\Project\Thriller.csv", index=False, encoding="utf-8")
print(r"CSV file - Thriller Movie saved successfully!")
# Out:
# CSV file - Thriller Movie saved successfully!

# %%
# Romance movies 

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

# Initialize WebDriver
driver = webdriver.Chrome()
driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=romance")

time.sleep(5)  # Waiting for the page to load

genre = "Romance"

# Scroll Until No More New Data Loads
scroll = True
movies_per_page = 50  # Assuming each load gives 50 movies
total_movies = 500
current_movies = 0

while scroll and current_movies < total_movies:
    old_page_source = driver.page_source  # Save old page source
    
    # Scroll down to load more data
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Allow time for new data to load
    
    new_page_source = driver.page_source  # Save new page source

    if new_page_source == old_page_source:
        try:
            # Locate and click the "See More" button if present
            see_more_button = driver.find_element(By.XPATH, "//span[contains(@class, 'ipc-see-more')]")
            ActionChains(driver).move_to_element(see_more_button).click().perform()
            time.sleep(3)  # Wait for new content to load
        except Exception:
            scroll = False  # Stop scrolling if button isn't found
    else:
        current_movies += movies_per_page  # Increment count

# Extract movie containers
movie_block = driver.find_elements(By.CSS_SELECTOR, "li.ipc-metadata-list-summary-item")

movie_list = []

for movie in movie_block:
    try:
        title = movie.find_element(By.CSS_SELECTOR, "h3.ipc-title__text").text.strip()
        duration_element = movie.find_element(By.XPATH, ".//span[contains(@class, 'dli-title-metadata-item') and (contains(text(),'h') or contains(text(),'m'))]")
        duration = duration_element.text.strip() if duration_element.text.strip() else "N/A"
        rating = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--rating").text.strip()
        voting = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--voteCount").text.strip()

    except:
        title = "N/A"
        duration = "N/A"
        rating = "N/A"
        voting = "N/A"

    movie_data = {
        "Title": title,
        "Genre": genre,
        "Duration": duration,
        "Rating": rating,
        "Voting": voting,
    }
    movie_list.append(movie_data)

# Print results
for movie in movie_list:
    print(movie)

# Close the driver
driver.quit()
# Out:
# {'Title': '1. Wicked', 'Genre': 'Romance', 'Duration': '2h 40m', 'Rating': '7.4', 'Voting': '(174K)'}
# {'Title': '2. Anora', 'Genre': 'Romance', 'Duration': '2h 19m', 'Rating': '7.5', 'Voting': '(211K)'}
# {'Title': '3. We Live in Time', 'Genre': 'Romance', 'Duration': '1h 48m', 'Rating': '7.0', 'Voting': '(59K)'}
# {'Title': '4. Babygirl', 'Genre': 'Romance', 'Duration': '1h 54m', 'Rating': '5.8', 'Voting': '(65K)'}
# {'Title': '5. The Fall Guy', 'Genre': 'Romance', 'Duration': '2h 6m', 'Rating': '6.8', 'Voting': '(229K)'}
# {'Title': '6. The Count of Monte-Cristo', 'Genre': 'Romance', 'Duration': '2h 58m', 'Rating': '7.6', 'Voting': '(38K)'}
# {'Title': '7. It Ends with Us', 'Genre': 'Romance', 'Duration': '2h 10m', 'Rating': '6.3', 'Voting': '(90K)'}
# {'Title': '8. Challengers', 'Genre': 'Romance', 'Duration': '2h 11m', 'Rating': '7.0', 'Voting': '(160K)'}
# {'Title': '9. The Idea of You', 'Genre': 'Romance', 'Duration': '1h 55m', 'Rating': '6.3', 'Voting': '(76K)'}
# {'Title': '10. Fly Me to the Moon', 'Genre': 'Romance', 'Duration': '2h 12m', 'Rating': '6.6', 'Voting': '(53K)'}
# {'Title': '11. Else', 'Genre': 'Romance', 'Duration': '1h 42m', 'Rating': '5.6', 'Voting': '(425)'}
# {'Title': '12. My Old Ass', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '6.9', 'Voting': '(42K)'}
# {'Title': '13. The Crow', 'Genre': 'Romance', 'Duration': '1h 51m', 'Rating': '4.7', 'Voting': '(37K)'}
# {'Title': '14. On Swift Horses', 'Genre': 'Romance', 'Duration': '1h 59m', 'Rating': '6.0', 'Voting': '(2.7K)'}
# {'Title': '15. Queer', 'Genre': 'Romance', 'Duration': '2h 17m', 'Rating': '6.4', 'Voting': '(24K)'}
# {'Title': '16. The Greatest Hits', 'Genre': 'Romance', 'Duration': '1h 34m', 'Rating': '6.2', 'Voting': '(7.8K)'}
# {'Title': '17. Love Lies Bleeding', 'Genre': 'Romance', 'Duration': '1h 44m', 'Rating': '6.6', 'Voting': '(59K)'}
# {'Title': '18. Mon Potongo', 'Genre': 'Romance', 'Duration': '2h 29m', 'Rating': '4.7', 'Voting': '(759)'}
# {'Title': '19. F*** Marry Kill', 'Genre': 'Romance', 'Duration': '1h 37m', 'Rating': '5.3', 'Voting': '(3.4K)'}
# {'Title': '20. All We Imagine as Light', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '7.1', 'Voting': '(11K)'}
# {'Title': '21. Bonjour Tristesse', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '5.8', 'Voting': '(576)'}
# {'Title': '22. A Family Affair', 'Genre': 'Romance', 'Duration': '1h 51m', 'Rating': '5.4', 'Voting': '(38K)'}
# {'Title': '23. A Nice Indian Boy', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '7.4', 'Voting': '(2.6K)'}
# {'Title': '24. Young Hearts', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '7.9', 'Voting': '(6K)'}
# {'Title': '25. Emmanuelle', 'Genre': 'Romance', 'Duration': '1h 47m', 'Rating': '4.1', 'Voting': '(2K)'}
# {'Title': '26. Culpa Tuya', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '5.2', 'Voting': '(14K)'}
# {'Title': '27. Spaceman', 'Genre': 'Romance', 'Duration': '1h 47m', 'Rating': '5.7', 'Voting': '(44K)'}
# {'Title': '28. Turtles All the Way Down', 'Genre': 'Romance', 'Duration': '1h 51m', 'Rating': '6.6', 'Voting': '(7.6K)'}
# {'Title': '29. Young Woman and the Sea', 'Genre': 'Romance', 'Duration': '2h 9m', 'Rating': '7.5', 'Voting': '(18K)'}
# {'Title': '30. Ask Me What You Want', 'Genre': 'Romance', 'Duration': '1h 54m', 'Rating': '3.9', 'Voting': '(1.3K)'}
# {'Title': '31. Dreams (Sex Love)', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '7.6', 'Voting': '(934)'}
# {'Title': '32. Jane Austen Wrecked My Life', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '6.4', 'Voting': '(964)'}
# {'Title': '33. Love Across Time', 'Genre': 'Romance', 'Duration': '1h', 'Rating': '7.1', 'Voting': '(866)'}
# {'Title': '34. Winter Spring Summer or Fall', 'Genre': 'Romance', 'Duration': '1h 37m', 'Rating': '6.0', 'Voting': '(3.2K)'}
# {'Title': '35. Role Play', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '5.5', 'Voting': '(19K)'}
# {'Title': '36. Upgraded', 'Genre': 'Romance', 'Duration': '1h 44m', 'Rating': '6.1', 'Voting': '(31K)'}
# {'Title': '37. Lonely Planet', 'Genre': 'Romance', 'Duration': '1h 34m', 'Rating': '5.7', 'Voting': '(12K)'}
# {'Title': '38. Love Me', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '5.1', 'Voting': '(3.1K)'}
# {'Title': '39. Wild Wild Punjab', 'Genre': 'Romance', 'Duration': '1h 49m', 'Rating': '6.2', 'Voting': '(16K)'}
# {'Title': '40. Lisa Frankenstein', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '6.1', 'Voting': '(29K)'}
# {'Title': '41. Love Li', 'Genre': 'Romance', 'Duration': '2h 48m', 'Rating': '6.4', 'Voting': '(14K)'}
# {'Title': '42. Your Monster', 'Genre': 'Romance', 'Duration': '1h 43m', 'Rating': '6.4', 'Voting': '(6.5K)'}
# {'Title': '43. Went Up the Hill', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '6.6', 'Voting': '(94)'}
# {'Title': '44. Girls Will Be Girls', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '7.1', 'Voting': '(2.8K)'}
# {'Title': '45. Dan Da Dan: First Encounter', 'Genre': 'Romance', 'Duration': '1h 23m', 'Rating': '8.2', 'Voting': '(3.1K)'}
# {'Title': '46. Lick', 'Genre': 'Romance', 'Duration': '1h 15m', 'Rating': '6.1', 'Voting': '(1K)'}
# {'Title': '47. Daniela Forever', 'Genre': 'Romance', 'Duration': '1h 53m', 'Rating': '5.9', 'Voting': '(381)'}
# {'Title': '48. Sidelined: The QB and Me', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '5.9', 'Voting': '(4.2K)'}
# {'Title': '49. Touch', 'Genre': 'Romance', 'Duration': '2h 1m', 'Rating': '7.4', 'Voting': '(6K)'}
# {'Title': '50. Before We Forget', 'Genre': 'Romance', 'Duration': '1h 48m', 'Rating': '7.5', 'Voting': '(156)'}
# {'Title': '51. Premalu', 'Genre': 'Romance', 'Duration': '2h 36m', 'Rating': '7.8', 'Voting': '(21K)'}
# {'Title': '52. Mother of the Bride', 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '4.8', 'Voting': '(17K)'}
# {'Title': '53. Kahan Shuru Kahan Khatam', 'Genre': 'Romance', 'Duration': '1h 47m', 'Rating': '6.1', 'Voting': '(3.3K)'}
# {'Title': '54. Killer Heat', 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '5.6', 'Voting': '(14K)'}
# {'Title': '55. The Master and Margarita', 'Genre': 'Romance', 'Duration': '2h 36m', 'Rating': '7.2', 'Voting': '(5.1K)'}
# {'Title': '56. The Tearsmith', 'Genre': 'Romance', 'Duration': '1h 43m', 'Rating': '5.2', 'Voting': '(13K)'}
# {'Title': '57. La Cocina', 'Genre': 'Romance', 'Duration': '2h 19m', 'Rating': '7.1', 'Voting': '(3.8K)'}
# {'Title': '58. Die Alone', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '5.8', 'Voting': '(4.1K)'}
# {'Title': '59. Someone Like You', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '5.9', 'Voting': '(2.4K)'}
# {'Title': '60. Find Me Falling', 'Genre': 'Romance', 'Duration': '1h 33m', 'Rating': '6.3', 'Voting': '(13K)'}
# {'Title': '61. Grafted', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '5.6', 'Voting': '(2.7K)'}
# {'Title': '62. Beating Hearts', 'Genre': 'Romance', 'Duration': '2h 46m', 'Rating': '7.0', 'Voting': '(6.2K)'}
# {'Title': '63. Love', 'Genre': 'Romance', 'Duration': '1h 59m', 'Rating': '7.3', 'Voting': '(616)'}
# {'Title': '64. Loveable', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '7.7', 'Voting': '(2.8K)'}
# {'Title': '65. Lilies Not for Me', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '7.0', 'Voting': '(740)'}
# {'Title': '66. Private Tutor', 'Genre': 'Romance', 'Duration': '1h 5m', 'Rating': '4.8', 'Voting': '(243)'}
# {'Title': '67. My Favourite Cake', 'Genre': 'Romance', 'Duration': '1h 37m', 'Rating': '7.4', 'Voting': '(8K)'}
# {'Title': '68. Our Little Secret', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '5.7', 'Voting': '(24K)'}
# {'Title': '69. The Merry Gentlemen', 'Genre': 'Romance', 'Duration': '1h 27m', 'Rating': '4.8', 'Voting': '(10K)'}
# {'Title': '70. Super Happy Forever', 'Genre': 'Romance', 'Duration': '1h 34m', 'Rating': '6.8', 'Voting': '(364)'}
# {'Title': '71. Irish Wish', 'Genre': 'Romance', 'Duration': '1h 33m', 'Rating': '5.2', 'Voting': '(22K)'}
# {'Title': '72. Girl Haunts Boy', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '6.3', 'Voting': '(3.4K)'}
# {'Title': '73. Beautiful Wedding', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '4.1', 'Voting': '(4.4K)'}
# {'Title': '74. Take My Hand', 'Genre': 'Romance', 'Duration': '1h 42m', 'Rating': '6.2', 'Voting': '(365)'}
# {'Title': '75. Teri Baaton Mein Aisa Uljha Jiya', 'Genre': 'Romance', 'Duration': '2h 21m', 'Rating': '6.2', 'Voting': '(55K)'}
# {'Title': '76. The Astronaut Lovers', 'Genre': 'Romance', 'Duration': '1h 56m', 'Rating': '7.1', 'Voting': '(1K)'}
# {'Title': '77. Three Friends', 'Genre': 'Romance', 'Duration': '1h 57m', 'Rating': '6.6', 'Voting': '(892)'}
# {'Title': '78. Sunlight', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '7.6', 'Voting': '(42)'}
# {'Title': '79. Turn Me On', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '5.6', 'Voting': '(804)'}
# {'Title': '80. Uranus 2324', 'Genre': 'Romance', 'Duration': '2h 10m', 'Rating': '6.4', 'Voting': '(5K)'}
# {'Title': '81. Hot Frosty', 'Genre': 'Romance', 'Duration': '1h 32m', 'Rating': '5.3', 'Voting': '(15K)'}
# {'Title': '82. Sex', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '6.6', 'Voting': '(1.5K)'}
# {'Title': '83. Boot Camp', 'Genre': 'Romance', 'Duration': '1h 34m', 'Rating': '5.8', 'Voting': '(1.3K)'}
# {'Title': '84. Wanted: Girlfriend', 'Genre': 'Romance', 'Duration': '49m', 'Rating': '4.2', 'Voting': '(239)'}
# {'Title': '85. The Family Star', 'Genre': 'Romance', 'Duration': '2h 39m', 'Rating': '5.4', 'Voting': '(5.7K)'}
# {'Title': '86. Love in the Big City', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '7.4', 'Voting': '(1.8K)'}
# {'Title': '87. High Tide', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '6.4', 'Voting': '(816)'}
# {'Title': '88. Addition', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '8.4', 'Voting': '(34)'}
# {'Title': '89. Pedro Páramo', 'Genre': 'Romance', 'Duration': '2h 10m', 'Rating': '6.3', 'Voting': '(3.2K)'}
# {'Title': '90. Through My Window: Looking at You', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '5.5', 'Voting': '(5.6K)'}
# {'Title': '91. Hear Me: Our Summer', 'Genre': 'Romance', 'Duration': '1h 49m', 'Rating': '7.5', 'Voting': '(981)'}
# {'Title': '92. Qalb', 'Genre': 'Romance', 'Duration': '2h 27m', 'Rating': '6.5', 'Voting': '(2.4K)'}
# {'Title': '93. Do Aur Do Pyaar', 'Genre': 'Romance', 'Duration': '2h 20m', 'Rating': '6.4', 'Voting': '(12K)'}
# {'Title': '94. Players', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '5.7', 'Voting': '(12K)'}
# {'Title': '95. Grand Tour', 'Genre': 'Romance', 'Duration': '2h 9m', 'Rating': '6.5', 'Voting': '(2.2K)'}
# {'Title': '96. Eks', 'Genre': 'Romance', 'Duration': '2h 1m', 'Rating': '4.5', 'Voting': '(214)'}
# {'Title': "97. From Contract Lover to the Billionaire's Bride", 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '6.8', 'Voting': '(566)'}
# {'Title': '98. Drawing Closer', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '7.6', 'Voting': '(2.8K)'}
# {'Title': '99. The Glassworker', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '7.2', 'Voting': '(2K)'}
# {'Title': '100. Rasavathi', 'Genre': 'Romance', 'Duration': '2h 28m', 'Rating': '6.4', 'Voting': '(598)'}
# {'Title': '101. Believe in Christmas', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '6.1', 'Voting': '(870)'}
# {'Title': '102. Ajosepo', 'Genre': 'Romance', 'Duration': '2h 14m', 'Rating': '8.8', 'Voting': '(72)'}
# {'Title': '103. Vulgar', 'Genre': 'Romance', 'Duration': '1h 43m', 'Rating': '5.4', 'Voting': '(205)'}
# {'Title': '104. 5lbs of Pressure', 'Genre': 'Romance', 'Duration': '1h 51m', 'Rating': '5.2', 'Voting': '(1.8K)'}
# {'Title': '105. This Is Me... Now', 'Genre': 'Romance', 'Duration': '1h 5m', 'Rating': '4.1', 'Voting': '(7.2K)'}
# {'Title': "106. My Ex's Wedding", 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '8.8', 'Voting': '(58)'}
# {'Title': '107. Bau: Artist at War', 'Genre': 'Romance', 'Duration': '2h 10m', 'Rating': '7.2', 'Voting': '(65)'}
# {'Title': '108. Mor Chhainha Bhuinya 2', 'Genre': 'Romance', 'Duration': '2h 40m', 'Rating': '7.2', 'Voting': '(132)'}
# {'Title': '109. This Time Next Year', 'Genre': 'Romance', 'Duration': '1h 56m', 'Rating': '5.6', 'Voting': '(2.4K)'}
# {'Title': '110. You Are the Apple of My Eye', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '6.8', 'Voting': '(3.8K)'}
# {'Title': '111. 0000 Kilometre', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '2.7', 'Voting': '(296)'}
# {'Title': '112. White Snake: Afloat', 'Genre': 'Romance', 'Duration': '2h 13m', 'Rating': '6.9', 'Voting': '(593)'}
# {'Title': '113. Freedom', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '5.9', 'Voting': '(1.5K)'}
# {'Title': '114. The Best Christmas Pageant Ever', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '6.8', 'Voting': '(6.3K)'}
# {'Title': '115. Chosen Family', 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '4.7', 'Voting': '(526)'}
# {'Title': '116. Amar Singh Chamkila', 'Genre': 'Romance', 'Duration': '2h 25m', 'Rating': '7.8', 'Voting': '(17K)'}
# {'Title': '117. The Dead Thing', 'Genre': 'Romance', 'Duration': '1h 34m', 'Rating': '4.7', 'Voting': '(1K)'}
# {'Title': '118. Murder Mubarak', 'Genre': 'Romance', 'Duration': '2h 20m', 'Rating': '5.8', 'Voting': '(51K)'}
# {'Title': '119. Timestalker', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '5.5', 'Voting': '(3.1K)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '121. Silent Love', 'Genre': 'Romance', 'Duration': '1h 56m', 'Rating': '6.4', 'Voting': '(444)'}
# {'Title': '122. Marmalade', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '6.3', 'Voting': '(3.8K)'}
# {'Title': '123. 3391 Kilometres', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '4.3', 'Voting': '(1.3K)'}
# {'Title': '124. Drained', 'Genre': 'Romance', 'Duration': '1h 47m', 'Rating': '4.5', 'Voting': '(333)'}
# {'Title': '125. Her Seyin Basi Merkür', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '3.4', 'Voting': '(504)'}
# {'Title': '126. Stag', 'Genre': 'Romance', 'Duration': '1h 27m', 'Rating': '4.6', 'Voting': '(477)'}
# {'Title': '127. How to Date Billy Walsh', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '5.2', 'Voting': '(4K)'}
# {'Title': '128. 18×2 Beyond Youthful Days', 'Genre': 'Romance', 'Duration': '2h 3m', 'Rating': '7.3', 'Voting': '(2.1K)'}
# {'Title': '129. Intoxicated by Love', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '8.5', 'Voting': '(14K)'}
# {'Title': '130. Swap', 'Genre': 'Romance', 'Duration': '1h 26m', 'Rating': '2.9', 'Voting': '(383)'}
# {'Title': '131. Blue Sun Palace', 'Genre': 'Romance', 'Duration': '1h 56m', 'Rating': '6.6', 'Voting': '(237)'}
# {'Title': '132. Zenithal', 'Genre': 'Romance', 'Duration': '1h 20m', 'Rating': '4.9', 'Voting': '(122)'}
# {'Title': '133. Detective Conan: The Million-Dollar Pentagram', 'Genre': 'Romance', 'Duration': '1h 51m', 'Rating': '6.7', 'Voting': '(1.6K)'}
# {'Title': '134. Gelin Takimi', 'Genre': 'Romance', 'Duration': '1h 49m', 'Rating': '3.9', 'Voting': '(6.5K)'}
# {'Title': '135. Futra Days', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '4.2', 'Voting': '(166)'}
# {'Title': '136. Black Tea', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '5.2', 'Voting': '(625)'}
# {'Title': '137. Romance on the Ranch', 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '6.8', 'Voting': '(428)'}
# {'Title': '138. Dandelion', 'Genre': 'Romance', 'Duration': '1h 53m', 'Rating': '5.3', 'Voting': '(422)'}
# {'Title': '139. Given 3: To the Sea', 'Genre': 'Romance', 'Duration': '1h 20m', 'Rating': '7.5', 'Voting': '(171)'}
# {'Title': '140. Meet Me Next Christmas', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '5.7', 'Voting': '(8.7K)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '142. Five Blind Dates', 'Genre': 'Romance', 'Duration': '1h 23m', 'Rating': '5.1', 'Voting': '(2.1K)'}
# {'Title': '143. Queens of Drama', 'Genre': 'Romance', 'Duration': '1h 54m', 'Rating': '6.3', 'Voting': '(225)'}
# {'Title': '144. Blame the Game', 'Genre': 'Romance', 'Duration': '1h 32m', 'Rating': '5.4', 'Voting': '(5.4K)'}
# {'Title': '145. Siddharth Roy', 'Genre': 'Romance', 'Duration': '2h 28m', 'Rating': '6.3', 'Voting': '(2.9K)'}
# {'Title': '146. Varshangalkku Shesham', 'Genre': 'Romance', 'Duration': '2h 46m', 'Rating': '6.6', 'Voting': '(4.5K)'}
# {'Title': '147. April, Come She Will', 'Genre': 'Romance', 'Duration': '1h 48m', 'Rating': '6.2', 'Voting': '(471)'}
# {'Title': '148. Mai', 'Genre': 'Romance', 'Duration': '2h 11m', 'Rating': '6.8', 'Voting': '(1.6K)'}
# {'Title': '149. First Taste', 'Genre': 'Romance', 'Duration': '1h 37m', 'Rating': '4.1', 'Voting': '(324)'}
# {'Title': '150. Auron Mein Kahan Dum Tha', 'Genre': 'Romance', 'Duration': '2h 30m', 'Rating': '6.4', 'Voting': '(41K)'}
# {'Title': "151. Cinderella's Curse", 'Genre': 'Romance', 'Duration': '1h 22m', 'Rating': '3.4', 'Voting': '(1.4K)'}
# {'Title': '152. The Air He Breathes', 'Genre': 'Romance', 'Duration': '1h 46m', 'Rating': '6.5', 'Voting': '(444)'}
# {'Title': '153. Art of Love', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '4.6', 'Voting': '(2.5K)'}
# {'Title': '154. Phir Aayi Hasseen Dillruba', 'Genre': 'Romance', 'Duration': '2h 12m', 'Rating': '5.8', 'Voting': '(7K)'}
# {'Title': '155. Here Now', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '4.9', 'Voting': '(491)'}
# {'Title': '156. Lesbian Space Princess', 'Genre': 'Romance', 'Duration': '1h 27m', 'Rating': '7.1', 'Voting': '(212)'}
# {'Title': '157. My Name Is Loh Kiwan', 'Genre': 'Romance', 'Duration': '2h 11m', 'Rating': '6.7', 'Voting': '(4.5K)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '159. Her Story', 'Genre': 'Romance', 'Duration': '2h 3m', 'Rating': '7.6', 'Voting': '(2K)'}
# {'Title': '160. The Southern Chronicles', 'Genre': 'Romance', 'Duration': '2h', 'Rating': '8.7', 'Voting': '(2.9K)'}
# {'Title': '161. Come Closer', 'Genre': 'Romance', 'Duration': '1h 47m', 'Rating': '6.9', 'Voting': '(301)'}
# {'Title': '162. Two to One', 'Genre': 'Romance', 'Duration': '1h 56m', 'Rating': '6.1', 'Voting': '(869)'}
# {'Title': '163. When in Rome', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '6.1', 'Voting': '(809)'}
# {'Title': '164. Chanchal Haseena', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '7.3', 'Voting': '(39)'}
# {'Title': '165. Christmas in the Spotlight', 'Genre': 'Romance', 'Duration': '1h 27m', 'Rating': '5.7', 'Voting': '(685)'}
# {'Title': '166. Krista', 'Genre': 'Romance', 'Duration': '58m', 'Rating': '5.5', 'Voting': '(61)'}
# {'Title': '167. My Future You', 'Genre': 'Romance', 'Duration': '1h 49m', 'Rating': '7.4', 'Voting': '(317)'}
# {'Title': '168. Wallbanger', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '5.6', 'Voting': '(750)'}
# {'Title': "169. We're All Gonna Die", 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '5.7', 'Voting': '(177)'}
# {'Title': "170. A '90s Christmas", 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '6.0', 'Voting': '(1.2K)'}
# {'Title': '171. A True Gentleman', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '4.5', 'Voting': '(2.3K)'}
# {'Title': '172. Mr. Manhattan', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '6.8', 'Voting': '(479)'}
# {'Title': '173. The Everything Pot', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '7.5', 'Voting': '(35)'}
# {'Title': '174. Valley of the Shadow of Death', 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '6.5', 'Voting': '(87)'}
# {'Title': '175. Honey Money Phony', 'Genre': 'Romance', 'Duration': '1h 55m', 'Rating': '6.2', 'Voting': '(225)'}
# {'Title': '176. El Hawa Sultan', 'Genre': 'Romance', 'Duration': '2h 16m', 'Rating': '6.5', 'Voting': '(894)'}
# {'Title': '177. Enchanting Christmas', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '6.3', 'Voting': '(371)'}
# {'Title': '178. Say a Little Prayer', 'Genre': 'Romance', 'Duration': '1h 43m', 'Rating': '8.5', 'Voting': '(48)'}
# {'Title': '179. Tendaberry', 'Genre': 'Romance', 'Duration': '1h 55m', 'Rating': '6.4', 'Voting': '(283)'}
# {'Title': '180. The Glory of Life', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '6.6', 'Voting': '(472)'}
# {'Title': '181. Rajkumar', 'Genre': 'Romance', 'Duration': '2h 25m', 'Rating': '7.4', 'Voting': '(2.8K)'}
# {'Title': '182. The Umesh Chronicles', 'Genre': 'Romance', 'Duration': '2h 4m', 'Rating': '8.5', 'Voting': '(17)'}
# {'Title': '183. Seni Memahami Kekasih', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '8.0', 'Voting': '(65)'}
# {'Title': '184. Badaa Saat Fi Yawman Ma', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '5.8', 'Voting': '(357)'}
# {'Title': '185. Saint Nick of Bethlehem', 'Genre': 'Romance', 'Duration': '1h 33m', 'Rating': '8.9', 'Voting': '(104)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '187. Could Have Waited for August', 'Genre': 'Romance', 'Duration': '1h 52m', 'Rating': '6.2', 'Voting': '(866)'}
# {'Title': '188. City Hunter', 'Genre': 'Romance', 'Duration': '1h 42m', 'Rating': '6.3', 'Voting': '(5.8K)'}
# {'Title': '189. Ashes', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '4.3', 'Voting': '(2.7K)'}
# {'Title': '190. Bad Newz', 'Genre': 'Romance', 'Duration': '2h 22m', 'Rating': '4.7', 'Voting': '(26K)'}
# {'Title': '191. Savi', 'Genre': 'Romance', 'Duration': '2h 6m', 'Rating': '6.1', 'Voting': '(35K)'}
# {'Title': '192. Young Werther', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '5.5', 'Voting': '(297)'}
# {'Title': '193. Romeo', 'Genre': 'Romance', 'Duration': '2h 30m', 'Rating': '6.0', 'Voting': '(1.4K)'}
# {'Title': '194. Ipar Adalah Maut', 'Genre': 'Romance', 'Duration': '2h 11m', 'Rating': '7.0', 'Voting': '(1.3K)'}
# {'Title': '195. Across the Sea', 'Genre': 'Romance', 'Duration': '1h 52m', 'Rating': '6.4', 'Voting': '(103)'}
# {'Title': '196. Miracle Mile', 'Genre': 'Romance', 'Duration': '1h 22m', 'Rating': '7.3', 'Voting': '(42)'}
# {'Title': '197. Why Do You?', 'Genre': 'Romance', 'Duration': '1h 43m', 'Rating': '5.3', 'Voting': '(482)'}
# {'Title': '198. Angithee 3', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '8.1', 'Voting': '(64)'}
# {'Title': '199. Música', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '6.4', 'Voting': '(5.1K)'}
# {'Title': '200. Perfect Match', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '6.6', 'Voting': '(369)'}
# {'Title': '201. Plan B', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '6.0', 'Voting': '(1.4K)'}
# {'Title': '202. Love Switch', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '6.1', 'Voting': '(285)'}
# {'Title': '203. Bachhala Malli', 'Genre': 'Romance', 'Duration': '2h 20m', 'Rating': '8.2', 'Voting': '(4K)'}
# {'Title': '204. Ibbani Tabbida Ileyali', 'Genre': 'Romance', 'Duration': '2h 40m', 'Rating': '7.4', 'Voting': '(881)'}
# {'Title': '205. Haunted Heart', 'Genre': 'Romance', 'Duration': '2h 8m', 'Rating': '4.7', 'Voting': '(529)'}
# {'Title': '206. Love, Divided', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '6.0', 'Voting': '(4.8K)'}
# {'Title': '207. Ek Anjaan Rishtey Ka Guilt 3', 'Genre': 'Romance', 'Duration': '1h 44m', 'Rating': '7.9', 'Voting': '(71)'}
# {'Title': '208. Seven Seas Seven Hills', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '8.6', 'Voting': '(101)'}
# {'Title': '209. Guilty Pleasure', 'Genre': 'Romance', 'Duration': '1h 59m', 'Rating': '4.7', 'Voting': '(178)'}
# {'Title': '210. Hello, Love, Again', 'Genre': 'Romance', 'Duration': '2h 2m', 'Rating': '6.7', 'Voting': '(956)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '212. Sex Love Venice', 'Genre': 'Romance', 'Duration': '1h 42m', 'Rating': '4.3', 'Voting': '(373)'}
# {'Title': '213. Still Fabulous', 'Genre': 'Romance', 'Duration': '1h 32m', 'Rating': '4.9', 'Voting': '(883)'}
# {'Title': '214. Tillu Square', 'Genre': 'Romance', 'Duration': '2h 17m', 'Rating': '6.6', 'Voting': '(3.5K)'}
# {'Title': "215. Cinderella's Revenge", 'Genre': 'Romance', 'Duration': '1h 25m', 'Rating': '3.7', 'Voting': '(1.2K)'}
# {'Title': '216. Pantaskah Aku Berhijab', 'Genre': 'Romance', 'Duration': '1h 54m', 'Rating': '7.9', 'Voting': '(84)'}
# {'Title': '217. The Swedish Torpedo', 'Genre': 'Romance', 'Duration': '2h', 'Rating': '6.0', 'Voting': '(298)'}
# {'Title': '218. Another End', 'Genre': 'Romance', 'Duration': '1h 59m', 'Rating': '6.4', 'Voting': '(858)'}
# {'Title': '219. Good Bad Things', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '5.8', 'Voting': '(242)'}
# {'Title': '220. Undergrads', 'Genre': 'Romance', 'Duration': '1h 6m', 'Rating': '5.1', 'Voting': '(65)'}
# {'Title': '221. Darkest Miriam', 'Genre': 'Romance', 'Duration': '1h 27m', 'Rating': '5.8', 'Voting': '(335)'}
# {'Title': '222. Miss You', 'Genre': 'Romance', 'Duration': '2h 8m', 'Rating': '6.1', 'Voting': '(3.2K)'}
# {'Title': '223. Love at 39 Degrees', 'Genre': 'Romance', 'Duration': '1h 55m', 'Rating': '5.6', 'Voting': '(1.5K)'}
# {'Title': '224. A Merry Royal Christmas', 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '5.4', 'Voting': '(168)'}
# {'Title': '225. Mr. Bachchan', 'Genre': 'Romance', 'Duration': '2h 30m', 'Rating': '3.6', 'Voting': '(5.3K)'}
# {'Title': '226. Love Me If You Dare', 'Genre': 'Romance', 'Duration': '2h 8m', 'Rating': '4.3', 'Voting': '(484)'}
# {'Title': '227. Langue Étrangère', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '6.6', 'Voting': '(591)'}
# {'Title': '228. Honeymoonish', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '5.3', 'Voting': '(1.6K)'}
# {'Title': '229. Love Story', 'Genre': 'Romance', 'Duration': '2h 5m', 'Rating': '5.4', 'Voting': '(444)'}
# {'Title': '230. Love Reddy', 'Genre': 'Romance', 'Duration': '2h 18m', 'Rating': '8.0', 'Voting': '(2.3K)'}
# {'Title': '231. Previously Saved Version', 'Genre': 'Romance', 'Duration': '1h 57m', 'Rating': '5.5', 'Voting': '(473)'}
# {'Title': '232. The Groomsmen Last Dance', 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '6.9', 'Voting': '(385)'}
# {'Title': '233. Perfect Endings', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '5.6', 'Voting': '(237)'}
# {'Title': '234. Jatt & Juliet 3', 'Genre': 'Romance', 'Duration': '2h 15m', 'Rating': '5.3', 'Voting': '(1.9K)'}
# {'Title': "235. Karma's a Bitch", 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '4.7', 'Voting': '(46)'}
# {'Title': '236. Trisha on the Rocks', 'Genre': 'Romance', 'Duration': '2h 52m', 'Rating': '5.3', 'Voting': '(3K)'}
# {'Title': '237. Aichaku', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '6.8', 'Voting': '(416)'}
# {'Title': '238. The Groomsmen: First Look', 'Genre': 'Romance', 'Duration': '1h 22m', 'Rating': '6.1', 'Voting': '(416)'}
# {'Title': '239. X & Y', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '8.1', 'Voting': '(17)'}
# {'Title': '240. The Holiday Exchange', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '5.6', 'Voting': '(427)'}
# {'Title': '241. Kang Mak', 'Genre': 'Romance', 'Duration': '2h 2m', 'Rating': '6.4', 'Voting': '(910)'}
# {'Title': '242. Paalum Pazhavum', 'Genre': 'Romance', 'Duration': '2h 27m', 'Rating': '4.9', 'Voting': '(194)'}
# {'Title': '243. DeAr', 'Genre': 'Romance', 'Duration': '2h 12m', 'Rating': '5.2', 'Voting': '(1.7K)'}
# {'Title': '244. Gone Running', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '7.0', 'Voting': '(4.5K)'}
# {'Title': '245. Love, Wine & Salt: A Tuscan Romance', 'Genre': 'Romance', 'Duration': '1h 20m', 'Rating': '5.3', 'Voting': '(70)'}
# {'Title': '246. The Private Eye', 'Genre': 'Romance', 'Duration': '1h 55m', 'Rating': '3.7', 'Voting': '(164)'}
# {'Title': '247. Raseeli Raatein', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '6.7', 'Voting': '(12)'}
# {'Title': '248. Los pequeños amores', 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '6.3', 'Voting': '(405)'}
# {'Title': '249. Viva La Vida', 'Genre': 'Romance', 'Duration': '2h 10m', 'Rating': '7.6', 'Voting': '(893)'}
# {'Title': '250. Umjolo: The Gone Girl', 'Genre': 'Romance', 'Duration': '1h 32m', 'Rating': '4.4', 'Voting': '(290)'}
# {'Title': '251. Mascarpone: The Rainbow Cake', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '6.1', 'Voting': '(558)'}
# {'Title': '252. Season of Love', 'Genre': 'Romance', 'Duration': '2h 6m', 'Rating': '5.0', 'Voting': '(433)'}
# {'Title': '253. Layla', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '6.1', 'Voting': '(480)'}
# {'Title': '254. Chijin no ai', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '8.0', 'Voting': '(11)'}
# {'Title': '255. Stranded Pearl', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '5.3', 'Voting': '(35)'}
# {'Title': '256. Love, Sitara', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '5.3', 'Voting': '(310)'}
# {'Title': '257. Reloaded 2', 'Genre': 'Romance', 'Duration': '45m', 'Rating': '7.5', 'Voting': '(1.2K)'}
# {'Title': '258. Fake Boyfriend', 'Genre': 'Romance', 'Duration': '1h 55m', 'Rating': '9.0', 'Voting': '(18)'}
# {'Title': '259. Goyo', 'Genre': 'Romance', 'Duration': '1h 46m', 'Rating': '6.6', 'Voting': '(2.3K)'}
# {'Title': '260. She Taught Love', 'Genre': 'Romance', 'Duration': '1h 42m', 'Rating': '5.3', 'Voting': '(429)'}
# {'Title': '261. Passport to Love', 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '6.2', 'Voting': '(432)'}
# {'Title': '262. My Boo', 'Genre': 'Romance', 'Duration': '2h 5m', 'Rating': '6.1', 'Voting': '(738)'}
# {'Title': '263. LSD 2: Love, Sex Aur Dhokha 2', 'Genre': 'Romance', 'Duration': '1h 59m', 'Rating': '3.8', 'Voting': '(2.8K)'}
# {'Title': '264. Maybe Forever', 'Genre': 'Romance', 'Duration': '1h 11m', 'Rating': '5.8', 'Voting': '(104)'}
# {'Title': '265. Elevator', 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '5.2', 'Voting': '(190)'}
# {'Title': '266. Bigayan', 'Genre': 'Romance', 'Duration': '43m', 'Rating': '6.2', 'Voting': '(46)'}
# {'Title': '267. A Circus Tale & a Love Song', 'Genre': 'Romance', 'Duration': '1h 54m', 'Rating': '5.9', 'Voting': '(114)'}
# {'Title': '268. Dilan 1983', 'Genre': 'Romance', 'Duration': '1h 56m', 'Rating': '6.3', 'Voting': '(248)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '270. Pure Love', 'Genre': 'Romance', 'Duration': '1h 49m', 'Rating': '7.1', 'Voting': '(205)'}
# {'Title': '271. Svemu dodje kraj', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '6.4', 'Voting': '(375)'}
# {'Title': '272. Love Lies', 'Genre': 'Romance', 'Duration': '1h 54m', 'Rating': '7.0', 'Voting': '(402)'}
# {'Title': '273. Reversi', 'Genre': 'Romance', 'Duration': '2h 15m', 'Rating': '7.0', 'Voting': '(313)'}
# {'Title': '274. Chainsaws Were Singing', 'Genre': 'Romance', 'Duration': '1h 57m', 'Rating': '7.2', 'Voting': '(391)'}
# {'Title': '275. The Great Gujarati Matrimony', 'Genre': 'Romance', 'Duration': '2h 24m', 'Rating': '7.6', 'Voting': '(96)'}
# {'Title': '276. Kaaduvetty', 'Genre': 'Romance', 'Duration': '2h 37m', 'Rating': '3.2', 'Voting': '(149)'}
# {'Title': '277. The Best Friend', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '6.4', 'Voting': '(152)'}
# {'Title': '278. Meet Me in Rome', 'Genre': 'Romance', 'Duration': '1h 25m', 'Rating': '5.2', 'Voting': '(696)'}
# {'Title': '279. El Roomie', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '5.8', 'Voting': '(317)'}
# {'Title': '280. Amar Prem Ki Prem Kahani', 'Genre': 'Romance', 'Duration': '1h 57m', 'Rating': '4.5', 'Voting': '(676)'}
# {'Title': '281. Roti Kapda Romance', 'Genre': 'Romance', 'Duration': '2h 33m', 'Rating': '5.9', 'Voting': '(2.5K)'}
# {'Title': '282. Marry Christmas', 'Genre': 'Romance', 'Duration': '1h 25m', 'Rating': '6.3', 'Voting': '(67)'}
# {'Title': '283. The Groomsmen: Second Chances', 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '6.1', 'Voting': '(475)'}
# {'Title': "284. Honeko Akabane's Bodyguards", 'Genre': 'Romance', 'Duration': '1h 57m', 'Rating': '6.0', 'Voting': '(51)'}
# {'Title': '285. Breakup Season', 'Genre': 'Romance', 'Duration': '1h 42m', 'Rating': '6.2', 'Voting': '(613)'}
# {'Title': '286. Happiness Is', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '3.8', 'Voting': '(309)'}
# {'Title': '287. Sevmek Yüzünden', 'Genre': 'Romance', 'Duration': '1h 44m', 'Rating': '3.5', 'Voting': '(668)'}
# {'Title': '288. No Pressure', 'Genre': 'Romance', 'Duration': '1h 51m', 'Rating': '5.1', 'Voting': '(1.1K)'}
# {'Title': '289. Ancika', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '6.8', 'Voting': '(824)'}
# {'Title': '290. Un/Happy for You', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '5.7', 'Voting': '(422)'}
# {'Title': '291. A Soldier for Christmas', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '8.2', 'Voting': '(8)'}
# {'Title': '292. In Good Hands 2', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '5.3', 'Voting': '(1K)'}
# {'Title': '293. Love Unlike in K-Dramas', 'Genre': 'Romance', 'Duration': '1h 58m', 'Rating': '6.5', 'Voting': '(149)'}
# {'Title': '294. He Loves Me Not', 'Genre': 'Romance', 'Duration': '1h 37m', 'Rating': '6.8', 'Voting': '(55)'}
# {'Title': '295. Holiday for Hire', 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '5.8', 'Voting': '(197)'}
# {'Title': '296. Love Syndrome: The Beginning', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '6.1', 'Voting': '(68)'}
# {'Title': '297. A European Christmas', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '4.7', 'Voting': '(199)'}
# {'Title': "298. L'heureuse élue", 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '5.5', 'Voting': '(386)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '300. Rose Rosy Te Gulab', 'Genre': 'Romance', 'Duration': '2h 15m', 'Rating': '5.8', 'Voting': '(320)'}
# {'Title': '301. Teasing Master Takagi-san Movie', 'Genre': 'Romance', 'Duration': '1h 59m', 'Rating': '6.6', 'Voting': '(369)'}
# {'Title': '302. Aaram Aravinda Swamy', 'Genre': 'Romance', 'Duration': '2h 12m', 'Rating': '9.3', 'Voting': '(331)'}
# {'Title': '303. The Silence of Marcos Tremmer', 'Genre': 'Romance', 'Duration': '1h 52m', 'Rating': '5.9', 'Voting': '(198)'}
# {'Title': '304. Pasutri Gaje', 'Genre': 'Romance', 'Duration': '1h 49m', 'Rating': '6.0', 'Voting': '(359)'}
# {'Title': '305. The Christmas Brew', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '5.4', 'Voting': '(155)'}
# {'Title': '306. Fruitcake', 'Genre': 'Romance', 'Duration': '1h 37m', 'Rating': '5.3', 'Voting': '(170)'}
# {'Title': '307. Given the Movie: Hiiragi Mix', 'Genre': 'Romance', 'Duration': '1h 10m', 'Rating': '7.6', 'Voting': '(246)'}
# {'Title': '308. Lyubvi ne byvaet?', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '5.4', 'Voting': '(167)'}
# {'Title': '309. Walter, Grace & The Submarine', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '9.3', 'Voting': '(8)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '312. Heavens x Candy', 'Genre': 'Romance', 'Duration': '1h 10m', 'Rating': '6.1', 'Voting': '(53)'}
# {'Title': '313. Sihinayaki Adare', 'Genre': 'Romance', 'Duration': '2h 30m', 'Rating': '6.5', 'Voting': '(200)'}
# {'Title': '314. Switch Up', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '8.6', 'Voting': '(30)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '316. Beauty and the Billionaire: Bali', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '5.8', 'Voting': '(239)'}
# {'Title': '317. Dying Briefly', 'Genre': 'Romance', 'Duration': '1h 18m', 'Rating': '5.9', 'Voting': '(58)'}
# {'Title': '318. Samana Sunrise', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '5.0', 'Voting': '(260)'}
# {'Title': '319. Yuva', 'Genre': 'Romance', 'Duration': '2h 33m', 'Rating': '5.7', 'Voting': '(854)'}
# {'Title': '320. Pon Ondru Kanden', 'Genre': 'Romance', 'Duration': '2h', 'Rating': '5.6', 'Voting': '(287)'}
# {'Title': '321. The Holiday Club', 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '6.6', 'Voting': '(399)'}
# {'Title': '322. Love... Reconsidered', 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '4.1', 'Voting': '(142)'}
# {'Title': '323. Forbidden Love', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '7.8', 'Voting': '(31)'}
# {'Title': '324. Letters at Christmas', 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '3.6', 'Voting': '(183)'}
# {'Title': '325. Éden & Charlie', 'Genre': 'Romance', 'Duration': '45m', 'Rating': '7.7', 'Voting': '(16)'}
# {'Title': '326. Anyone But Her', 'Genre': 'Romance', 'Duration': '1h 33m', 'Rating': '4.9', 'Voting': '(295)'}
# {'Title': '327. Black Owner and Horny College Girls', 'Genre': 'Romance', 'Duration': '1h 5m', 'Rating': '3.6', 'Voting': '(10)'}
# {'Title': '328. Letuchiy korabl', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '3.4', 'Voting': '(394)'}
# {'Title': '329. O2', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '6.6', 'Voting': '(8.1K)'}
# {'Title': '330. Shark Island', 'Genre': 'Romance', 'Duration': '1h 21m', 'Rating': '3.0', 'Voting': '(138)'}
# {'Title': '331. Love Is Never on Time', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '8.6', 'Voting': '(75)'}
# {'Title': '332. Murphy', 'Genre': 'Romance', 'Duration': '2h 16m', 'Rating': '7.0', 'Voting': '(2.4K)'}
# {'Title': '333. Kisko Tha Pata', 'Genre': 'Romance', 'Duration': '2h 15m', 'Rating': '6.9', 'Voting': '(21)'}
# {'Title': '334. Alterlove', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '7.8', 'Voting': '(15)'}
# {'Title': '335. Kupu-Kupu Kertas', 'Genre': 'Romance', 'Duration': '1h 53m', 'Rating': '6.5', 'Voting': '(225)'}
# {'Title': '336. Kill Me If You Dare', 'Genre': 'Romance', 'Duration': '1h 34m', 'Rating': '4.6', 'Voting': '(1.4K)'}
# {'Title': '337. Oshana', 'Genre': 'Romance', 'Duration': '2h 29m', 'Rating': '5.7', 'Voting': '(800)'}
# {'Title': '338. Amaltash', 'Genre': 'Romance', 'Duration': '1h 53m', 'Rating': '8.1', 'Voting': '(160)'}
# {'Title': '339. Azzamine', 'Genre': 'Romance', 'Duration': '1h 44m', 'Rating': '7.0', 'Voting': '(121)'}
# {'Title': '340. The Time of Fever', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '8.0', 'Voting': '(757)'}
# {'Title': '341. C4 Cinta', 'Genre': 'Romance', 'Duration': '2h 47m', 'Rating': '7.4', 'Voting': '(158)'}
# {'Title': '342. The Proud Princess', 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '6.4', 'Voting': '(150)'}
# {'Title': '343. Sicilian Holiday', 'Genre': 'Romance', 'Duration': '1h 42m', 'Rating': '4.9', 'Voting': '(24)'}
# {'Title': '344. Sweet Summer Love', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '6.6', 'Voting': '(76)'}
# {'Title': '345. We Are Faheem & Karun', 'Genre': 'Romance', 'Duration': '1h 21m', 'Rating': '9.0', 'Voting': '(80)'}
# {'Title': '346. A Toast to Love', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '5.7', 'Voting': '(153)'}
# {'Title': '347. Albany Road', 'Genre': 'Romance', 'Duration': '2h 15m', 'Rating': '7.8', 'Voting': '(118)'}
# {'Title': '348. Kacher Manush Dure Thuiya', 'Genre': 'Romance', 'Duration': '2h 24m', 'Rating': '7.8', 'Voting': '(1.2K)'}
# {'Title': '349. Lobola Man', 'Genre': 'Romance', 'Duration': '1h 48m', 'Rating': '4.5', 'Voting': '(216)'}
# {'Title': '350. Game On', 'Genre': 'Romance', 'Duration': '2h 20m', 'Rating': '5.2', 'Voting': '(2.3K)'}
# {'Title': '351. Liu mang qu mo shi', 'Genre': 'Romance', 'Duration': '1h 44m', 'Rating': '5.6', 'Voting': '(56)'}
# {'Title': '352. Heartbreak Motel', 'Genre': 'Romance', 'Duration': '1h 55m', 'Rating': '7.0', 'Voting': '(321)'}
# {'Title': '353. Him', 'Genre': 'Romance', 'Duration': '1h 20m', 'Rating': '7.4', 'Voting': '(32)'}
# {'Title': '354. Christmas on the Ranch', 'Genre': 'Romance', 'Duration': '1h 26m', 'Rating': '6.1', 'Voting': '(140)'}
# {'Title': '355. Joli joli', 'Genre': 'Romance', 'Duration': '1h 56m', 'Rating': '5.5', 'Voting': '(148)'}
# {'Title': '356. Paper Flowers', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '8.5', 'Voting': '(37)'}
# {'Title': '357. The Lifeguards', 'Genre': 'Romance', 'Duration': '1h 47m', 'Rating': '3.7', 'Voting': '(147)'}
# {'Title': '358. Hold Me Close', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '4.8', 'Voting': '(77)'}
# {'Title': '359. María, Me Muero', 'Genre': 'Romance', 'Duration': '1h 33m', 'Rating': '5.2', 'Voting': '(123)'}
# {'Title': '360. Prabuthwa Junior Kalashala', 'Genre': 'Romance', 'Duration': '2h 11m', 'Rating': '7.0', 'Voting': '(2.1K)'}
# {'Title': '361. À toute allure', 'Genre': 'Romance', 'Duration': '1h 26m', 'Rating': '5.4', 'Voting': '(239)'}
# {'Title': '362. Shrek 5: The Contract - A Fan Made Film', 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '7.4', 'Voting': '(22)'}
# {'Title': '363. Alaap', 'Genre': 'Romance', 'Duration': '2h 25m', 'Rating': '6.5', 'Voting': '(151)'}
# {'Title': '364. One Night in Tokyo', 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '7.1', 'Voting': '(93)'}
# {'Title': '365. The Heartbreak Agency', 'Genre': 'Romance', 'Duration': '1h 34m', 'Rating': '5.3', 'Voting': '(747)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '367. Lady Outlaw', 'Genre': 'Romance', 'Duration': '1h 44m', 'Rating': '6.6', 'Voting': '(26)'}
# {'Title': '368. Ahl Al Kahf', 'Genre': 'Romance', 'Duration': '2h', 'Rating': '5.3', 'Voting': '(296)'}
# {'Title': '369. Aku Jati, Aku Asperger', 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '7.6', 'Voting': '(95)'}
# {'Title': '370. Last Song for You', 'Genre': 'Romance', 'Duration': '1h 46m', 'Rating': '7.0', 'Voting': '(111)'}
# {'Title': '371. PAPmusic - Animation for Fashion', 'Genre': 'Romance', 'Duration': '1h 25m', 'Rating': '1.1', 'Voting': '(198)'}
# {'Title': '372. Meeting Ms. Leigh', 'Genre': 'Romance', 'Duration': '1h 57m', 'Rating': '8.8', 'Voting': '(82)'}
# {'Title': '373. Love You to Debt', 'Genre': 'Romance', 'Duration': '2h 15m', 'Rating': '6.2', 'Voting': '(778)'}
# {'Title': '374. Sureshinteyum Sumalathayudeyum Hridayahariyaya Pranayakatha', 'Genre': 'Romance', 'Duration': '2h 18m', 'Rating': '6.0', 'Voting': '(85)'}
# {'Title': '375. Books & Drinks', 'Genre': 'Romance', 'Duration': '1h 34m', 'Rating': '5.1', 'Voting': '(155)'}
# {'Title': "376. It's So Big It Hurts, Black Oppa", 'Genre': 'Romance', 'Duration': '1h 1m', 'Rating': '5.6', 'Voting': '(11)'}
# {'Title': '377. Christmas at Plumhill Manor', 'Genre': 'Romance', 'Duration': '1h 27m', 'Rating': '6.1', 'Voting': '(509)'}
# {'Title': '378. Moments We Shared', 'Genre': 'Romance', 'Duration': '2h 11m', 'Rating': '5.3', 'Voting': '(134)'}
# {'Title': '379. A Heart for Christmas', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '7.6', 'Voting': '(102)'}
# {'Title': '380. The Architecture of Love', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '6.9', 'Voting': '(519)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '382. Midwinter', 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '6.5', 'Voting': '(60)'}
# {'Title': '383. Verliefd op Bali', 'Genre': 'Romance', 'Duration': '1h 53m', 'Rating': '5.0', 'Voting': '(338)'}
# {'Title': "384. Momma's Boy", 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '3.8', 'Voting': '(49)'}
# {'Title': '385. Dreaming of You', 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '8.4', 'Voting': '(63)'}
# {'Title': '386. Christmas in Lagos', 'Genre': 'Romance', 'Duration': '2h', 'Rating': '4.7', 'Voting': '(182)'}
# {'Title': '387. A Christmas of Wonders', 'Genre': 'Romance', 'Duration': '1h 26m', 'Rating': '4.9', 'Voting': '(131)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': "390. Shooting My Life's Script", 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '6.2', 'Voting': '(344)'}
# {'Title': '391. Umjolo: Day Ones', 'Genre': 'Romance', 'Duration': '1h 26m', 'Rating': '4.2', 'Voting': '(167)'}
# {'Title': '392. A Brooklyn Love Story', 'Genre': 'Romance', 'Duration': '1h 47m', 'Rating': '5.3', 'Voting': '(116)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '394. That Kind of Love', 'Genre': 'Romance', 'Duration': '2h 16m', 'Rating': '5.7', 'Voting': '(340)'}
# {'Title': '395. Dhruvathaare', 'Genre': 'Romance', 'Duration': '2h 45m', 'Rating': '8.0', 'Voting': '(649)'}
# {'Title': '396. Onegin', 'Genre': 'Romance', 'Duration': '2h 21m', 'Rating': '7.0', 'Voting': '(1.2K)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '398. Young Lion of the West', 'Genre': 'Romance', 'Duration': '1h 33m', 'Rating': '5.3', 'Voting': '(110)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '400. Premalo', 'Genre': 'Romance', 'Duration': '2h 8m', 'Rating': '7.3', 'Voting': '(1.1K)'}
# {'Title': '401. Soft Love', 'Genre': 'Romance', 'Duration': '1h 54m', 'Rating': '6.8', 'Voting': '(42)'}
# {'Title': '402. Perdiendo el Juicio', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '7.7', 'Voting': '(21)'}
# {'Title': '403. Jingle Bell Love', 'Genre': 'Romance', 'Duration': '1h 21m', 'Rating': '6.1', 'Voting': '(224)'}
# {'Title': '404. Little Hearts', 'Genre': 'Romance', 'Duration': '2h 16m', 'Rating': '5.9', 'Voting': '(2.6K)'}
# {'Title': '405. Matters of the Heart', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '6.8', 'Voting': '(319)'}
# {'Title': '406. In the Summer Rain', 'Genre': 'Romance', 'Duration': '2h 9m', 'Rating': '6.2', 'Voting': '(21)'}
# {'Title': '407. Life is Filled with So Much of You', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '7.2', 'Voting': '(78)'}
# {'Title': '408. Morando com o Crush', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '5.5', 'Voting': '(190)'}
# {'Title': '409. My Boyfriend Is a Sex Worker', 'Genre': 'Romance', 'Duration': '50m', 'Rating': '5.4', 'Voting': '(17)'}
# {'Title': '410. Ma chi ti conosce', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '5.8', 'Voting': '(146)'}
# {'Title': "411. What Happened in My Black Boyfriend's Room", 'Genre': 'Romance', 'Duration': '1h 2m', 'Rating': '5.4', 'Voting': '(11)'}
# {'Title': '412. Sign Here', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '6.2', 'Voting': '(255)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '416. Maple Leaf Dreams', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '4.8', 'Voting': '(138)'}
# {'Title': '417. Future Date', 'Genre': 'Romance', 'Duration': '1h 22m', 'Rating': '5.6', 'Voting': '(133)'}
# {'Title': '418. My Sassy Girl', 'Genre': 'Romance', 'Duration': '1h 57m', 'Rating': '5.1', 'Voting': '(149)'}
# {'Title': '419. Royal Façade', 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '8.4', 'Voting': '(60)'}
# {'Title': '420. The Little Things', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '7.8', 'Voting': '(44)'}
# {'Title': '421. A Christmas Dream', 'Genre': 'Romance', 'Duration': '1h 34m', 'Rating': '4.9', 'Voting': '(54)'}
# {'Title': '422. Powder Pup', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '6.0', 'Voting': '(84)'}
# {'Title': '423. Throuple', 'Genre': 'Romance', 'Duration': '1h 32m', 'Rating': '6.4', 'Voting': '(75)'}
# {'Title': '424. The Mediterranean Sea', 'Genre': 'Romance', 'Duration': '1h 48m', 'Rating': '7.2', 'Voting': '(99)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '426. Boys on Film 24: Happy Endings', 'Genre': 'Romance', 'Duration': '2h 54m', 'Rating': '7.0', 'Voting': '(29)'}
# {'Title': '427. Juni', 'Genre': 'Romance', 'Duration': '2h 18m', 'Rating': '7.3', 'Voting': '(227)'}
# {'Title': '428. Pool & Party', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '2.7', 'Voting': '(270)'}
# {'Title': '429. You Are Not Alone', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '6.0', 'Voting': '(77)'}
# {'Title': '430. My Zombabe', 'Genre': 'Romance', 'Duration': '1h 45m', 'Rating': '5.0', 'Voting': '(94)'}
# {'Title': '431. Die Ironie des Lebens', 'Genre': 'Romance', 'Duration': '1h 49m', 'Rating': '6.6', 'Voting': '(79)'}
# {'Title': '432. Kuch Sapney Apne', 'Genre': 'Romance', 'Duration': '2h', 'Rating': '8.1', 'Voting': '(57)'}
# ...
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '598. Buzzy Noise', 'Genre': 'Romance', 'Duration': '1h 59m', 'Rating': '6.0', 'Voting': '(61)'}
# {'Title': '599. Maaya Ka Moh', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '3.7', 'Voting': '(17)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '601. Ye xiao nü sheng', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '7.1', 'Voting': '(52)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '603. Hell City', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '9.1', 'Voting': '(28)'}
# {'Title': '604. Stalker', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '2.7', 'Voting': '(11)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '606. Dhaaak', 'Genre': 'Romance', 'Duration': '2h 8m', 'Rating': '8.6', 'Voting': '(24)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '608. The Love Buzz', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '5.7', 'Voting': '(170)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '610. Bedtime Stories: Tales of Love and Hate', 'Genre': 'Romance', 'Duration': '1h 5m', 'Rating': '7.7', 'Voting': '(15)'}
# {'Title': '611. Lyubov so vtorogo vzglyada', 'Genre': 'Romance', 'Duration': '1h 37m', 'Rating': '4.7', 'Voting': '(74)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '614. Dukkhito', 'Genre': 'Romance', 'Duration': '29m', 'Rating': '7.4', 'Voting': '(69)'}
# {'Title': '615. B4S: Truoc Gio Yeu', 'Genre': 'Romance', 'Duration': '1h 37m', 'Rating': '5.6', 'Voting': '(65)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '617. Love at First Lie', 'Genre': 'Romance', 'Duration': '1h 47m', 'Rating': '4.3', 'Voting': '(39)'}
# {'Title': '618. Ravikula Raghurama', 'Genre': 'Romance', 'Duration': '1h 51m', 'Rating': '7.9', 'Voting': '(2.1K)'}
# {'Title': "619. DreadClub: Vampire's Verdict", 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '4.5', 'Voting': '(64)'}
# {'Title': '620. A Very Bayou Holiday', 'Genre': 'Romance', 'Duration': '1h 27m', 'Rating': '5.2', 'Voting': '(11)'}
# {'Title': '621. This Is Not A Love Song', 'Genre': 'Romance', 'Duration': '1h 12m', 'Rating': '7.1', 'Voting': '(44)'}
# {'Title': "622. All's Fair in Love", 'Genre': 'Romance', 'Duration': '1h 55m', 'Rating': '6.6', 'Voting': '(18)'}
# {'Title': '623. Bienvenidos al paraíso', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '4.7', 'Voting': '(23)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '626. Greice', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '6.9', 'Voting': '(137)'}
# {'Title': '627. The Umbrella Fairy', 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '5.7', 'Voting': '(62)'}
# {'Title': '628. Listy do M. Pozegnania i powroty', 'Genre': 'Romance', 'Duration': '2h 3m', 'Rating': '5.9', 'Voting': '(341)'}
# {'Title': '629. Goreyan Naal Lagdi Zameen Jatt Di', 'Genre': 'Romance', 'Duration': '1h 48m', 'Rating': '7.8', 'Voting': '(30)'}
# {'Title': '630. Nie Xiaoqian', 'Genre': 'Romance', 'Duration': '1h 52m', 'Rating': '6.3', 'Voting': '(19)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '632. ON i Ona', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '4.6', 'Voting': '(84)'}
# {'Title': '633. Podrostki. Pervaya lyubov', 'Genre': 'Romance', 'Duration': '1h 42m', 'Rating': '5.8', 'Voting': '(61)'}
# {'Title': "634. L'invenzione di noi due", 'Genre': 'Romance', 'Duration': '1h 46m', 'Rating': '4.8', 'Voting': '(40)'}
# {'Title': '635. Vremya est!', 'Genre': 'Romance', 'Duration': '1h 14m', 'Rating': '5.6', 'Voting': '(12)'}
# {'Title': '636. Step Back, Doors Closing', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '9.0', 'Voting': '(41)'}
# {'Title': '637. Dr. Jason II - Lights & Shadows', 'Genre': 'Romance', 'Duration': '1h 2m', 'Rating': '5.0', 'Voting': '(349)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '639. Reeza GTR', 'Genre': 'Romance', 'Duration': '1h 31m', 'Rating': '6.9', 'Voting': '(16)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '641. #OOTD: Outfit of the Designer', 'Genre': 'Romance', 'Duration': '1h 47m', 'Rating': '5.7', 'Voting': '(49)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '643. To potami', 'Genre': 'Romance', 'Duration': '1h 33m', 'Rating': '6.4', 'Voting': '(22)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '645. Hearts Creek', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '5.9', 'Voting': '(130)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '649. Der Junge dem die Welt gehört', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '7.9', 'Voting': '(77)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '651. Dil Kush', 'Genre': 'Romance', 'Duration': '2h 15m', 'Rating': '8.1', 'Voting': '(550)'}
# {'Title': '652. Abhi', 'Genre': 'Romance', 'Duration': '2h 15m', 'Rating': '8.1', 'Voting': '(46)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '657. My Own Normal', 'Genre': 'Romance', 'Duration': '57m', 'Rating': '8.0', 'Voting': '(7)'}
# {'Title': '658. Jaunt', 'Genre': 'Romance', 'Duration': '1h 18m', 'Rating': '8.7', 'Voting': '(8)'}
# {'Title': '659. Raju Gari Ammayi Naidu Gari Abbayi', 'Genre': 'Romance', 'Duration': '2h 38m', 'Rating': '8.2', 'Voting': '(3.1K)'}
# {'Title': '660. Unarvugal Thodarkadhai', 'Genre': 'Romance', 'Duration': '1h 51m', 'Rating': '6.3', 'Voting': '(53)'}
# {'Title': '661. Haunted Happy Hour', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '7.4', 'Voting': '(18)'}
# {'Title': '662. Timing', 'Genre': 'Romance', 'Duration': '2h 18m', 'Rating': '7.6', 'Voting': '(66)'}
# {'Title': '663. Chow Chow Bath', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '7.2', 'Voting': '(1.2K)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '665. Lyod 3', 'Genre': 'Romance', 'Duration': '2h 14m', 'Rating': '6.0', 'Voting': '(317)'}
# {'Title': '666. Youth in Trouble', 'Genre': 'Romance', 'Duration': '1h 46m', 'Rating': '7.8', 'Voting': '(28)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '668. Eksie Perfeksie', 'Genre': 'Romance', 'Duration': '1h 43m', 'Rating': '6.4', 'Voting': '(22)'}
# {'Title': '669. More na dvoikh', 'Genre': 'Romance', 'Duration': '1h 22m', 'Rating': '5.0', 'Voting': '(26)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '671. Fragments of Us', 'Genre': 'Romance', 'Duration': '49m', 'Rating': '7.2', 'Voting': '(12)'}
# {'Title': '672. Silent Sparks', 'Genre': 'Romance', 'Duration': '1h 18m', 'Rating': '6.1', 'Voting': '(66)'}
# {'Title': '673. A Fragile Flower', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '7.9', 'Voting': '(1.6K)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '675. Undying', 'Genre': 'Romance', 'Duration': '26m', 'Rating': '6.5', 'Voting': '(15)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '677. Guxim', 'Genre': 'Romance', 'Duration': '1h 15m', 'Rating': '7.2', 'Voting': '(37)'}
# {'Title': '678. Khoka Bhai Tama Pain: A Song Epic', 'Genre': 'Romance', 'Duration': '2h 33m', 'Rating': '8.8', 'Voting': '(161)'}
# {'Title': '679. La piel en primavera', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '6.9', 'Voting': '(51)'}
# {'Title': '680. Allahr Vres', 'Genre': 'Romance', 'Duration': '2h 15m', 'Rating': '8.2', 'Voting': '(18)'}
# {'Title': '681. Tauba Tera Jalwa', 'Genre': 'Romance', 'Duration': '2h 10m', 'Rating': '5.4', 'Voting': '(17)'}
# {'Title': '682. Omenavarkaat', 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '7.0', 'Voting': '(210)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '684. Zehan', 'Genre': 'Romance', 'Duration': '1h 53m', 'Rating': '5.0', 'Voting': '(28)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '688. Suchana', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '8.7', 'Voting': '(511)'}
# {'Title': '689. The Haunting of Lanquetot', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '3.7', 'Voting': '(10)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '691. Because I Love Bad Weather', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '6.2', 'Voting': '(160)'}
# {'Title': '692. Maunam', 'Genre': 'Romance', 'Duration': '1h 46m', 'Rating': '8.5', 'Voting': '(46)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '694. A Wall Away', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '4.9', 'Voting': '(76)'}
# {'Title': '695. Zorawar Di Jacqueline', 'Genre': 'Romance', 'Duration': '2h 27m', 'Rating': '5.7', 'Voting': '(1K)'}
# {'Title': '696. Papu mame zaverni', 'Genre': 'Romance', 'Duration': '1h 46m', 'Rating': '3.6', 'Voting': '(72)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '698. Fallen Leaves, Broken Lighters', 'Genre': 'Romance', 'Duration': '1h 36m', 'Rating': '7.7', 'Voting': '(8)'}
# {'Title': '699. La herencia de Flora', 'Genre': 'Romance', 'Duration': '2h 14m', 'Rating': '5.8', 'Voting': '(6)'}
# {'Title': '700. If My Lover Were a Flower', 'Genre': 'Romance', 'Duration': '1h 50m', 'Rating': '8.7', 'Voting': '(9)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '702. Surjo', 'Genre': 'Romance', 'Duration': '2h 35m', 'Rating': '7.8', 'Voting': '(14)'}
# {'Title': '703. Cedo Demais', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '4.5', 'Voting': '(29)'}
# {'Title': '704. Labyrinth', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '4.7', 'Voting': '(18)'}
# {'Title': '705. Gharjwai', 'Genre': 'Romance', 'Duration': '2h 14m', 'Rating': '7.9', 'Voting': '(907)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '709. Tochka opory', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '4.2', 'Voting': '(34)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '712. For Regn', 'Genre': 'Romance', 'Duration': '2h 20m', 'Rating': '3.8', 'Voting': '(565)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '714. Pithala Maathi', 'Genre': 'Romance', 'Duration': '2h 20m', 'Rating': '7.5', 'Voting': '(845)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '718. Before Marriage', 'Genre': 'Romance', 'Duration': '1h 52m', 'Rating': '7.9', 'Voting': '(1.1K)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '721. Pravo na levo', 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '3.6', 'Voting': '(41)'}
# {'Title': '722. Penguin Girl', 'Genre': 'Romance', 'Duration': '1h 38m', 'Rating': '6.2', 'Voting': '(20)'}
# {'Title': '723. La Pura Vida', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '7.3', 'Voting': '(33)'}
# {'Title': '724. Chetyre chetverti', 'Genre': 'Romance', 'Duration': '2h 32m', 'Rating': '7.8', 'Voting': '(12)'}
# {'Title': '725. Licença para Enlouquecer', 'Genre': 'Romance', 'Duration': '1h 35m', 'Rating': '7.8', 'Voting': '(16)'}
# {'Title': "726. Neath's Love Story 2", 'Genre': 'Romance', 'Duration': '1h 28m', 'Rating': '7.3', 'Voting': '(23)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '728. Love Love', 'Genre': 'Romance', 'Duration': '1h 1m', 'Rating': '9.0', 'Voting': '(7)'}
# {'Title': '729. 10 Pasimatymu', 'Genre': 'Romance', 'Duration': '1h 39m', 'Rating': '5.7', 'Voting': '(31)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '731. Keluar Main 1994', 'Genre': 'Romance', 'Duration': '1h 52m', 'Rating': '7.8', 'Voting': '(56)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '733. Puang Bos!', 'Genre': 'Romance', 'Duration': '1h 40m', 'Rating': '8.4', 'Voting': '(12)'}
# {'Title': '734. Bambara Wasanthe', 'Genre': 'Romance', 'Duration': '1h 41m', 'Rating': '7.5', 'Voting': '(6)'}
# {'Title': '735. I 20', 'Genre': 'Romance', 'Duration': '1h 54m', 'Rating': '9.0', 'Voting': '(494)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '737. Koi wo Shiranai Bokutachi wa', 'Genre': 'Romance', 'Duration': '1h 51m', 'Rating': '5.3', 'Voting': '(10)'}
# {'Title': '738. Bewafa Darling', 'Genre': 'Romance', 'Duration': '56m', 'Rating': '8.7', 'Voting': '(15)'}
# {'Title': '739. iKHlaas', 'Genre': 'Romance', 'Duration': '50m', 'Rating': '8.1', 'Voting': '(17)'}
# {'Title': '740. Majnoo', 'Genre': 'Romance', 'Duration': '2h 3m', 'Rating': '9.6', 'Voting': '(61)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '742. Apsara', 'Genre': 'Romance', 'Duration': '2h 30m', 'Rating': '6.8', 'Voting': '(34)'}
# {'Title': '743. Lucky Heart', 'Genre': 'Romance', 'Duration': '1h 30m', 'Rating': '4.4', 'Voting': '(12)'}
# {'Title': '744. Sangharshana', 'Genre': 'Romance', 'Duration': '1h 42m', 'Rating': '7.3', 'Voting': '(1.6K)'}
# {'Title': '745. Forget Me Not', 'Genre': 'Romance', 'Duration': '1h 29m', 'Rating': '6.5', 'Voting': '(157)'}
# {'Title': 'N/A', 'Genre': 'Romance', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '747. Love Mouli', 'Genre': 'Romance', 'Duration': '2h 26m', 'Rating': '6.5', 'Voting': '(87)'}
# {'Title': '748. Ayo Balikan', 'Genre': 'Romance', 'Duration': '1h 26m', 'Rating': '7.0', 'Voting': '(32)'}
# {'Title': '749. Cedric & Alysia', 'Genre': 'Romance', 'Duration': '1h 24m', 'Rating': '5.3', 'Voting': '(52)'}
# {'Title': '750. Fujimi Lovers', 'Genre': 'Romance', 'Duration': '1h 43m', 'Rating': '6.0', 'Voting': '(48)'}

# %%
#common csv converting code

import pandas as pd

df=pd.DataFrame(movie_list)

# 1. Remove leading numbers from "Title"
df["Title"] = df["Title"].str.replace(r"^\d+\.\s*", "", regex=True)

# 2. Remove parentheses from "Voting"
df["Voting"] = df["Voting"].str.replace(r"[()]", "", regex=True)

# 3. Reset index to start from 1
df.index = df.index + 1

df.to_csv(r"D:\Nirosha\GUVI\Project\romance.csv", index=False, encoding="utf-8")
print("CSV file - Romance Movies saved successfully!")
# Out:
# CSV file - Romance Movies saved successfully!

# %%
# Comedy movies 

from selenium import webdriver 
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

# Initialize WebDriver
driver = webdriver.Chrome()
driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=comedy")

time.sleep(5)  # Waiting for the page to load

genre = "Comedy"

# Scroll Until No More New Data Loads
scroll = True
movies_per_page = 50  # Assuming each load gives 50 movies
total_movies = 500
current_movies = 0

while scroll and current_movies < total_movies:
    old_page_source = driver.page_source  # Save old page source
    
    # Scroll down to load more data
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Allow time for new data to load
    
    new_page_source = driver.page_source  # Save new page source

    if new_page_source == old_page_source:
        try:
            # Locate and click the "See More" button if present
            see_more_button = driver.find_element(By.XPATH, "//span[contains(@class, 'ipc-see-more')]")
            ActionChains(driver).move_to_element(see_more_button).click().perform()
            time.sleep(3)  # Wait for new content to load
        except Exception:
            scroll = False  # Stop scrolling if button isn't found
    else:
        current_movies += movies_per_page  # Increment count

# Extract movie containers
movie_block = driver.find_elements(By.CSS_SELECTOR, "li.ipc-metadata-list-summary-item")

movie_list = []

for movie in movie_block:
    try:
        title = movie.find_element(By.CSS_SELECTOR, "h3.ipc-title__text").text.strip()
        duration_element = movie.find_element(By.XPATH, ".//span[contains(@class, 'dli-title-metadata-item') and (contains(text(),'h') or contains(text(),'m'))]")
        duration = duration_element.text.strip() if duration_element.text.strip() else "N/A"
        rating = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--rating").text.strip()
        voting = movie.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--voteCount").text.strip()
    except:
        title = "N/A"
        duration = "N/A"
        rating = "N/A"
        voting = "N/A"

    movie_data = {
        "Title": title,
        "Genre": genre,
        "Duration": duration,
        "Rating": rating,
        "Voting": voting,
    }
    movie_list.append(movie_data)

# Print results
for movie in movie_list:
    print(movie)

# Close the driver
driver.quit()
# Out:
# {'Title': '1. Anora', 'Genre': 'Comedy', 'Duration': '2h 19m', 'Rating': '7.5', 'Voting': '(211K)'}
# {'Title': '2. Riff Raff', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '5.7', 'Voting': '(5.1K)'}
# {'Title': '3. Friendship', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '6.9', 'Voting': '(15K)'}
# {'Title': '4. Deadpool & Wolverine', 'Genre': 'Comedy', 'Duration': '2h 8m', 'Rating': '7.5', 'Voting': '(513K)'}
# {'Title': '5. Long Distance', 'Genre': 'Comedy', 'Duration': '1h 27m', 'Rating': '5.7', 'Voting': '(4.3K)'}
# {'Title': '6. The Ministry of Ungentlemanly Warfare', 'Genre': 'Comedy', 'Duration': '2h 2m', 'Rating': '6.8', 'Voting': '(141K)'}
# {'Title': '7. A Real Pain', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '7.1', 'Voting': '(107K)'}
# {'Title': '8. Sonic the Hedgehog 3', 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '6.9', 'Voting': '(67K)'}
# {'Title': '9. The Fall Guy', 'Genre': 'Comedy', 'Duration': '2h 6m', 'Rating': '6.8', 'Voting': '(229K)'}
# {'Title': '10. Beetlejuice Beetlejuice', 'Genre': 'Comedy', 'Duration': '1h 45m', 'Rating': '6.6', 'Voting': '(156K)'}
# {'Title': '11. Moana 2', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '6.5', 'Voting': '(111K)'}
# {'Title': '12. Freaky Tales', 'Genre': 'Comedy', 'Duration': '1h 47m', 'Rating': '6.2', 'Voting': '(7.9K)'}
# {'Title': '13. Challengers', 'Genre': 'Comedy', 'Duration': '2h 11m', 'Rating': '7.0', 'Voting': '(160K)'}
# {'Title': '14. IF', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '6.4', 'Voting': '(60K)'}
# {'Title': '15. Fight or Flight', 'Genre': 'Comedy', 'Duration': '1h 42m', 'Rating': '6.4', 'Voting': '(16K)'}
# {'Title': '16. The Idea of You', 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '6.3', 'Voting': '(76K)'}
# {'Title': '17. Sister Midnight', 'Genre': 'Comedy', 'Duration': '1h 47m', 'Rating': '5.8', 'Voting': '(1.4K)'}
# {'Title': '18. Argylle', 'Genre': 'Comedy', 'Duration': '2h 19m', 'Rating': '5.6', 'Voting': '(95K)'}
# {'Title': '19. Inside Out 2', 'Genre': 'Comedy', 'Duration': '1h 36m', 'Rating': '7.5', 'Voting': '(225K)'}
# {'Title': '20. Abigail', 'Genre': 'Comedy', 'Duration': '1h 49m', 'Rating': '6.5', 'Voting': '(101K)'}
# {'Title': '21. Kinds of Kindness', 'Genre': 'Comedy', 'Duration': '2h 44m', 'Rating': '6.5', 'Voting': '(62K)'}
# {'Title': '22. Fly Me to the Moon', 'Genre': 'Comedy', 'Duration': '2h 12m', 'Rating': '6.6', 'Voting': '(53K)'}
# {'Title': '23. Ghostbusters: Frozen Empire', 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '6.1', 'Voting': '(96K)'}
# {'Title': '24. Saturday Night', 'Genre': 'Comedy', 'Duration': '1h 49m', 'Rating': '6.9', 'Voting': '(34K)'}
# {'Title': '25. My Old Ass', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '6.9', 'Voting': '(42K)'}
# {'Title': '26. Borderlands', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '4.7', 'Voting': '(51K)'}
# {'Title': '27. Despicable Me 4', 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '6.2', 'Voting': '(69K)'}
# {'Title': '28. Sketch', 'Genre': 'Comedy', 'Duration': '1h 32m', 'Rating': '8.1', 'Voting': '(95)'}
# {'Title': '29. The Friend', 'Genre': 'Comedy', 'Duration': '1h 59m', 'Rating': '6.3', 'Voting': '(3.5K)'}
# {'Title': '30. The Instigators', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '6.2', 'Voting': '(39K)'}
# {'Title': '31. Paddington in Peru', 'Genre': 'Comedy', 'Duration': '1h 46m', 'Rating': '6.7', 'Voting': '(27K)'}
# {'Title': '32. Bad Boys: Ride or Die', 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '6.5', 'Voting': '(104K)'}
# {'Title': '33. A Different Man', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '6.9', 'Voting': '(32K)'}
# {'Title': '34. Bob Trevino Likes It', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '7.5', 'Voting': '(2.8K)'}
# {'Title': '35. Snack Shack', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '7.0', 'Voting': '(14K)'}
# {'Title': '36. Kneecap', 'Genre': 'Comedy', 'Duration': '1h 45m', 'Rating': '7.6', 'Voting': '(20K)'}
# {'Title': '37. The Union', 'Genre': 'Comedy', 'Duration': '1h 47m', 'Rating': '5.4', 'Voting': '(55K)'}
# {'Title': '38. The Greatest Hits', 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '6.2', 'Voting': '(7.8K)'}
# {'Title': '39. Spermageddon', 'Genre': 'Comedy', 'Duration': '1h 20m', 'Rating': '5.5', 'Voting': '(1.3K)'}
# {'Title': '40. Red One', 'Genre': 'Comedy', 'Duration': '2h 3m', 'Rating': '6.3', 'Voting': '(143K)'}
# {'Title': '41. The Visitor', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '4.1', 'Voting': '(404)'}
# {'Title': '42. Mean Girls', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '5.5', 'Voting': '(38K)'}
# {'Title': "43. It's What's Inside", 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '6.6', 'Voting': '(45K)'}
# {'Title': '44. Kung Fu Panda 4', 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '6.3', 'Voting': '(71K)'}
# {'Title': '45. F*** Marry Kill', 'Genre': 'Comedy', 'Duration': '1h 37m', 'Rating': '5.3', 'Voting': '(3.4K)'}
# {'Title': '46. Sew Torn', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '6.0', 'Voting': '(968)'}
# {'Title': '47. Ricky Stanicky', 'Genre': 'Comedy', 'Duration': '1h 53m', 'Rating': '6.2', 'Voting': '(58K)'}
# {'Title': '48. On Becoming a Guinea Fowl', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '7.0', 'Voting': '(1.4K)'}
# {'Title': '49. Misericordia', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '6.8', 'Voting': '(2.8K)'}
# {'Title': '50. Drive-Away Dolls', 'Genre': 'Comedy', 'Duration': '1h 24m', 'Rating': '5.4', 'Voting': '(25K)'}
# {'Title': '51. A Family Affair', 'Genre': 'Comedy', 'Duration': '1h 51m', 'Rating': '5.4', 'Voting': '(38K)'}
# {'Title': '52. A Nice Indian Boy', 'Genre': 'Comedy', 'Duration': '1h 36m', 'Rating': '7.4', 'Voting': '(2.6K)'}
# {'Title': '53. Jackpot!', 'Genre': 'Comedy', 'Duration': '1h 46m', 'Rating': '5.8', 'Voting': '(32K)'}
# {'Title': '54. The Garfield Movie', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '5.7', 'Voting': '(25K)'}
# {'Title': '55. The Day the Earth Blew Up: A Looney Tunes Movie', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '6.9', 'Voting': '(6.5K)'}
# {'Title': '56. Beverly Hills Cop: Axel F', 'Genre': 'Comedy', 'Duration': '1h 58m', 'Rating': '6.4', 'Voting': '(83K)'}
# {'Title': '57. How to Make Millions Before Grandma Dies', 'Genre': 'Comedy', 'Duration': '2h 5m', 'Rating': '7.9', 'Voting': '(18K)'}
# {'Title': '58. Nightbitch', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '5.5', 'Voting': '(21K)'}
# {'Title': "59. Miller's Girl", 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '5.2', 'Voting': '(25K)'}
# {'Title': "60. The Killer's Game", 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '5.8', 'Voting': '(19K)'}
# {'Title': "61. I Don't Understand You", 'Genre': 'Comedy', 'Duration': '1h 37m', 'Rating': '5.4', 'Voting': '(939)'}
# {'Title': '62. Eephus', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '6.7', 'Voting': '(1.1K)'}
# {'Title': '63. Thelma', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '7.0', 'Voting': '(25K)'}
# {'Title': '64. The Wonderful Story of Henry Sugar and Three More', 'Genre': 'Comedy', 'Duration': '1h 28m', 'Rating': '7.1', 'Voting': '(8.7K)'}
# {'Title': '65. Y2K', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '4.8', 'Voting': '(17K)'}
# {'Title': '66. Modi: Three Days on the Wing of Madness', 'Genre': 'Comedy', 'Duration': '1h 48m', 'Rating': '5.4', 'Voting': '(651)'}
# {'Title': '67. Dìdi', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '7.3', 'Voting': '(14K)'}
# {'Title': '68. Jane Austen Wrecked My Life', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '6.4', 'Voting': '(963)'}
# {'Title': '69. Brothers', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '5.4', 'Voting': '(14K)'}
# {'Title': '70. Role Play', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '5.5', 'Voting': '(19K)'}
# {'Title': '71. Get Away', 'Genre': 'Comedy', 'Duration': '1h 26m', 'Rating': '5.3', 'Voting': '(7.8K)'}
# {'Title': '72. Incoming', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '5.8', 'Voting': '(15K)'}
# {'Title': '73. Old Guy', 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '5.2', 'Voting': '(3.4K)'}
# {'Title': '74. Upgraded', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '6.1', 'Voting': '(31K)'}
# {'Title': '75. Greedy People', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '6.2', 'Voting': '(13K)'}
# {'Title': '76. Wallace & Gromit: Vengeance Most Fowl', 'Genre': 'Comedy', 'Duration': '1h 22m', 'Rating': '7.5', 'Voting': '(37K)'}
# {'Title': '77. Lift', 'Genre': 'Comedy', 'Duration': '1h 47m', 'Rating': '5.5', 'Voting': '(50K)'}
# {'Title': '78. Wild Wild Punjab', 'Genre': 'Comedy', 'Duration': '1h 49m', 'Rating': '6.2', 'Voting': '(16K)'}
# {'Title': '79. Lisa Frankenstein', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '6.1', 'Voting': '(29K)'}
# {'Title': '80. Bad Shabbos', 'Genre': 'Comedy', 'Duration': '1h 24m', 'Rating': '7.2', 'Voting': '(334)'}
# {'Title': '81. Sacramento', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '5.9', 'Voting': '(1.8K)'}
# {'Title': '82. Superboys of Malegaon', 'Genre': 'Comedy', 'Duration': '2h 7m', 'Rating': '7.7', 'Voting': '(6.1K)'}
# {'Title': '83. Your Monster', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '6.4', 'Voting': '(6.5K)'}
# {'Title': '84. Holy Cow', 'Genre': 'Comedy', 'Duration': '1h 32m', 'Rating': '7.1', 'Voting': '(2.8K)'}
# {'Title': '85. Skincare', 'Genre': 'Comedy', 'Duration': '1h 36m', 'Rating': '5.7', 'Voting': '(5K)'}
# {'Title': '86. The Balconettes', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '5.9', 'Voting': '(1.5K)'}
# {'Title': '87. Dan Da Dan: First Encounter', 'Genre': 'Comedy', 'Duration': '1h 23m', 'Rating': '8.2', 'Voting': '(3.1K)'}
# {'Title': '88. Goodrich', 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '6.3', 'Voting': '(6.4K)'}
# {'Title': '89. Spellbound', 'Genre': 'Comedy', 'Duration': '1h 49m', 'Rating': '5.5', 'Voting': '(8K)'}
# {'Title': '90. Nuked', 'Genre': 'Comedy', 'Duration': '1h 26m', 'Rating': '6.8', 'Voting': '(67)'}
# {'Title': '91. The Marching Band', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '7.4', 'Voting': '(4.2K)'}
# {'Title': '92. Ghostlight', 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '7.6', 'Voting': '(6.5K)'}
# {'Title': '93. Hard Truths', 'Genre': 'Comedy', 'Duration': '1h 37m', 'Rating': '7.2', 'Voting': '(6.7K)'}
# {'Title': '94. The Uninvited', 'Genre': 'Comedy', 'Duration': '1h 37m', 'Rating': '5.3', 'Voting': '(800)'}
# {'Title': '95. Unfrosted', 'Genre': 'Comedy', 'Duration': '1h 37m', 'Rating': '5.5', 'Voting': '(35K)'}
# {'Title': '96. Harold and the Purple Crayon', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '5.7', 'Voting': '(9K)'}
# {'Title': '97. Der Buchspazierer', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '7.2', 'Voting': '(683)'}
# {'Title': '98. Four Mothers', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '6.9', 'Voting': '(583)'}
# {'Title': '99. Universal Language', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '6.9', 'Voting': '(2.1K)'}
# {'Title': '100. Sasquatch Sunset', 'Genre': 'Comedy', 'Duration': '1h 28m', 'Rating': '5.4', 'Voting': '(5.7K)'}
# {'Title': '101. Sookshma Darshini', 'Genre': 'Comedy', 'Duration': '2h 22m', 'Rating': '7.8', 'Voting': '(11K)'}
# {'Title': '102. Premalu', 'Genre': 'Comedy', 'Duration': '2h 36m', 'Rating': '7.8', 'Voting': '(21K)'}
# {'Title': '103. Mother of the Bride', 'Genre': 'Comedy', 'Duration': '1h 28m', 'Rating': '4.8', 'Voting': '(17K)'}
# {'Title': '104. Kahan Shuru Kahan Khatam', 'Genre': 'Comedy', 'Duration': '1h 47m', 'Rating': '6.1', 'Voting': '(3.3K)'}
# {'Title': '105. Rumours', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '4.9', 'Voting': '(5.3K)'}
# {'Title': '106. Orion and the Dark', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '6.3', 'Voting': '(18K)'}
# {'Title': '107. My Spy: The Eternal City', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '5.7', 'Voting': '(11K)'}
# {'Title': '108. My Dead Friend Zoe', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '6.5', 'Voting': '(2.9K)'}
# {'Title': '109. Piece by Piece', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '6.9', 'Voting': '(6.4K)'}
# {'Title': '110. Find Me Falling', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '6.3', 'Voting': '(13K)'}
# {'Title': '111. Family Pack', 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '5.5', 'Voting': '(9.8K)'}
# {'Title': '112. Cells at Work!', 'Genre': 'Comedy', 'Duration': '1h 49m', 'Rating': '6.7', 'Voting': '(1K)'}
# {'Title': '113. Simarik', 'Genre': 'Comedy', 'Duration': '1h 51m', 'Rating': '5.3', 'Voting': '(4.2K)'}
# {'Title': '114. The Radleys', 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '5.0', 'Voting': '(3K)'}
# {'Title': '115. Dead Talents Society', 'Genre': 'Comedy', 'Duration': '1h 51m', 'Rating': '7.0', 'Voting': '(2.7K)'}
# {'Title': '116. Night of the Zoopocalypse', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '6.0', 'Voting': '(1K)'}
# {'Title': '117. Uma Musume: Pretty Derby - Beginning of a New Era', 'Genre': 'Comedy', 'Duration': '1h 48m', 'Rating': '7.4', 'Voting': '(178)'}
# {'Title': '118. Ultraman: Rising', 'Genre': 'Comedy', 'Duration': '1h 57m', 'Rating': '6.9', 'Voting': '(6.8K)'}
# {'Title': '119. Psycho Therapy: The Shallow Tale of a Writer Who Decided to Write about a Serial Killer', 'Genre': 'Comedy', 'Duration': '1h 42m', 'Rating': '6.2', 'Voting': '(1.6K)'}
# {'Title': '120. My Favourite Cake', 'Genre': 'Comedy', 'Duration': '1h 37m', 'Rating': '7.4', 'Voting': '(8K)'}
# {'Title': '121. Our Little Secret', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '5.7', 'Voting': '(24K)'}
# {'Title': '122. Bloody Axe Wound', 'Genre': 'Comedy', 'Duration': '1h 23m', 'Rating': '5.0', 'Voting': '(1.1K)'}
# {'Title': "123. Doraemon the Movie: Nobita's Earth Symphony", 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '6.6', 'Voting': '(1.6K)'}
# {'Title': '124. The American Society of Magical Negroes', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '3.8', 'Voting': '(12K)'}
# {'Title': '125. Hitpig', 'Genre': 'Comedy', 'Duration': '1h 26m', 'Rating': '5.2', 'Voting': '(1.1K)'}
# {'Title': '126. The Merry Gentlemen', 'Genre': 'Comedy', 'Duration': '1h 27m', 'Rating': '4.8', 'Voting': '(10K)'}
# {'Title': '127. Super Happy Forever', 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '6.8', 'Voting': '(364)'}
# {'Title': '128. Irish Wish', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '5.2', 'Voting': '(22K)'}
# {'Title': '129. Stree 2: Sarkate Ka Aatank', 'Genre': 'Comedy', 'Duration': '2h 27m', 'Rating': '6.9', 'Voting': '(43K)'}
# {'Title': '130. Diamanti', 'Genre': 'Comedy', 'Duration': '2h 15m', 'Rating': '6.8', 'Voting': '(1.7K)'}
# {'Title': '131. Haikyu!! The Dumpster Battle', 'Genre': 'Comedy', 'Duration': '1h 25m', 'Rating': '7.7', 'Voting': '(6.7K)'}
# {'Title': '132. Aavesham', 'Genre': 'Comedy', 'Duration': '2h 35m', 'Rating': '7.8', 'Voting': '(30K)'}
# {'Title': '133. Dear Santa', 'Genre': 'Comedy', 'Duration': '1h 47m', 'Rating': '5.4', 'Voting': '(19K)'}
# {'Title': '134. Beautiful Wedding', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '4.1', 'Voting': '(4.4K)'}
# {'Title': '135. Jamais sans mon psy', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '5.1', 'Voting': '(615)'}
# {'Title': '136. Sweethearts', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '5.6', 'Voting': '(4.3K)'}
# {'Title': '137. Treasure', 'Genre': 'Comedy', 'Duration': '1h 51m', 'Rating': '6.3', 'Voting': '(2.2K)'}
# {'Title': '138. Manamey', 'Genre': 'Comedy', 'Duration': '2h 35m', 'Rating': '5.3', 'Voting': '(787)'}
# {'Title': '139. Teri Baaton Mein Aisa Uljha Jiya', 'Genre': 'Comedy', 'Duration': '2h 21m', 'Rating': '6.2', 'Voting': '(55K)'}
# {'Title': '140. Officer Black Belt', 'Genre': 'Comedy', 'Duration': '1h 48m', 'Rating': '6.9', 'Voting': '(8.9K)'}
# {'Title': '141. The Astronaut Lovers', 'Genre': 'Comedy', 'Duration': '1h 56m', 'Rating': '7.1', 'Voting': '(1K)'}
# {'Title': '142. Three Friends', 'Genre': 'Comedy', 'Duration': '1h 57m', 'Rating': '6.6', 'Voting': '(892)'}
# {'Title': '143. Sunlight', 'Genre': 'Comedy', 'Duration': '1h 36m', 'Rating': '7.6', 'Voting': '(42)'}
# {'Title': '144. Winner', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '6.5', 'Voting': '(2.8K)'}
# {'Title': '145. I, the Executioner', 'Genre': 'Comedy', 'Duration': '1h 58m', 'Rating': '6.3', 'Voting': '(2.1K)'}
# {'Title': '146. Turn Me On', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '5.6', 'Voting': '(804)'}
# {'Title': '147. Megamind vs. The Doom Syndicate', 'Genre': 'Comedy', 'Duration': '1h 23m', 'Rating': '2.5', 'Voting': '(5.8K)'}
# {'Title': '148. Sweet Dreams', 'Genre': 'Comedy', 'Duration': '1h 35m', 'Rating': '5.4', 'Voting': '(1.5K)'}
# {'Title': '149. Hotspring Sharkattack', 'Genre': 'Comedy', 'Duration': '1h 10m', 'Rating': '6.1', 'Voting': '(66)'}
# {'Title': '150. Kalvan', 'Genre': 'Comedy', 'Duration': '2h 22m', 'Rating': '5.6', 'Voting': '(1K)'}
# {'Title': '151. The Second Act', 'Genre': 'Comedy', 'Duration': '1h 20m', 'Rating': '6.4', 'Voting': '(3.9K)'}
# {'Title': '152. A House on Fire', 'Genre': 'Comedy', 'Duration': '1h 45m', 'Rating': '7.2', 'Voting': '(3.6K)'}
# {'Title': '153. Between the Temples', 'Genre': 'Comedy', 'Duration': '1h 51m', 'Rating': '6.2', 'Voting': '(3.2K)'}
# {'Title': '154. Hot Frosty', 'Genre': 'Comedy', 'Duration': '1h 32m', 'Rating': '5.3', 'Voting': '(15K)'}
# {'Title': '155. I Am What I Am 2', 'Genre': 'Comedy', 'Duration': '2h 14m', 'Rating': '7.5', 'Voting': '(418)'}
# {'Title': '156. Sthanarthi Sreekuttan', 'Genre': 'Comedy', 'Duration': '2h 15m', 'Rating': '7.0', 'Voting': '(1.7K)'}
# {'Title': "157. Arthur's Whisky", 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '4.7', 'Voting': '(1K)'}
# {'Title': '158. Die Hart 2: Die Harter', 'Genre': 'Comedy', 'Duration': '1h 32m', 'Rating': '4.3', 'Voting': '(5.7K)'}
# {'Title': '159. Boot Camp', 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '5.8', 'Voting': '(1.3K)'}
# {'Title': '160. The Pee Pee Poo Poo Man', 'Genre': 'Comedy', 'Duration': '1h 19m', 'Rating': '7.7', 'Voting': '(44)'}
# {'Title': '161. Sex-Positive', 'Genre': 'Comedy', 'Duration': '1h 25m', 'Rating': '4.1', 'Voting': '(810)'}
# {'Title': '162. Adult Best Friends', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '5.2', 'Voting': '(575)'}
# {'Title': '163. Love in the Big City', 'Genre': 'Comedy', 'Duration': '1h 58m', 'Rating': '7.4', 'Voting': '(1.8K)'}
# {'Title': '164. Babes', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '6.3', 'Voting': '(6.6K)'}
# {'Title': '165. The Fabulous Four', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '4.8', 'Voting': '(1.7K)'}
# {'Title': "166. The Supremes at Earl's All-You-Can-Eat", 'Genre': 'Comedy', 'Duration': '2h 4m', 'Rating': '6.5', 'Voting': '(1.5K)'}
# {'Title': '167. The Problem with People', 'Genre': 'Comedy', 'Duration': '1h 42m', 'Rating': '5.7', 'Voting': '(562)'}
# {'Title': '168. Space Cadet', 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '5.0', 'Voting': '(10K)'}
# {'Title': '169. The Mouse Trap', 'Genre': 'Comedy', 'Duration': '1h 20m', 'Rating': '2.4', 'Voting': '(3.6K)'}
# {'Title': '170. Peacock', 'Genre': 'Comedy', 'Duration': '1h 42m', 'Rating': '7.2', 'Voting': '(739)'}
# {'Title': '171. Crayon Shin-chan: Our Dinosaur Diary', 'Genre': 'Comedy', 'Duration': '1h 46m', 'Rating': '6.6', 'Voting': '(633)'}
# {'Title': '172. Standing on the Shoulders of Kitties', 'Genre': 'Comedy', 'Duration': '1h 51m', 'Rating': '6.2', 'Voting': '(680)'}
# {'Title': '173. Stealing Pulp Fiction', 'Genre': 'Comedy', 'Duration': '1h 18m', 'Rating': '6.0', 'Voting': '(54)'}
# {'Title': '174. Mukadderat', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '7.0', 'Voting': '(1.6K)'}
# {'Title': "175. Let's Start a Cult", 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '5.9', 'Voting': '(1.6K)'}
# {'Title': '176. Through My Window: Looking at You', 'Genre': 'Comedy', 'Duration': '1h 45m', 'Rating': '5.5', 'Voting': '(5.6K)'}
# {'Title': '177. That Christmas', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '6.8', 'Voting': '(17K)'}
# {'Title': '178. How to Make a Killing', 'Genre': 'Comedy', 'Duration': '1h 49m', 'Rating': '6.5', 'Voting': '(1.5K)'}
# {'Title': "179. Don't Tell Mom the Babysitter's Dead", 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '3.8', 'Voting': '(1.3K)'}
# {'Title': '180. Do Aur Do Pyaar', 'Genre': 'Comedy', 'Duration': '2h 20m', 'Rating': '6.4', 'Voting': '(12K)'}
# {'Title': '181. Miracle Mirrors', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '5.4', 'Voting': '(396)'}
# {'Title': '182. Players', 'Genre': 'Comedy', 'Duration': '1h 45m', 'Rating': '5.7', 'Voting': '(12K)'}
# {'Title': '183. Jaaiye Aap Kahan Jaayenge', 'Genre': 'Comedy', 'Duration': '1h 59m', 'Rating': '8.7', 'Voting': '(59)'}
# {'Title': '184. Un altro ferragosto', 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '5.7', 'Voting': '(653)'}
# {'Title': '185. I Love You Forever', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '5.6', 'Voting': '(219)'}
# {'Title': '186. The 4:30 Movie', 'Genre': 'Comedy', 'Duration': '1h 27m', 'Rating': '6.0', 'Voting': '(4K)'}
# {'Title': '187. Boy Kaldag', 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '5.5', 'Voting': '(192)'}
# {'Title': '188. Lake George', 'Genre': 'Comedy', 'Duration': '1h 58m', 'Rating': '6.5', 'Voting': '(1.6K)'}
# {'Title': '189. Pabar', 'Genre': 'Comedy', 'Duration': '2h 39m', 'Rating': '8.2', 'Voting': '(283)'}
# {'Title': '190. Buffalo Kids', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '6.6', 'Voting': '(793)'}
# {'Title': '191. Madgaon Express', 'Genre': 'Comedy', 'Duration': '2h 23m', 'Rating': '7.0', 'Voting': '(41K)'}
# {'Title': '192. Vaazha: Biopic of a Billion Boys', 'Genre': 'Comedy', 'Duration': '2h 5m', 'Rating': '7.3', 'Voting': '(4.7K)'}
# {'Title': '193. Believe in Christmas', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '6.1', 'Voting': '(870)'}
# {'Title': '194. Everybody Loves Jenifa', 'Genre': 'Comedy', 'Duration': '2h 15m', 'Rating': '8.4', 'Voting': '(103)'}
# {'Title': '195. Ajosepo', 'Genre': 'Comedy', 'Duration': '2h 14m', 'Rating': '8.8', 'Voting': '(72)'}
# {'Title': '196. Vulgar', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '5.4', 'Voting': '(205)'}
# {'Title': '197. Hisaab Barabar', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '5.8', 'Voting': '(1.9K)'}
# {'Title': '198. Handsome Guys', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '6.5', 'Voting': '(990)'}
# {'Title': '199. Khel Khel Mein', 'Genre': 'Comedy', 'Duration': '2h 15m', 'Rating': '6.5', 'Voting': '(28K)'}
# {'Title': '200. Summer Camp', 'Genre': 'Comedy', 'Duration': '1h 35m', 'Rating': '4.5', 'Voting': '(1.7K)'}
# {'Title': '201. This Is Me... Now', 'Genre': 'Comedy', 'Duration': '1h 5m', 'Rating': '4.1', 'Voting': '(7.2K)'}
# {'Title': "202. My Ex's Wedding", 'Genre': 'Comedy', 'Duration': '1h 35m', 'Rating': '8.8', 'Voting': '(58)'}
# {'Title': '203. Am I Racist?', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '6.6', 'Voting': '(17K)'}
# {'Title': '204. U Are the Universe', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '7.6', 'Voting': '(419)'}
# {'Title': '205. Crew', 'Genre': 'Comedy', 'Duration': '1h 58m', 'Rating': '5.8', 'Voting': '(38K)'}
# {'Title': '206. Bau: Artist at War', 'Genre': 'Comedy', 'Duration': '2h 10m', 'Rating': '7.2', 'Voting': '(65)'}
# {'Title': '207. Tim Travers & the Time Travelers Paradox', 'Genre': 'Comedy', 'Duration': '1h 35m', 'Rating': '6.8', 'Voting': '(354)'}
# {'Title': '208. A Little Something Extra', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '7.0', 'Voting': '(5.3K)'}
# {'Title': '209. The Thundermans Return', 'Genre': 'Comedy', 'Duration': '1h 10m', 'Rating': '5.0', 'Voting': '(1.9K)'}
# {'Title': '210. Dedalus', 'Genre': 'Comedy', 'Duration': '1h 32m', 'Rating': '7.8', 'Voting': '(48)'}
# {'Title': '211. Takintilar', 'Genre': 'Comedy', 'Duration': '1h 36m', 'Rating': '5.3', 'Voting': '(3K)'}
# {'Title': '212. Invention', 'Genre': 'Comedy', 'Duration': '1h 12m', 'Rating': '5.9', 'Voting': '(119)'}
# {'Title': '213. Saving Bikini Bottom: The Sandy Cheeks Movie', 'Genre': 'Comedy', 'Duration': '1h 22m', 'Rating': '3.7', 'Voting': '(4.1K)'}
# {'Title': '214. Baby Assassins: Nice Days', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '7.2', 'Voting': '(380)'}
# {'Title': '215. This Time Next Year', 'Genre': 'Comedy', 'Duration': '1h 56m', 'Rating': '5.6', 'Voting': '(2.4K)'}
# {'Title': '216. You Are the Apple of My Eye', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '6.8', 'Voting': '(3.8K)'}
# {'Title': '217. Bring on the Damned!', 'Genre': 'Comedy', 'Duration': '1h 54m', 'Rating': '5.0', 'Voting': '(49)'}
# {'Title': '218. Swamp Dogg Gets His Pool Painted', 'Genre': 'Comedy', 'Duration': '1h 35m', 'Rating': '8.3', 'Voting': '(99)'}
# {'Title': '219. How Could I Live Without You?', 'Genre': 'Comedy', 'Duration': '1h 45m', 'Rating': '6.9', 'Voting': '(1.1K)'}
# {'Title': '220. Bidurbhai', 'Genre': 'Comedy', 'Duration': '2h 28m', 'Rating': '9.2', 'Voting': '(421)'}
# {'Title': '221. White Snake: Afloat', 'Genre': 'Comedy', 'Duration': '2h 13m', 'Rating': '6.9', 'Voting': '(593)'}
# {'Title': '222. Munjya', 'Genre': 'Comedy', 'Duration': '2h 3m', 'Rating': '6.3', 'Voting': '(26K)'}
# {'Title': '223. Nutcrackers', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '5.5', 'Voting': '(9.5K)'}
# {'Title': '224. Dirty Ice Cream', 'Genre': 'Comedy', 'Duration': '47m', 'Rating': '4.2', 'Voting': '(139)'}
# {'Title': '225. The Best Christmas Pageant Ever', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '6.8', 'Voting': '(6.3K)'}
# {'Title': '226. Trouble', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '6.2', 'Voting': '(7.2K)'}
# {'Title': '227. Chosen Family', 'Genre': 'Comedy', 'Duration': '1h 28m', 'Rating': '4.7', 'Voting': '(526)'}
# {'Title': '228. Kangaroo Island', 'Genre': 'Comedy', 'Duration': '1h 53m', 'Rating': '7.9', 'Voting': '(30)'}
# {'Title': "229. Jim's Story", 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '6.8', 'Voting': '(1.1K)'}
# {'Title': '230. Murder Mubarak', 'Genre': 'Comedy', 'Duration': '2h 20m', 'Rating': '5.8', 'Voting': '(51K)'}
# {'Title': '231. À bicyclette!', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '6.9', 'Voting': '(296)'}
# {'Title': '232. Notice to Quit', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '5.5', 'Voting': '(621)'}
# {'Title': '233. Bull Run', 'Genre': 'Comedy', 'Duration': '1h 37m', 'Rating': '8.2', 'Voting': '(14)'}
# {'Title': '234. Timestalker', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '5.5', 'Voting': '(3.1K)'}
# {'Title': "235. The Tiger's Apprentice", 'Genre': 'Comedy', 'Duration': '1h 24m', 'Rating': '5.8', 'Voting': '(2.3K)'}
# {'Title': '236. Opa Cor', 'Genre': 'Comedy', 'Duration': '1h 26m', 'Rating': '5.7', 'Voting': '(403)'}
# {'Title': '237. Marcello Mio', 'Genre': 'Comedy', 'Duration': '2h', 'Rating': '5.9', 'Voting': '(998)'}
# {'Title': "238. Cheech & Chong's Last Movie", 'Genre': 'Comedy', 'Duration': '2h', 'Rating': '7.3', 'Voting': '(533)'}
# {'Title': '239. Breakfast with Giraffes', 'Genre': 'Comedy', 'Duration': '1h 37m', 'Rating': '5.9', 'Voting': '(1.2K)'}
# {'Title': '240. Reunion', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '5.6', 'Voting': '(3.7K)'}
# {'Title': '241. The Gutter', 'Genre': 'Comedy', 'Duration': '1h 32m', 'Rating': '5.5', 'Voting': '(584)'}
# {'Title': '242. El Hareefa 2: El Remontada', 'Genre': 'Comedy', 'Duration': '2h 10m', 'Rating': '6.3', 'Voting': '(570)'}
# {'Title': '243. Little Death', 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '5.5', 'Voting': '(213)'}
# {'Title': '244. Drugstore June', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '5.4', 'Voting': '(1.8K)'}
# {'Title': '245. Agak Laen', 'Genre': 'Comedy', 'Duration': '1h 59m', 'Rating': '7.6', 'Voting': '(3.1K)'}
# {'Title': '246. Chantal in Fairyland', 'Genre': 'Comedy', 'Duration': '1h 58m', 'Rating': '4.6', 'Voting': '(2.8K)'}
# {'Title': '247. Marmalade', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '6.3', 'Voting': '(3.8K)'}
# {'Title': '248. Empire Queen: The Golden Age of Magic', 'Genre': 'Comedy', 'Duration': '2h 28m', 'Rating': '3.3', 'Voting': '(255)'}
# {'Title': '249. The Black Hole', 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '6.0', 'Voting': '(256)'}
# {'Title': '250. Thelma the Unicorn', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '5.7', 'Voting': '(3.1K)'}
# {'Title': '251. Prom Dates', 'Genre': 'Comedy', 'Duration': '1h 26m', 'Rating': '5.2', 'Voting': '(1.8K)'}
# {'Title': '252. Bhool Bhulaiyaa 3', 'Genre': 'Comedy', 'Duration': '2h 38m', 'Rating': '4.6', 'Voting': '(78K)'}
# {'Title': '253. Heavier Trip', 'Genre': 'Comedy', 'Duration': '1h 36m', 'Rating': '6.0', 'Voting': '(1.5K)'}
# {'Title': '254. And Mrs', 'Genre': 'Comedy', 'Duration': '1h 51m', 'Rating': '5.8', 'Voting': '(846)'}
# {'Title': '255. Arena Wars', 'Genre': 'Comedy', 'Duration': '1h 36m', 'Rating': '5.5', 'Voting': '(3.2K)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '257. Her Seyin Basi Merkür', 'Genre': 'Comedy', 'Duration': '1h 45m', 'Rating': '3.4', 'Voting': '(504)'}
# {'Title': '258. The Mountain', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '6.5', 'Voting': '(214)'}
# {'Title': '259. La Casa', 'Genre': 'Comedy', 'Duration': '1h 23m', 'Rating': '6.9', 'Voting': '(1K)'}
# {'Title': '260. Mittran Da Challeya Truck Ni', 'Genre': 'Comedy', 'Duration': '2h 11m', 'Rating': '7.7', 'Voting': '(1.1K)'}
# {'Title': '261. How to Date Billy Walsh', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '5.2', 'Voting': '(4K)'}
# {'Title': '262. Bookworm', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '6.0', 'Voting': '(2.1K)'}
# {'Title': "263. The Price of Nonna's Inheritance", 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '5.3', 'Voting': '(1.2K)'}
# {'Title': '264. Panda Plan', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '5.1', 'Voting': '(1.6K)'}
# {'Title': '265. Up the Catalogue', 'Genre': 'Comedy', 'Duration': '1h 12m', 'Rating': '8.1', 'Voting': '(10)'}
# {'Title': '266. Shell', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '6.8', 'Voting': '(79)'}
# {'Title': '267. The Fisherman', 'Genre': 'Comedy', 'Duration': '1h 46m', 'Rating': '7.5', 'Voting': '(60)'}
# {'Title': '268. Dear Paris', 'Genre': 'Comedy', 'Duration': '1h 48m', 'Rating': '5.6', 'Voting': '(409)'}
# {'Title': '269. Zenithal', 'Genre': 'Comedy', 'Duration': '1h 20m', 'Rating': '4.9', 'Voting': '(122)'}
# {'Title': '270. Gelin Takimi', 'Genre': 'Comedy', 'Duration': '1h 49m', 'Rating': '3.9', 'Voting': '(6.5K)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': "272. Kyuka: Before Summer's End", 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '6.3', 'Voting': '(414)'}
# {'Title': '273. The Present', 'Genre': 'Comedy', 'Duration': '1h 26m', 'Rating': '5.5', 'Voting': '(942)'}
# {'Title': '274. Pilot', 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '6.2', 'Voting': '(931)'}
# {'Title': '275. A Legend', 'Genre': 'Comedy', 'Duration': '2h 9m', 'Rating': '4.7', 'Voting': '(1.1K)'}
# {'Title': '276. Spread', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '5.7', 'Voting': '(682)'}
# {'Title': '277. Hotii de Subiecte', 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '6.4', 'Voting': '(228)'}
# {'Title': '278. A Country Called Ghana', 'Genre': 'Comedy', 'Duration': '1h 27m', 'Rating': '7.6', 'Voting': '(25)'}
# {'Title': '279. A.R.M', 'Genre': 'Comedy', 'Duration': '2h 30m', 'Rating': '7.1', 'Voting': '(9.1K)'}
# {'Title': '280. Feeling Randy', 'Genre': 'Comedy', 'Duration': '1h 21m', 'Rating': '7.1', 'Voting': '(519)'}
# {'Title': '281. The Other Way Around', 'Genre': 'Comedy', 'Duration': '1h 54m', 'Rating': '6.4', 'Voting': '(1.8K)'}
# {'Title': '282. Meet Me Next Christmas', 'Genre': 'Comedy', 'Duration': '1h 45m', 'Rating': '5.7', 'Voting': '(8.7K)'}
# {'Title': '283. Rent Free', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '7.8', 'Voting': '(82)'}
# {'Title': '284. Carved', 'Genre': 'Comedy', 'Duration': '1h 35m', 'Rating': '4.4', 'Voting': '(2.9K)'}
# {'Title': '285. 200% Wolf', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '5.9', 'Voting': '(1.3K)'}
# {'Title': '286. Lopaliki Ra Chepta', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '8.1', 'Voting': '(1.5K)'}
# {'Title': '287. Seeds', 'Genre': 'Comedy', 'Duration': '1h 22m', 'Rating': '4.9', 'Voting': '(240)'}
# {'Title': '288. Running on Empty', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '4.9', 'Voting': '(618)'}
# {'Title': '289. Five Blind Dates', 'Genre': 'Comedy', 'Duration': '1h 23m', 'Rating': '5.1', 'Voting': '(2.1K)'}
# {'Title': '290. Queens of Drama', 'Genre': 'Comedy', 'Duration': '1h 54m', 'Rating': '6.3', 'Voting': '(225)'}
# {'Title': '291. Meet the Barbarians', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '6.4', 'Voting': '(720)'}
# {'Title': '292. Blame the Game', 'Genre': 'Comedy', 'Duration': '1h 32m', 'Rating': '5.4', 'Voting': '(5.4K)'}
# {'Title': '293. Nice Girls', 'Genre': 'Comedy', 'Duration': '1h 32m', 'Rating': '4.2', 'Voting': '(1.2K)'}
# {'Title': '294. 10 Lives', 'Genre': 'Comedy', 'Duration': '1h 28m', 'Rating': '5.9', 'Voting': '(2.1K)'}
# {'Title': '295. Destroy All Neighbors', 'Genre': 'Comedy', 'Duration': '1h 25m', 'Rating': '5.3', 'Voting': '(2.1K)'}
# {'Title': '296. Varshangalkku Shesham', 'Genre': 'Comedy', 'Duration': '2h 46m', 'Rating': '6.6', 'Voting': '(4.5K)'}
# {'Title': '297. K-Pops!', 'Genre': 'Comedy', 'Duration': '1h 54m', 'Rating': '7.3', 'Voting': '(62)'}
# {'Title': '298. The Trainer', 'Genre': 'Comedy', 'Duration': '1h 35m', 'Rating': '7.2', 'Voting': '(67)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '300. The Holiday List', 'Genre': 'Comedy', 'Duration': '1h 25m', 'Rating': '4.2', 'Voting': '(219)'}
# {'Title': '301. Pegasus 2', 'Genre': 'Comedy', 'Duration': '2h 1m', 'Rating': '6.9', 'Voting': '(1.3K)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '303. The Underdoggs', 'Genre': 'Comedy', 'Duration': '1h 36m', 'Rating': '5.6', 'Voting': '(4.7K)'}
# {'Title': '304. Illegal Hayatlar: Meclis', 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '6.8', 'Voting': '(860)'}
# {'Title': '305. Frankie Freako', 'Genre': 'Comedy', 'Duration': '1h 25m', 'Rating': '5.5', 'Voting': '(1.4K)'}
# {'Title': '306. Citizen of a Kind', 'Genre': 'Comedy', 'Duration': '1h 54m', 'Rating': '6.6', 'Voting': '(935)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '309. Fakt Purusho Maate', 'Genre': 'Comedy', 'Duration': '2h 16m', 'Rating': '7.0', 'Voting': '(283)'}
# {'Title': '310. Lesbian Space Princess', 'Genre': 'Comedy', 'Duration': '1h 27m', 'Rating': '7.1', 'Voting': '(212)'}
# {'Title': '311. I Want to Be Neenja! The Movie', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '3.6', 'Voting': '(404)'}
# {'Title': '312. The Empire', 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '5.2', 'Voting': '(1.4K)'}
# {'Title': '313. Her Story', 'Genre': 'Comedy', 'Duration': '2h 3m', 'Rating': '7.6', 'Voting': '(2K)'}
# {'Title': '314. Street Trash', 'Genre': 'Comedy', 'Duration': '1h 25m', 'Rating': '4.5', 'Voting': '(965)'}
# {'Title': '315. Dog on Trial', 'Genre': 'Comedy', 'Duration': '1h 23m', 'Rating': '6.0', 'Voting': '(809)'}
# {'Title': '316. The Southern Chronicles', 'Genre': 'Comedy', 'Duration': '2h', 'Rating': '8.7', 'Voting': '(2.9K)'}
# {'Title': '317. Rats!', 'Genre': 'Comedy', 'Duration': '1h 25m', 'Rating': '6.5', 'Voting': '(224)'}
# {'Title': '318. Crackcoon', 'Genre': 'Comedy', 'Duration': '1h 28m', 'Rating': '3.6', 'Voting': '(458)'}
# {'Title': '319. Slay', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '6.5', 'Voting': '(1.2K)'}
# {'Title': '320. Krazy House', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '4.8', 'Voting': '(1.5K)'}
# {'Title': "321. Noah's Ark", 'Genre': 'Comedy', 'Duration': '1h 36m', 'Rating': '4.2', 'Voting': '(706)'}
# {'Title': '322. Two to One', 'Genre': 'Comedy', 'Duration': '1h 56m', 'Rating': '6.1', 'Voting': '(869)'}
# {'Title': '323. When in Rome', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '6.1', 'Voting': '(809)'}
# {'Title': '324. The Code', 'Genre': 'Comedy', 'Duration': '1h 38m', 'Rating': '6.0', 'Voting': '(242)'}
# {'Title': '325. Longing', 'Genre': 'Comedy', 'Duration': '1h 51m', 'Rating': '4.7', 'Voting': '(942)'}
# {'Title': '326. Wishing on a Star', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '6.6', 'Voting': '(195)'}
# {'Title': '327. No Time to Spy: A Loud House Movie', 'Genre': 'Comedy', 'Duration': '1h 21m', 'Rating': '6.3', 'Voting': '(505)'}
# {'Title': '328. Tezgah', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '5.4', 'Voting': '(204)'}
# {'Title': '329. Broken Rage', 'Genre': 'Comedy', 'Duration': '1h 2m', 'Rating': '6.1', 'Voting': '(1.7K)'}
# {'Title': '330. And the Breadwinner Is...', 'Genre': 'Comedy', 'Duration': '2h 3m', 'Rating': '5.9', 'Voting': '(494)'}
# {'Title': '331. My Future You', 'Genre': 'Comedy', 'Duration': '1h 49m', 'Rating': '7.4', 'Voting': '(317)'}
# {'Title': '332. Wallbanger', 'Genre': 'Comedy', 'Duration': '1h 58m', 'Rating': '5.6', 'Voting': '(750)'}
# {'Title': '333. A Sudden Case of Christmas', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '5.1', 'Voting': '(1.2K)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': "335. We're All Gonna Die", 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '5.7', 'Voting': '(177)'}
# {'Title': '336. Monster on a Plane', 'Genre': 'Comedy', 'Duration': '1h 28m', 'Rating': '4.6', 'Voting': '(2.4K)'}
# {'Title': '337. Face Off 7: One Wish', 'Genre': 'Comedy', 'Duration': '2h 18m', 'Rating': '7.3', 'Voting': '(383)'}
# {'Title': '338. Another Day in America', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '8.9', 'Voting': '(95)'}
# {'Title': '339. Sin instrucciones', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '6.3', 'Voting': '(655)'}
# {'Title': "340. Operation Taco Gary's", 'Genre': 'Comedy', 'Duration': '1h 28m', 'Rating': '6.8', 'Voting': '(35)'}
# {'Title': '341. Empire Waist', 'Genre': 'Comedy', 'Duration': '1h 37m', 'Rating': '6.2', 'Voting': '(218)'}
# {'Title': '342. Troubleshooters', 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '6.4', 'Voting': '(436)'}
# {'Title': '343. Mr. Manhattan', 'Genre': 'Comedy', 'Duration': '1h 50m', 'Rating': '6.8', 'Voting': '(479)'}
# {'Title': '344. Jack in Time for Christmas', 'Genre': 'Comedy', 'Duration': '1h 6m', 'Rating': '4.6', 'Voting': '(1K)'}
# {'Title': '345. Moartea in vacanta', 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '6.6', 'Voting': '(1.7K)'}
# {'Title': "346. Christmas Eve in Miller's Point", 'Genre': 'Comedy', 'Duration': '1h 46m', 'Rating': '5.6', 'Voting': '(2.3K)'}
# {'Title': "347. A Dog's Will 2", 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '6.2', 'Voting': '(3.2K)'}
# {'Title': '348. Griffin in Summer', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '7.2', 'Voting': '(172)'}
# {'Title': "349. Everything's Fifty Fifty", 'Genre': 'Comedy', 'Duration': '1h 53m', 'Rating': '6.3', 'Voting': '(589)'}
# {'Title': '350. Denominación de origen', 'Genre': 'Comedy', 'Duration': '1h 26m', 'Rating': '8.2', 'Voting': '(305)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '352. 404 Run Run', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '5.7', 'Voting': '(507)'}
# {'Title': '353. Balas & Bolinhos: Só Mais uma Coisa', 'Genre': 'Comedy', 'Duration': '1h 53m', 'Rating': '6.3', 'Voting': '(405)'}
# {'Title': '354. Bodegón con fantasmas', 'Genre': 'Comedy', 'Duration': '1h 28m', 'Rating': '6.5', 'Voting': '(264)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '356. The Everything Pot', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '7.5', 'Voting': '(35)'}
# {'Title': '357. The Gesuidouz', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '6.7', 'Voting': '(100)'}
# {'Title': '358. Honey Money Phony', 'Genre': 'Comedy', 'Duration': '1h 55m', 'Rating': '6.2', 'Voting': '(225)'}
# {'Title': '359. Sallywood', 'Genre': 'Comedy', 'Duration': '1h 35m', 'Rating': '7.7', 'Voting': '(62)'}
# {'Title': '360. Mud Key', 'Genre': 'Comedy', 'Duration': '1h 16m', 'Rating': '5.5', 'Voting': '(77)'}
# {'Title': '361. Paying for It', 'Genre': 'Comedy', 'Duration': '1h 25m', 'Rating': '6.9', 'Voting': '(133)'}
# {'Title': '362. Haunt Season', 'Genre': 'Comedy', 'Duration': '1h 21m', 'Rating': '4.9', 'Voting': '(907)'}
# {'Title': '363. Enchanting Christmas', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '6.3', 'Voting': '(371)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '365. Drie dagen vis', 'Genre': 'Comedy', 'Duration': '1h 25m', 'Rating': '7.4', 'Voting': '(328)'}
# {'Title': '366. Say a Little Prayer', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '8.5', 'Voting': '(48)'}
# {'Title': '367. Vicky Vidya Ka Woh Wala Video', 'Genre': 'Comedy', 'Duration': '2h 32m', 'Rating': '5.2', 'Voting': '(12K)'}
# {'Title': '368. V dobrém i zlém', 'Genre': 'Comedy', 'Duration': '1h 33m', 'Rating': '6.0', 'Voting': '(98)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': "370. Hemet, or the Landlady Don't Drink Tea", 'Genre': 'Comedy', 'Duration': '1h 29m', 'Rating': '4.3', 'Voting': '(96)'}
# {'Title': '371. Seni Memahami Kekasih', 'Genre': 'Comedy', 'Duration': '1h 31m', 'Rating': '8.0', 'Voting': '(65)'}
# {'Title': '372. Badaa Saat Fi Yawman Ma', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '5.8', 'Voting': '(357)'}
# {'Title': '373. Extremely Unique Dynamic', 'Genre': 'Comedy', 'Duration': '1h 13m', 'Rating': '7.4', 'Voting': '(353)'}
# {'Title': '374. Air Fryer Slaughter', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '6.3', 'Voting': '(569)'}
# {'Title': '375. Tomten är far till alla barnen', 'Genre': 'Comedy', 'Duration': '2h 30m', 'Rating': '7.2', 'Voting': '(14)'}
# {'Title': '376. Die Kwiksilwers (The Quicksilvers)', 'Genre': 'Comedy', 'Duration': '1h 30m', 'Rating': '8.4', 'Voting': '(16)'}
# {'Title': '377. Jo Koy: Live from Brooklyn', 'Genre': 'Comedy', 'Duration': '59m', 'Rating': '6.6', 'Voting': '(804)'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': 'N/A', 'Genre': 'Comedy', 'Duration': 'N/A', 'Rating': 'N/A', 'Voting': 'N/A'}
# {'Title': '380. Could Have Waited for August', 'Genre': 'Comedy', 'Duration': '1h 52m', 'Rating': '6.2', 'Voting': '(866)'}
# {'Title': '381. Hollywood Dreams', 'Genre': 'Comedy', 'Duration': '1h 39m', 'Rating': '8.5', 'Voting': '(22)'}
# {'Title': '382. Passagrana', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '6.4', 'Voting': '(148)'}
# {'Title': '383. Cheers to Life', 'Genre': 'Comedy', 'Duration': '1h 44m', 'Rating': '5.2', 'Voting': '(297)'}
# {'Title': '384. The Gentleman', 'Genre': 'Comedy', 'Duration': '1h 43m', 'Rating': '7.9', 'Voting': '(107)'}
# {'Title': '385. Lubber Pandhu', 'Genre': 'Comedy', 'Duration': '2h 26m', 'Rating': '8.1', 'Voting': '(6.9K)'}
# {'Title': '386. AJ Goes to the Dog Park', 'Genre': 'Comedy', 'Duration': '1h 19m', 'Rating': '7.2', 'Voting': '(15)'}
# {'Title': '387. Kundannoorile Kulsitha Lahala', 'Genre': 'Comedy', 'Duration': '2h 27m', 'Rating': '5.7', 'Voting': '(312)'}
# {'Title': '388. French Girl', 'Genre': 'Comedy', 'Duration': '1h 46m', 'Rating': '5.5', 'Voting': '(2.5K)'}
# {'Title': '389. City Hunter', 'Genre': 'Comedy', 'Duration': '1h 42m', 'Rating': '6.3', 'Voting': '(5.8K)'}
# {'Title': '390. 35-Chinna Katha Kaadu', 'Genre': 'Comedy', 'Duration': '2h 25m', 'Rating': '7.9', 'Voting': '(1.1K)'}
# {'Title': '391. Inheritance', 'Genre': 'Comedy', 'Duration': '1h 34m', 'Rating': '5.1', 'Voting': '(3.7K)'}
# {'Title': '392. The Final Play', 'Genre': 'Comedy', 'Duration': '1h 48m', 'Rating': '7.4', 'Voting': '(12)'}
# {'Title': '393. Bad Newz', 'Genre': 'Comedy', 'Duration': '2h 22m', 'Rating': '4.7', 'Voting': '(26K)'}
# {'Title': '394. Mars', 'Genre': 'Comedy', 'Duration': '1h 24m', 'Rating': '8.1', 'Voting': '(26)'}
# {'Title': '395. Young Werther', 'Genre': 'Comedy', 'Duration': '1h 41m', 'Rating': '5.5', 'Voting': '(297)'}
# {'Title': '396. Guruvayoor Ambalanadayil', 'Genre': 'Comedy', 'Duration': '2h 12m', 'Rating': '6.6', 'Voting': '(5.1K)'}
# {'Title': '397. Miracle Mile', 'Genre': 'Comedy', 'Duration': '1h 22m', 'Rating': '7.3', 'Voting': '(42)'}
# {'Title': '398. Woody Woodpecker Goes to Camp', 'Genre': 'Comedy', 'Duration': '1h 40m', 'Rating': '4.5', 'Voting': '(2.7K)'}
# {'Title': '399. The Real Bros of Simi Valley: The Movie', 'Genre': 'Comedy', 'Duration': '1h 46m', 'Rating': '7.0', 'Voting': '(1.1K)'}
# {'Title': '400. Cocorico', 'Genre': 'Comedy', 'Duration': '1h 32m', 'Rating': '5.9', 'Voting': '(3.4K)'}

# %%
#common csv converting code

import pandas as pd

df=pd.DataFrame(movie_list)

# 1. Remove leading numbers from "Title"
df["Title"] = df["Title"].str.replace(r"^\d+\.\s*", "", regex=True)

# 2. Remove parentheses from "Voting"
df["Voting"] = df["Voting"].str.replace(r"[()]", "", regex=True)

# 3. Reset index to start from 1
df.index = df.index + 1

df.to_csv(r"D:\Nirosha\GUVI\Project\comedy.csv", index=False, encoding="utf-8")
print("CSV file - Comedy Movies saved successfully!")
# Out:
# CSV file - Comedy Movies saved successfully!

# %%
# %pip install pandas

import pandas as pd
import os
import mysql.connector

# Folder path containing the CSV files
folder_path = r"D:\Nirosha\GUVI\Project"

#  list of all CSV files in the folder 
csv_files = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith(".csv")][:5]

# Read and merge the data
df = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)

# Remove duplicates based on "Title" column (keep the first occurrence)
df.drop_duplicates(subset=["Title"], keep="first", inplace=True)

#  Save the cleaned merged data 
output_file = os.path.join(folder_path, "merged_cleaned_movies.csv")
df.to_csv(output_file, index=False)

print(f"Merged CSV file saved as: {output_file}")
# Out:
# Requirement already satisfied: pandas in d:\nirosha\guvi\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\nirosha\guvi\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\nirosha\guvi\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\nirosha\guvi\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\nirosha\guvi\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\nirosha\guvi\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Merged CSV file saved as: D:\Nirosha\GUVI\Project\merged_cleaned_movies.csv

# %%
# %pip install mysql-connector-python 

import pandas as pd
import numpy as np
import mysql.connector
connection = mysql.connector.connect(
    host = "LocalHost",
    port = 3306,
    user = "root",
    password = "Sathya@217989",
    database = "movies",
)

mycursor = connection.cursor(buffered=True)

# Read CSV
df = pd.read_csv(r"D:\Nirosha\GUVI\Project\merged_cleaned_movies.csv")

# Replace NaN values with NULL
df = df.replace({np.nan: None})

# Insert data into the table
for _,row in df.iterrows():
    mycursor.execute("INSERT INTO movies.total_movie(Title,Genre,Duration,Rating,Voting) VALUES (%s, %s, %s, %s, %s)", 
                     (row.Title, row.Genre, row.Duration, float(row.Rating) if row.Rating is not None else None, row.Voting)
    )

connection.commit()
mycursor.close()
connection.close()
print(" Data uploaded successfully!")
# Out:
# Requirement already satisfied: mysql-connector-python in d:\nirosha\guvi\.venv\lib\site-packages (9.3.0)
# Note: you may need to restart the kernel to use updated packages.
#  Data uploaded successfully!
